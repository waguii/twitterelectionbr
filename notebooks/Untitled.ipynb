# %%
import pandas as pd
import numpy as np
from twitterelectionbr.cnn.model_1.predict_gender import predict_gender_simple_img
import imutils

# %%
tweets_dilma = pd.read_csv('../raw_data/data/2014/DILMA_ROUSSEFF/#dilma/query_#dilma.csv', parse_dates=True)

# %%
tweets_dilma.shape
# Out:
# (37157, 21)

# %%
tweets_dilma.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37157 entries, 0 to 37156
# Data columns (total 21 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   url              37157 non-null  object
#  1   date             37157 non-null  object
#  2   content          37157 non-null  object
#  3   id               37157 non-null  int64
#  4   reply_count      37157 non-null  int64
#  5   retweet_count    37157 non-null  int64
#  6   like_count       37157 non-null  int64
#  7   quote_count      37157 non-null  int64
#  8   lang             37157 non-null  object
#  9   username         37157 non-null  object
#  10  displayname      37155 non-null  object
#  11  description      27664 non-null  object
#  12  verified         37157 non-null  bool
#  13  created          37157 non-null  object
#  14  followers_count  37157 non-null  int64
#  15  friends_count    37157 non-null  int64
#  16  location         24131 non-null  object
#  17  protected        37157 non-null  bool
#  18  profile_img      37156 non-null  object
#  19  query            37157 non-null  object
#  20  crawled_date     37157 non-null  object
# dtypes: bool(2), int64(7), object(12)
# memory usage: 5.5+ MB

# %%
def analyse_img_url(url):
    #print('URL ' + url)
    img = imutils.url_to_image(url)
    return predict_gender_simple_img(img)

# %%
def transform_dataset(dataset):
    
    dataset_unique = dataset.drop_duplicates(subset=['username']).sample(10)

    dataset_unique['cnn'] = [analyse_img_url(row) for row in dataset_unique['profile_img']]
    dataset_unique['gender']  = dataset_unique['cnn'].apply(lambda score_dict: score_dict.get('gender', np.nan))
    dataset_unique['gender_confidence_score']  = dataset_unique['cnn'].apply(lambda score_dict: score_dict.get('gender_confidence_score', np.nan))

    merged = pd.merge(tweets_dilma, dataset_unique, how='inner', 
                      left_on=['username'],right_on=['username'],
                      suffixes=('', '_delme'))

    # Discard the columns that acquired a suffix
    merged = merged[[c for c in merged.columns if not c.endswith('_delme')]]
    
    return merged

# %%
result = transform_dataset(tweets_dilma)

# %%
result
# Out:
#                                                   url                 date  \
# 0   https://twitter.com/jessicskull/status/4890667...  2014-07-15 15:19:42
# 1   https://twitter.com/jessicskull/status/5258093...  2014-10-25 00:41:26
# 2   https://twitter.com/jessicskull/status/4866380...  2014-07-08 22:28:35
# 3   https://twitter.com/andreluisantana/status/525...  2014-10-25 02:12:15
# 4   https://twitter.com/Pers3phon9/status/52582064...  2014-10-25 01:26:26
# 5   https://twitter.com/Pers3phon9/status/48554808...  2014-07-05 22:17:39
# 6   https://twitter.com/naiany/status/525817036002...  2014-10-25 01:12:05
# 7   https://twitter.com/Lucasfrota11/status/512008...  2014-09-16 22:41:35
# 8   https://twitter.com/InformeRJO/status/51890632...  2014-10-05 23:31:23
# 9   https://twitter.com/MarinaSilvaBLA/status/5210...  2014-10-11 19:54:35
# 10  https://twitter.com/leirbagoliver/status/52487...  2014-10-22 10:56:33
# 9   ...             320           608                     NaN     False
# 10  ...            1697          5000       São Paulo, Brasil     False
# 11  ...              73           345                     NaN     False
# 12  ...             179           280  Rio de Janeiro, Brasil     False
# 13  ...             179           280  Rio de Janeiro, Brasil     False
# 14  ...             179           280  Rio de Janeiro, Brasil     False
# 15  ...             179           280  Rio de Janeiro, Brasil     False
#
#                                           profile_img   query crawled_date  \
# 0   https://pbs.twimg.com/profile_images/150133844...  #dilma   2022-06-02
# 1   https://pbs.twimg.com/profile_images/150133844...  #dilma   2022-06-02
# 2   https://pbs.twimg.com/profile_images/150133844...  #dilma   2022-06-02
# 3   https://pbs.twimg.com/profile_images/147090848...  #dilma   2022-06-02
# 4   https://pbs.twimg.com/profile_images/139450705...  #dilma   2022-06-02
# 5   https://pbs.twimg.com/profile_images/139450705...  #dilma   2022-06-02
# 6   https://pbs.twimg.com/profile_images/563316418...  #dilma   2022-06-02
# 7   https://pbs.twimg.com/profile_images/104660051...  #dilma   2022-06-02
# 8   https://pbs.twimg.com/profile_images/887009084...  #dilma   2022-06-02
# 9   https://pbs.twimg.com/profile_images/521004775...  #dilma   2022-06-02
# 10  https://pbs.twimg.com/profile_images/152916614...  #dilma   2022-06-02
# 11  https://pbs.twimg.com/profile_images/750834684...  #dilma   2022-06-02
# 12  https://pbs.twimg.com/profile_images/810458976...  #dilma   2022-06-02
# 13  https://pbs.twimg.com/profile_images/810458976...  #dilma   2022-06-02
# 14  https://pbs.twimg.com/profile_images/810458976...  #dilma   2022-06-02
# 15  https://pbs.twimg.com/profile_images/810458976...  #dilma   2022-06-02
#
#                                                   cnn  gender  \
# 0   {'gender': 'Male', 'gender_confidence_score': ...    Male
# 1   {'gender': 'Male', 'gender_confidence_score': ...    Male
# 2   {'gender': 'Male', 'gender_confidence_score': ...    Male
# 3   {'gender': 'Male', 'gender_confidence_score': ...    Male
# 4   {'gender': 'Female', 'gender_confidence_score'...  Female
# 5   {'gender': 'Female', 'gender_confidence_score'...  Female
# 6                                                  {}     NaN
# 7   {'gender': 'Male', 'gender_confidence_score': ...    Male
# 8   {'gender': 'Male', 'gender_confidence_score': ...    Male
# 9   {'gender': 'Female', 'gender_confidence_score'...  Female
# 10                                                 {}     NaN
# 11                                                 {}     NaN
# 12  {'gender': 'Male', 'gender_confidence_score': ...    Male
# 13  {'gender': 'Male', 'gender_confidence_score': ...    Male
# 14  {'gender': 'Male', 'gender_confidence_score': ...    Male
# 15  {'gender': 'Male', 'gender_confidence_score': ...    Male
#
#    gender_confidence_score
# 0                 0.984948
# 1                 0.984948
# 2                 0.984948
# 3                 0.765194
# 4                 0.852856
# 5                 0.852856
# 6                      NaN
# 7                 0.985694
# 8                 0.993137
# 9                 0.948449
# 10                     NaN
# 11                     NaN
# 12                0.985081
# 13                0.985081
# 14                0.985081
# 15                0.985081
#
# [16 rows x 24 columns]
