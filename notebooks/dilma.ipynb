# %% [markdown]
# # Import modules

# %%
import pandas as pd
import numpy as np
import re
import string
import itertools
import unidecode
import nltk 
from nltk.util import ngrams
from nltk.corpus import stopwords
from tqdm import tqdm_notebook
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
from umap import UMAP
from hdbscan import HDBSCAN
from sklearn.feature_extraction.text import CountVectorizer

# %%
df = pd.read_csv('../raw_data/dilma.csv')
#df_dilma.head(10)

# %%
df['content'].sample(10)
# Out:
# 55508     "@Flordelismk: #Dilma VOCÊ ACHOU A TAMPA PARA ...
# 6987      Me lembro tanto da Erenice lépida e faceira at...
# 7386      #Dilma cumpriu todas as promessas feitas a tra...
# 103451    O que vai acontecer no Brasil caso a receita d...
# 19749     Nem com a maior boa vontade dá prá votar nas #...
# 92463     Por campanha de #Dilma, militância petista rea...
# 97780     Quem bate cartão não vota em patrão!!! #Dilma1...
# 37813     A foto é linda. Embora passe uma imagem triste...
# 94386              @MudaMais  #Dilma esta linda nesta foto!
# 60312     Kkkkkkkkkkkkk A #Dilma esqueceu de pagar esse ...
# Name: content, dtype: object

# %% [markdown]
# # Preprocessing

# %%
def clean_tweet(tweet):

    tweet = tweet.lower()
    tweet = re.sub(" \d+", "", tweet)
    tweet = re.sub('\@[a-zA-Z0-9]*', ' ', tweet) # remove username start with @
    tweet = re.sub('https?:\/\/[a-zA-Z0-9@:%._\/+~#=?&;-]*', ' ', tweet) # remove link in the tweet
    tweet = re.sub('\$[a-zA-Z0-9]*', ' ', tweet) # remove the variable start with $
    #tweet = re.sub('[^a-zA-Z\']', ' ', tweet)
    for punctuation in new_punc: # remove panctuations 
            tweet = tweet.replace(punctuation, '')
    tweet = ' '.join( [w for w in tweet.split() if len(w)>1] ) #remove one letter words
    tweet = ''.join(c[0] for c in itertools.groupby(tweet)) #remove duplicated letters
    tweet = unidecode.unidecode(tweet)  # normalizar as letras com acentos 
    tweet = ' '.join(word for word in tweet.split(' ') if word not in stop_words) # remove stopwords
    
                          
    #doc = nlp(tweet)
    #tweet= [token.lemma_ for token in doc ]
    
    return tweet

# %%
# %%time

new_punc = list(string.punctuation)
del new_punc[2]
stop_words = stopwords.words('portuguese')
stop_words.remove('não')
addicional = [
            'd', 'ta', 'q', 'tah', 'tao', 'eh', 'vc', 'voce',
            'pq', 'quedê', 'mto', 'mt', 'bj', 'bjs','vcs','bb',
            'b', 'sao', 'axo', 'mano', 'ae', 'neh', 'aí',
            'kkk', 'porque', 'né', 'no', 'iai', 'tbm', 'msm', 'jah', 'yahoo', 'yahoobr','rt']
stop_words.extend(addicional)
df['content'] = df['content'].astype(str)
df = df.drop_duplicates(subset="content",keep="first")

df["content_clean"]=df["content"].apply(lambda x:clean_tweet(x))

df=df[df["lang"]=="pt"]
df=df[["date","username","content_clean"]]
df['date'] = pd.to_datetime(df['date'])
df
# Out:
# CPU times: user 7.52 s, sys: 108 ms, total: 7.63 s
# Wall time: 8.17 s
#                       date        username  \
# 0      2014-09-19 23:58:17   luiz_carlosar
# 1      2014-09-19 23:57:12      alves_auri
# 2      2014-09-19 23:55:33   Sem_NeuroseYT
# 3      2014-09-19 23:51:37    NaldoValenca
# 4      2014-09-19 23:49:07         Colatto
# ...                    ...             ...
# 104625 2014-09-10 00:03:52      UDN_tofora
# 104626 2014-09-10 00:03:12      O_Apedeuta
# 104627 2014-09-10 00:02:16   TerezaBraSiLL
# 104628 2014-09-10 00:02:04          cavlis
# 104629 2014-09-10 00:01:05  alissonstynner
#
#                                             content_clean
# 0            boechat diz surpreso solidez campanha #dilma
# 1       permitame compartilhar pensamento #dilma outra...
# 2       #dilma compra pesquisa compra copa almenta pas...
# 3       alo coxinha #minhacasaminhavida #dilma investi...
# 4                                  hauahuahu #dilma entao
# ...                                                   ...
# 104625  matriculas ensino superior crescem8 #dilma #pt...
# 104626  contra tudocontra revistacontra comentaristas ...
# 104627          alguns investimentos governo #dilma paulo
# 104628  programa tv dilma hoje tv excelente direto cla...
# 104629           propaganda #dilma maravilhae conto fadas
#
# [101412 rows x 3 columns]

# %% [markdown]
# # Topic Modeling LatentDirichletAllocation

# %%
# %%time
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()

data_vectorized = vectorizer.fit_transform(df['content_clean'])

lda_model = LatentDirichletAllocation(n_components=11, learning_method='online', learning_offset=20, max_iter=10, random_state=42)

lda_vectors = lda_model.fit_transform(data_vectorized)
# Out:
# CPU times: user 4min 37s, sys: 198 ms, total: 4min 38s
# Wall time: 4min 39s

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

display_topics(lda_model, vectorizer.get_feature_names(), 15)
# Out:
# Topic 0:
# dilma gov coruptos vai pf crisenapf sera ate mundo estao gt ganhar dizer votar mentira
# Topic 1:
# dilma numero vamos turno dia ai ter ver ainda quero vitoria hoje votos primeiro politica
# Topic 2:
# dilma diz brasil nao marina programa bom bem vota aqui falar dilma13 debatenaglobo pro propostas
# Topic 3:
# fez dilma milhoes nacional sp pesoas eleitoral minas emprego estado agua favor maismedicos mg ano
# Topic 4:
# dilma pt aecio lula nao so psdb marina agora iso esa petrobras globo eleicoes2014 ja
# Topic 5:
# dilma povo pra brasil nao voto lula educacao melhor forapt foradilma sim saude nosa inflacao
# Topic 6:
# dilma governo copa brasil quer pesquisa sabe segundo todo vida casa vao medicos mostra poder
# Topic 7:
# dilma brasil pra padilha vez vou 13 continuar cara noso verdade deve cada ser trabalhadores
# Topic 8:
# veja cair dilma sobre nunca sempre video via vote afirma vem mal debatedaband noo jornal
# Topic 9:
# presos dilma debate pergunta copadascopas apos dois aeciocheiraderota coracao fose voa lugar parabens aeroporto desa
# Topic 10:
# dilma nao presidenta pais ser todos ja votar presidente ese novo pode eleicoes anos la

# %% [markdown]
# # Modelo LDA Gensim

# %%
e_sentences=[]
for sentences in df['content_clean']:
    e_sentences.append(sentences.split(' '))
        
e_sentences
# Out:
# [['boechat', 'diz', 'surpreso', 'solidez', 'campanha', '#dilma'],
#  ['permitame', 'compartilhar', 'pensamento', '#dilma', 'outra', 'vez'],
#  ['#dilma',
#   'compra',
#   'pesquisa',
#   'compra',
#   'copa',
#   'almenta',
#   'pasagem',
#   'onibus',
#   'vende',
#   'copa',
#   'almenta',
#   'pasagem',
#   'metro'],
#  ['alo',
#   'coxinha',
#   '#minhacasaminhavida',
#   '#dilma',
#   'investiu',
#   'oes',
#   'sp235',
#   'moradias',
#   'entregues',
#   'e592',
#   'contratadas',
#   'total',
#   'de827'],
#  ['hauahuahu', '#dilma', 'entao'],
#  ['desde',
#   'eleicao',
#   'bage',
#   'tomou',
#   'rumo',
#   'desenvolvimento',
#   '#tarso13',
#   '#dilma',
#   'baita',
#   'comicio'],
#  ['alo',
#   'coxinha',
#   '#cienciasemfronteiras',
#   '#dilma',
#   'concedeu',
#   'estudantes',
#   'sp9mil',
#   'bolsas',
#   'sendo6',
#   'mulheres2',
#   'negros',
#   'e7',
#   'jovens'],
#  ['alo',
#   'coxinha',
#   '#dilma',
#   'atraves',
#   '#fies',
#   'atendeu',
#   'mil',
#   'universitarios',
#   'desde',
#   '53',
#   'mulheres',
#   '36',
#   'negros',
#   '826',
#   'demais',
#   'jovens'],
#  ['avancos',
#   'alcancados',
#   'brasil',
#   'hoje',
#   'nao',
#   'frutos',
#   'acaso',
#   'governanca',
#   'voltada',
#   'pra',
#   'intereses',
#   'brasilvota',
#   '#dilma'],
#  ['alo',
#   'coxinha',
#   '#prouni',
#   '#dilma',
#   'concedeu',
#   'sp7mil',
#   'bolsas',
#   'universitarias',
#   '53',
#   'mulheres',
#   '409',
#   'negros',
#   '687',
#   'demais',
#   'jovens'],
#  ['marina',
#   'silva',
#   'mente',
#   'nao',
#   'propostas',
#   'agradam',
#   'intereses',
#   'povoseu',
#   'programa',
#   'puro',
#   'neoliberalismo',
#   'vota',
#   '#dilma'],
#  ['ibge',
#   'pnad',
#   'desconfio',
#   'algum',
#   'tecnico',
#   'aloprado',
#   'quis',
#   'prejudicar',
#   '#dilma'],
#  ['imprensa',
#   'investigar',
#   'sim',
#   '#dilma',
#   'qualquer',
#   'informacao',
#   'decore',
#   'investigacao',
#   'basico',
#   'elementar',
#   '#foradilma',
#   '#forapt'],
#  ['presao', '#dilma'],
#  ['alo',
#   'coxinha',
#   '#pronatec',
#   '#dilma',
#   'abriu',
#   'sp2',
#   'milhao',
#   'matriculas',
#   'municipios',
#   'mulheres',
#   'negros',
#   'e6',
#   'demais',
#   'jovens'],
#  ['#dilma', 'copa', 'pode', 'servir', 'exemplo', 'aviacao', 'regional'],
#  ['#dilma',
#   'pais',
#   'perto',
#   'universalizar',
#   'iluminacao6',
#   'domicilios',
#   'ja',
#   'contam',
#   'energia',
#   'eletrica'],
#  ['#dilma',
#   'teatro',
#   'castro',
#   'alves',
#   'bahia',
#   'tombado',
#   'patrimonio',
#   'cultural',
#   'brasileiro'],
#  ['entrevista',
#   '#dilma',
#   'record',
#   'querem',
#   'saber',
#   'pasteurizadotipo',
#   'so',
#   'cabecinha'],
#  ['alo',
#   'coxinha',
#   '#pronatec',
#   '#dilma',
#   'concedeu2',
#   'milhao',
#   'matriculas',
#   'municipios',
#   'sendo',
#   '52',
#   'mulheres',
#   '42',
#   'negros',
#   '626',
#   'jovens'],
#  ['#dilma',
#   'anuncia',
#   'regularizacao',
#   'mil',
#   'asentamentos',
#   'rurais',
#   'incra'],
#  ['imagina', 'estivese', 'lugar', '#dilma', 'ja', 'cometido', 'suicidio'],
#  ['sinto',
#   'dilma',
#   'melhor',
#   'artista',
#   'povo',
#   'brasileiro',
#   '#marina',
#   '#dilma',
#   '#atitudeparamudar',
#   '#brasilia',
#   '#fortaleza'],
#  ['espetaculo', 'crescimento', 'efeito', '#dilma', 'economia'],
#  ['#dilma', 'recebeu', 'hj', 'atletas', 'destacaram'],
#  ['caminhada', '#dilma', '#padilha', 'santo', 'amaro'],
#  ['marina',
#   'silvacandidata',
#   'banqueiros',
#   'itau',
#   'nao',
#   'povonao',
#   'deixe',
#   'enganarvota',
#   'conscientevota',
#   '#dilma'],
#  ['nao',
#   'vota',
#   'marina',
#   'silva',
#   'pro',
#   'brasil',
#   'permanecer',
#   'independente',
#   'sistema',
#   'financeiro',
#   'causou',
#   'atual',
#   'crise',
#   'economica',
#   'mundial',
#   'vota',
#   '#dilma'],
#  ['governo',
#   'mentirosos',
#   'basta',
#   'ver',
#   'campanha',
#   '#dilma',
#   'nao',
#   'honesta',
#   '#vaipracubapt',
#   '#foradilma',
#   '#abaixodecretodadilma'],
#  ['ciro',
#   'gomes',
#   'sobre',
#   'marina',
#   'silvae',
#   'vazio',
#   'absolutoaproveita',
#   'inocencia',
#   'juventude',
#   'mal',
#   'informada',
#   'pig',
#   'vote',
#   '#dilma'],
#  ['tacalhe', 'pau', '#dilma'],
#  ['alo',
#   'coxinha',
#   '#dilma',
#   'agraciou',
#   'sp',
#   'com187',
#   '#maismedicos',
#   'municipios',
#   '53',
#   'estado',
#   'beneficiando5',
#   'milhoes',
#   'pesoas',
#   'suica'],
#  ['nao',
#   'representa',
#   '#marina',
#   '#dilma',
#   '#marinadeverdade',
#   '#atitudeparamudar',
#   '#brasilia',
#   '#fortaleza',
#   '#bahia',
#   '#manaus',
#   '#salvador'],
#  ['alo',
#   'coxinha',
#   '#dilma',
#   'destinou',
#   'municipios',
#   'paulo563',
#   'equipamentos',
#   'retroescavadeiras',
#   'moto',
#   'niveladoras',
#   'caminhoes',
#   'cacamba'],
#  ['iso', 'ai', 'camarada', 'iso', 'nao', 'preco', '#dilma', 'vamos'],
#  ['certo',
#   '#dilma',
#   'ficar',
#   'dando',
#   'entrevistas',
#   'coletivas',
#   'perto',
#   'eleicoes'],
#  ['#dilma', 'falou', 'falado'],
#  ['alo',
#   'coxinha',
#   '#pac',
#   '#dilma',
#   'tambem',
#   'colocou',
#   'sp',
#   'aeroportos',
#   '7bi',
#   'rodovias',
#   'alem',
#   '#luzparatodos624',
#   'ligacoes',
#   'so'],
#  ['#dilma', 'novo'],
#  ['brasil', '#dilma', 'povo', 'povo'],
#  ['estudei',
#   'pasei',
#   'mereco',
#   'convocacao',
#   'nao',
#   'facil',
#   '#chamacaixaprovados2014',
#   '#dilma'],
#  ['alo',
#   'coxinha',
#   '#pac',
#   '#dilma',
#   'colocou',
#   '6bi',
#   'setor',
#   'petroleiro',
#   '7bi',
#   'mobilidade',
#   'urbana',
#   '3bi',
#   'transmisao',
#   'energia',
#   'eletrica',
#   'so'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['grandes',
#   'obras',
#   'mobilidade',
#   'urbana',
#   '#dilma',
#   'proporcionam',
#   'rapidez',
#   'seguranca',
#   'cariocas',
#   'sala',
#   'imprensa'],
#  ['acoes',
#   '#dilma',
#   'enfrentamento',
#   'seca',
#   'destaques',
#   'paraiba',
#   'sala',
#   'imprensa'],
#  ['amanha',
#   'levara',
#   'ese',
#   'material',
#   'candidatos',
#   'dilma',
#   'armando',
#   'joao',
#   'paulo',
#   '#dilma'],
#  ['governo',
#   '#dilma',
#   'quer',
#   'padrao',
#   'copa',
#   'seguranca',
#   'publica',
#   'todo',
#   'brasil',
#   'sala',
#   'imprensa'],
#  ['juventude', '#dilma'],
#  ['alo',
#   'coxinha',
#   '#dilma',
#   'investiu',
#   'paulo',
#   'cerca',
#   'oes',
#   'so',
#   'menina',
#   'olhos',
#   'tucanos',
#   'rodoanel',
#   'leste',
#   'bilhoes',
#   'bndes'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['nosa', 'presidenta', '#dilma', 'sendo', 'aclamada', 'povo'],
#  ['#dilma',
#   'rousef',
#   'faz',
#   'criticas',
#   'bolsistas',
#   'reprovados',
#   'ciencias',
#   'presidente',
#   'comenta',
#   'nota',
#   'universi'],
#  ['exatamente', 'presidenta', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['breser', 'pereira', 'explica', 'votara', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['marina',
#   'hein',
#   'ja',
#   'usou',
#   'discursos',
#   'chavoes',
#   'futebolisticos',
#   'agora',
#   'cinefilos',
#   '#dilma13denovo',
#   '#dilmaemalta',
#   '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['sente', 'coitadinho', 'nao', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['nao', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['nao', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['nao', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['nao', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['nao', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['nao', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['nao', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['nao', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['nao', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['nao', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['nao', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['nao', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['#dilma',
#   'deveria',
#   'ser',
#   'garota',
#   'propaganda',
#   'tse',
#   'perguntada',
#   'sobre',
#   'escandalo',
#   'petrobras',
#   'so',
#   'fica',
#   'bla',
#   'bla',
#   'bla',
#   'bla'],
#  ['nao', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['nao', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['#dilma',
#   'deveria',
#   'ser',
#   'garota',
#   'propaganda',
#   'tse',
#   'perguntada',
#   'sobre',
#   'escandalo',
#   'petrobras',
#   'so',
#   'fica',
#   'bla',
#   'bla',
#   'bla',
#   'bla',
#   'bla'],
#  ['#dilma',
#   'ganhar',
#   'esas',
#   'eleicoes',
#   'vai',
#   'ser',
#   'cima',
#   'muita',
#   'mentira',
#   'povo',
#   'brasileiro',
#   'sera',
#   'iludido',
#   'mundo',
#   '#foradilma',
#   '#forapt'],
#  ['iso', 'contigo', 'presidenta', '#dilma'],
#  ['novaodesa', '#dilma', 'muita', 'clase', 'muita', 'etica', '#dilmais'],
#  ['#pt',
#   'usou',
#   '#coreios',
#   'enviar',
#   'propagandas',
#   '#dilma',
#   'uso',
#   'maquina',
#   'publica',
#   'grave',
#   'crime',
#   'eleitoral',
#   '#ptnojento',
#   '#forapt'],
#  ['procurador',
#   'geral',
#   'republica',
#   'favor',
#   'direito',
#   'resposta',
#   '#dilma',
#   'horario',
#   'eleitoral'],
#  ['ate',
#   'marineiros',
#   'estao',
#   'abandonando',
#   '#marina',
#   'gt',
#   'somaria',
#   'ese',
#   'programa',
#   'governogt',
#   'gte',
#   '#dilmajs'],
#  ['#dilma', 'responderia', 'sobre', 'atraso'],
#  ['procurador',
#   'geral',
#   'republica',
#   'favor',
#   'direito',
#   'resposta',
#   '#dilma',
#   'horario',
#   'eleitoral'],
#  ['dilminha',
#   'fatura',
#   'logo',
#   'esa',
#   'releicao',
#   'gente',
#   'precisando',
#   'nosa',
#   'atencao',
#   'k',
#   '#dilma',
#   '#dilma13denovo'],
#  ['acreditar',
#   'ontem',
#   'ibge',
#   'divulgou',
#   'desigualdade',
#   'social',
#   'brasil',
#   'aumentou',
#   'hoje',
#   'voltou',
#   'tras',
#   '#dilma',
#   'mandou'],
#  ['karol', 'crf', '#dilma', 'moral', 'iso'],
#  ['novaodesa',
#   '#dilma',
#   'unica',
#   'cqc',
#   'conseguiu',
#   'chegar',
#   'perto',
#   'pra',
#   'zoar'],
#  ['hoje',
#   'dia',
#   'tirar',
#   'fotos',
#   'personagens',
#   'famosos',
#   'brasil',
#   '#pepapig',
#   '#dilma',
#   '#euprefiroapepacomopresidente'],
#  ['coisa',
#   'dar',
#   'braco',
#   'torcer',
#   '#pt',
#   'conseguiu',
#   'fazer',
#   'rejeicao',
#   '#marinasilva',
#   'explodir',
#   'asim',
#   'menor',
#   '#dilma'],
#  ['nao',
#   'funcao',
#   'imprensa',
#   'fazer',
#   'investigacao',
#   'afirma',
#   '#dilma',
#   'sobre',
#   'denuncias',
#   'veja',
#   '#portalimprensa'],
#  ['campanha',
#   '#marina',
#   'desidrata',
#   'igual',
#   'cantareira',
#   'enquanto',
#   '#dilma',
#   'sobe',
#   'jornal',
#   'coreio',
#   'brasil'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['#dilma', 'dispara', 'frente', '#marina'],
#  ['ja',
#   'caminho',
#   'certo',
#   'presidenta',
#   '#dilma',
#   'contigo',
#   'outra',
#   'vez',
#   'brasil',
#   'seguir',
#   'frente'],
#  ['segundo',
#   '#datafolha',
#   'brasileiro',
#   'acha',
#   'governo',
#   '#dilma',
#   'otimo',
#   'regular',
#   'aprova',
#   'governo',
#   'mudar',
#   'marina'],
#  ['iso', 'contigo', 'presidenta', '#dilma', 'aretada'],
#  ['uso',
#   'maquina',
#   'publica',
#   '#pt',
#   'propaganda',
#   '#dilma',
#   'iso',
#   'crime',
#   'eleitoral',
#   'grave',
#   'gente',
#   'absurdo'],
#  ['dona',
#   '#dilma',
#   'queira',
#   'receber',
#   'bonus',
#   'dizendo',
#   'pfe',
#   'iso',
#   'lembrese',
#   'pf',
#   'paga',
#   'brasileiros',
#   'pra',
#   'iso',
#   'ptcalada'],
#  ['descarado',
#   'uso',
#   'maquina',
#   'publica',
#   'campanha',
#   'eleitoral',
#   '#pt',
#   '#dilma'],
#  ['dona',
#   '#dilma',
#   'pense',
#   'bem',
#   'antes',
#   'falar',
#   'prc',
#   'tendo',
#   'trabalhado',
#   'govfhc',
#   'venda',
#   'pasadena',
#   'corupcoes',
#   'oreu',
#   'govptista',
#   'k'],
#  ['pouco',
#   'consigo',
#   'ver',
#   'horario',
#   'politico',
#   '#dilma',
#   'gt',
#   'radio',
#   'tv',
#   'gt',
#   'confeso',
#   'ainda',
#   'emociono',
#   'gt'],
#  ['dificil',
#   'alguem',
#   'tentar',
#   'derubar',
#   '#dilma',
#   'experiencia',
#   'vida',
#   'profisional',
#   'tremenda',
#   'alem',
#   'estupendo',
#   'auto',
#   'controle'],
#  ['institutos',
#   'pesquisas',
#   'comecarem',
#   'divulgar',
#   '#verdadeiras',
#   'pesquisas',
#   'presidenta',
#   '#dilma',
#   '#ganhara',
#   'nodeg',
#   'turno',
#   '#sei'],
#  ['soria',
#   'ultimo',
#   'ano',
#   '#dilma',
#   'so',
#   'depende',
#   '#brasilnaoevenezuela',
#   '#brasilnaoecuba',
#   '#forapt',
#   '#ptnuncamais'],
#  ['machismo',
#   'congreso',
#   '#dilma',
#   'coloca',
#   'muitos',
#   'homens',
#   'bolso',
#   'olhe',
#   'la',
#   'nao',
#   'todos'],
#  ['#vermeio', 'vermeio', '#caroceata', 'legal', '#dilma', 'campo', 'asfalto'],
#  ['ultima',
#   'agenda',
#   'noite',
#   'terminando',
#   'dia',
#   'luta',
#   '#crivela',
#   '#10',
#   '#governador',
#   '#dilma',
#   '#13...'],
#  ['besta',
#   'fubana',
#   'blog',
#   'archive',
#   'titanic',
#   'vermeioistrelado',
#   '#eleicoes2014',
#   '#pt',
#   '#marina',
#   '#dilma',
#   '#aecio'],
#  ['mau',
#   'caratismo',
#   '#dilma',
#   'cumpanheiros',
#   'algo',
#   'inimaginavel',
#   'esa',
#   'gente',
#   'causa',
#   'nojo',
#   'medo',
#   '#foracambadapt'],
#  ['pra', 'achar', 'mulher', '#dilma', 'procurar', 'agulha', 'palheiro'],
#  ['brasileiros', 'toda', 'parte', 'sabem', 'bom', 'brasil', '#dilma'],
#  ['rastro',
#   'incompetencia',
#   'lula',
#   'dilma',
#   'instalaram',
#   'caos',
#   'brasil',
#   'querem',
#   'ser',
#   'aplaudidos',
#   'iso',
#   '#dilma',
#   '#crise'],
#  ['#maismudancasmaisfuturo', '#dilma', 'releita', 'primeiro', 'turno'],
#  ['#eleicoes2014',
#   'consigo',
#   'entender',
#   '#vem',
#   '#p',
#   '#rua',
#   '#d#dilma',
#   'frente',
#   'enquanto',
#   '#quem',
#   '#votar',
#   '#dilma',
#   '#governo',
#   '#merece'],
#  ['revoltante', '#dilma'],
#  ['foto',
#   'sensacional',
#   'pesoas',
#   'ruas',
#   'alegria',
#   'ver',
#   'presidenta',
#   '#dilma',
#   'vamos',
#   'votar',
#   'novamente'],
#  ['verdade', '#dilma', 'subiu', 'pesquisas'],
#  ['vamos',
#   'divulgar',
#   'nome',
#   'maria',
#   'lucia',
#   'prandi',
#   'candidata',
#   'deputada',
#   'federal',
#   'santosp',
#   'numero',
#   'tambem',
#   '#dilma'],
#  ['juventude',
#   'brasileira',
#   'nao',
#   'informacao',
#   'coreta',
#   'coisas',
#   'boas',
#   'acontecem',
#   'nese',
#   'pais',
#   'gente',
#   'nao',
#   've',
#   'tv',
#   '#dilma'],
#  ['vamos',
#   'divulgar',
#   'nome',
#   'telma',
#   'souza',
#   'candidata',
#   'deputada',
#   'estadual',
#   'numero',
#   'ex',
#   'prefeita',
#   'santosp',
#   '#dilma'],
#  ['datafolha', 'dilma', 'vai', 'marina', 'cai', '#dilma', '#pt'],
#  ['osmarina',
#   'nao',
#   'aprende',
#   '#dilma',
#   'bate',
#   'defende',
#   'ministerio',
#   'esporte'],
#  ['facil', 'votar', 'clica', 'quero', 'ver', 'muitos', '13', '#dilma'],
#  ['dilma',
#   'diz',
#   'pedira',
#   'aceso',
#   'depoimento',
#   'exdiretor',
#   'petrobras',
#   '#dilma',
#   '#politica'],
#  ['presidenta',
#   '#dilma',
#   'rousef',
#   'recebeu',
#   'hoje',
#   'palacio',
#   'planalto',
#   'atletas',
#   'olimpicos',
#   'paralimpicos'],
#  ['presidente',
#   '#dilma',
#   'nao',
#   'merecer',
#   'nosa',
#   'confianca',
#   'confiamos',
#   'nele',
#   'decepsinou',
#   'iso',
#   'dilma',
#   'nao',
#   'dar'],
#  ['contentes', 'dilma', 'caminhar', 'paulo', '#dilma', 'novo', 'voto'],
#  ['aqui',
#   '#recife',
#   'vence',
#   '#dilma',
#   'nao',
#   'gostamos',
#   'pesoa',
#   'oportunizando',
#   'situacao',
#   'comocao'],
#  ['nunca', 'sei', 'fato', 'pensa', 'diz', '#dilma', 'sobre', '#marina'],
#  ['sempre', 'cabe', 'urnas', 'vote', '#dilma'],
#  ["'papel",
#   'imprensa',
#   'nao',
#   'investigar',
#   'sim',
#   'divulgar',
#   "informacoes'",
#   'diz',
#   'poste',
#   'lider',
#   'suprema',
#   '#dilma',
#   '#vaidemais'],
#  ['onde',
#   'paso',
#   'conversa',
#   'sobre',
#   'eleicao',
#   'respondo',
#   'imediato',
#   'voto',
#   '#dilma',
#   'todos',
#   'torcem',
#   'alegria'],
#  ['amigos',
#   'diseram',
#   'proximo',
#   'governo',
#   '#dilma',
#   'vai',
#   'privilegiar',
#   'midias',
#   'virtuais',
#   'jornalismo',
#   'independente',
#   'penso',
#   'sera',
#   'bom'],
#  ['vamos', '#dilma', 'pracas', 'parques', 'praias'],
#  ['vamos', '#dilma', 'pracas', 'parques', 'praias'],
#  ['vamos', '#dilma', 'pracas', 'parques', 'praias'],
#  ['vamos', '#dilma', 'pracas', 'parques', 'praias'],
#  ['vamos', '#dilma', 'pracas', 'parques', 'praias'],
#  ['#juventude', 'fica', 'alegria', '#dilma', 'caminha', 'ruas', '#dilma2014'],
#  ['#dilma',
#   'rousef',
#   'recebe',
#   'brasilia',
#   'atletas',
#   'destacaram',
#   'tera',
#   'brasil'],
#  ['conhecendo',
#   'verdade',
#   'baixe',
#   'relatorio',
#   'conquistas',
#   'brasil',
#   '#dilma'],
#  ['#agita13',
#   'baixada',
#   'santista',
#   'arthur',
#   'chioro',
#   '#dilma',
#   '#padilha',
#   '#suplicy'],
#  ['votar',
#   '#dilma',
#   'presidente',
#   'defender',
#   'gara',
#   'coragem',
#   'crescimento',
#   'clase',
#   'trabalhadora',
#   'cart',
#   'asinada'],
#  ['#dilma',
#   'recebe',
#   'atletas',
#   'olimpicos',
#   'paralimpicos',
#   'palacio',
#   'planalto',
#   'jornal',
#   'brasil'],
#  ['#dilma', 'toda', 'mudanca', 'so', 'comeco'],
#  ['#dilma', 'toda', 'mudanca', 'so', 'comeco'],
#  ['#dilma', 'toda', 'mudanca', 'so', 'comeco'],
#  ['#dilma', 'toda', 'mudanca', 'so', 'comeco'],
#  ['#dilma', 'toda', 'mudanca', 'so', 'comeco'],
#  ['#dilma',
#   'mulher',
#   'fibra',
#   'gestora',
#   'incontestavel',
#   'mae',
#   '#pac',
#   'enfrenta',
#   'dia',
#   'dia',
#   'milhares',
#   'covardes',
#   '#pig',
#   'escondem',
#   'atras',
#   'jornais'],
#  ['preocupada',
#   'presidente',
#   '#dilma',
#   'vai',
#   'pedir',
#   '#stf',
#   'aceso',
#   'depoimento',
#   'exdiretor',
#   '#petrobras',
#   'pf'],
#  ['presidente',
#   '#dilma',
#   'vai',
#   'pedir',
#   '#stf',
#   'aceso',
#   'depoimento',
#   'exdiretor',
#   '#petrobras',
#   'paulo',
#   'roberto',
#   'costa',
#   'policia',
#   'federal'],
#  ['#padilha', '#13', '#dilma', 'brasil', 'continuar', 'crescendo'],
#  ['fantasmas',
#   'gafanhotos',
#   'voltam',
#   'asombrar',
#   'releicao',
#   'beto',
#   'richa',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#globo',
#   '#jn'],
#  ['viralizam',
#   'fotos',
#   'aa',
#   'dama',
#   'fernanda',
#   'richa',
#   'jantar',
#   'suspenso',
#   'blitz',
#   'tre',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#globo',
#   '#jn'],
#  ['dilma',
#   'diz',
#   'caso',
#   'coreios',
#   'factoide',
#   'campanha',
#   'saiba',
#   '#dilma',
#   '#coreios'],
#  ['mentem',
#   'descaradamente',
#   '#juventude',
#   'precisa',
#   'saber',
#   'pais',
#   'governado',
#   'pe',
#   'pres',
#   '#dilma',
#   'rede',
#   'globo',
#   'nao',
#   'divulga'],
#  ['#dilma',
#   'diz',
#   'especulacao',
#   'limite',
#   'ridiculo',
#   'asociar',
#   'reuters',
#   'brasil'],
#  ['so',
#   'obras',
#   'eixo',
#   'energia',
#   'pac',
#   'concluidas',
#   'cade',
#   'mae',
#   'pac',
#   '#dilma'],
#  ['cut', 'proposta', '#dilma', 'emprego', 'renda', 'outros', 'desemprego'],
#  ['cut', 'proposta', '#dilma', 'emprego', 'renda', 'outros', 'desemprego'],
#  ['cut', 'proposta', '#dilma', 'emprego', 'renda', 'outros', 'desemprego'],
#  ['cut', 'proposta', '#dilma', 'emprego', 'renda', 'outros', 'desemprego'],
#  ['cut', 'proposta', '#dilma', 'emprego', 'renda', 'outros', 'desemprego'],
#  ['#dilma',
#   'influencia',
#   'pesquisa',
#   'eleitoral',
#   '#bolsa',
#   'ridicula',
#   'gt',
#   'entende',
#   '#nada',
#   'economia',
#   'logo',
#   've'],
#  ['#dilma',
#   'diz',
#   'alguns',
#   'estudantes',
#   'desmerecem',
#   'pais',
#   'dilma',
#   'rousef',
#   'afirmou',
#   'nesta',
#   'sextafeira',
#   '19',
#   'durante',
#   'co'],
#  ['toda',
#   'vida',
#   'frente',
#   'hermano',
#   'quer',
#   'falem',
#   'jamais',
#   'parecera',
#   'viva',
#   'chavez',
#   'viva',
#   '#dilma',
#   'viva',
#   '#lula'],
#  ['#dilma',
#   'politicas',
#   'incentivo',
#   'preparam',
#   'atletas',
#   'brasileiros',
#   'olimpiadas',
#   'sala',
#   'imprensa'],
#  ['juventude',
#   'comeca',
#   'espertar',
#   'pleito',
#   'pasado',
#   'anos',
#   'tirou',
#   'titulo',
#   'pra',
#   'votar',
#   '#dilma'],
#  ['amanha',
#   '#dilma',
#   'participa',
#   'caminhada',
#   'paulo',
#   'santo',
#   'amaro',
#   'sala',
#   'imprensa'],
#  ['hoje', 'ato', '#dilma', 'baixada', 'fluminense'],
#  ['#dilma',
#   'estratosferainalcancaveluns',
#   'pontos',
#   'acima',
#   'damelhor',
#   'performance',
#   'pesquisasnosvestidos',
#   'vermelho',
#   'paixaolt3valente'],
#  ['dilma',
#   'diz',
#   'caso',
#   'coreios',
#   'factoide',
#   'campanha',
#   '#dilma',
#   '#politica',
#   '#hojemdia'],
#  ['deolho',
#   'nao',
#   'voto',
#   '#dilma',
#   '#eleicao2014',
#   '#brasil',
#   'pt',
#   '#eleicoes2014'],
#  ['#dilma',
#   'certa',
#   'nao',
#   'invisto',
#   'bovespa',
#   'meio',
#   'rico',
#   'especulador',
#   'manter',
#   'luxo',
#   'dinheiro',
#   'trabalhador'],
#  ['feldman',
#   'diz',
#   '#dilma',
#   'votos',
#   'dependencia',
#   'verdadedependentes',
#   'moradiasaudeducacaoculturaempregosdignidade',
#   'cidada'],
#  ['sim',
#   '#dilma',
#   'tambem',
#   'lula',
#   'subjacente',
#   'tudo',
#   'projeto',
#   'social',
#   'sintetizado',
#   'discurso',
#   'pose',
#   '#lula',
#   'jan'],
#  ['#dilma',
#   'pedira',
#   '#stf',
#   'aceso',
#   '#depoimento',
#   '#delator',
#   'gt',
#   '#medo',
#   'obvio',
#   '#stf',
#   'vai',
#   '#conceder'],
#  ['boa',
#   'noticia',
#   'pra',
#   '#dilma',
#   'nao',
#   'elevar',
#   'juros',
#   'fed',
#   'frustra',
#   'oposicao',
#   'tupiniquim',
#   'catastrofista'],
#  ['#dilma', 'obrigado', 'trem', 'bala'],
#  ['tanto',
#   'calor',
#   'vou',
#   'banhar',
#   'igarape',
#   'sabonete',
#   'biodegradavel',
#   'pra',
#   'ser',
#   'sustentavel',
#   'opinioes',
#   '#eleicoes2014',
#   '#dilma',
#   '#aecio'],
#  ['vou',
#   'soltar',
#   'coque',
#   'menos',
#   'cabelo',
#   'armado',
#   'proteje',
#   'queda',
#   '#perdendomaispontosqueogoias',
#   '#eleicoes2014',
#   '#marinasilva',
#   '#dilma',
#   '#aecio'],
#  ['#dilma',
#   'quer',
#   'saber',
#   'alista',
#   'petrolao#',
#   'siga',
#   'tweter',
#   'todo',
#   'brasil',
#   'ja',
#   'sabe'],
#  ['presidente',
#   'comite',
#   'paralimpico',
#   'brasileiro',
#   'defende',
#   'releicao',
#   'dilma',
#   '#dilma',
#   '#politica'],
#  ['#dilma',
#   'pedira',
#   'stf',
#   'aceso',
#   'depoimento',
#   'paulo',
#   'roberto',
#   'costa',
#   'jornal',
#   'brasil'],
#  ['toda',
#   'conquista',
#   'novo',
#   'comeco',
#   '"toda',
#   'conquista',
#   'novo',
#   'comeco"',
#   'diz',
#   '#dilma',
#   'record',
#   'dise',
#   'presidenta',
#   'dilma'],
#  ['toda',
#   'conquista',
#   'novo',
#   'comeco',
#   '"toda',
#   'conquista',
#   'novo',
#   'comeco"',
#   'diz',
#   '#dilma',
#   'record',
#   'dise',
#   'presidenta',
#   'dilma'],
#  ['toda',
#   'conquista',
#   'novo',
#   'comeco',
#   '"toda',
#   'conquista',
#   'novo',
#   'comeco"',
#   'diz',
#   '#dilma',
#   'record',
#   'dise',
#   'presidenta',
#   'dilma'],
#  ['toda',
#   'conquista',
#   'novo',
#   'comeco',
#   '"toda',
#   'conquista',
#   'novo',
#   'comeco"',
#   'diz',
#   '#dilma',
#   'record',
#   'dise',
#   'presidenta',
#   'dilma'],
#  ['toda',
#   'conquista',
#   'novo',
#   'comeco',
#   '"toda',
#   'conquista',
#   'novo',
#   'comeco"',
#   'diz',
#   '#dilma',
#   'record',
#   'dise',
#   'presidenta',
#   'dilma'],
#  ['toda',
#   'conquista',
#   'novo',
#   'comeco',
#   '"toda',
#   'conquista',
#   'novo',
#   'comeco"',
#   'diz',
#   '#dilma',
#   'record',
#   'dise',
#   'presidenta',
#   'dilma'],
#  ['toda',
#   'conquista',
#   'novo',
#   'comeco',
#   '"toda',
#   'conquista',
#   'novo',
#   'comeco"',
#   'diz',
#   '#dilma',
#   'record',
#   'dise',
#   'presidenta',
#   'dilma'],
#  ['#dilma',
#   'fundos',
#   'pensao',
#   'vao',
#   'cair',
#   'nesa',
#   'ceo',
#   'odebrecht',
#   'ambiental',
#   'diz',
#   'empresa',
#   'planeja',
#   'ipo'],
#  ['#dilma',
#   'ese',
#   'lixo',
#   'pt',
#   'podem',
#   'ate',
#   'chegar',
#   'ganhar',
#   'eleicao',
#   'nao',
#   'sera',
#   'voto'],
#  ['adorei', 'entrevista', 'rede', 'record', '#dilma'],
#  ['vamos', 'deixar', '#dilma', 'onde', '#dilma', 'novo'],
#  ['#juventude',
#   'precisa',
#   'saber',
#   'pais',
#   'governado',
#   'presidenta',
#   '#dilma',
#   'rede',
#   'globo',
#   'nao',
#   'divulga'],
#  ['olha', '#dilma', 'treinando', 'danca', 'break', 'juventude', 'adorou'],
#  ['presidenta', 'pluralidade', 'cultural', '#dilma'],
#  ['grande',
#   'noticia',
#   'politicas',
#   'sociais',
#   'vitoriosas',
#   'governos',
#   '#lula',
#   '#dilma',
#   'brasil',
#   'destacou',
#   'combate'],
#  ['deixem', 'mulher', '#dilma', 'trabalhar'],
#  ['#dilma',
#   '#minhacasamelhor',
#   'credito',
#   'facilitado',
#   'compra',
#   'moveis',
#   'eletrodomesticos',
#   'injeta',
#   'bilhoes',
#   'economia'],
#  ['sempre',
#   'somando',
#   'apoios',
#   '#dilma',
#   'agora',
#   'leonardo',
#   'bof',
#   'bem',
#   'vindo',
#   'abraco'],
#  ['#dilma',
#   'conhece',
#   '#minhacasaminhavida',
#   'rural',
#   'ja',
#   'entregues',
#   'mil',
#   'casas',
#   'campo',
#   'sera',
#   'ampliado'],
#  ['metade', 'mim', 'vota', '#dilma', 'outra', 'metade', 'tambem'],
#  ['#dilma',
#   '#minhacasaminhavida',
#   'ja',
#   'garante',
#   'moradia',
#   'digna',
#   'a8',
#   'milhoes',
#   'brasileiros',
#   'sera',
#   'ampliado'],
#  ['sobretudo',
#   'usaram',
#   '#dilma',
#   'simbolo',
#   'demonstrando',
#   'anelo',
#   'autodeterminacao',
#   'articulado',
#   'clamor',
#   'prol',
#   'multipolarizacao'],
#  ['brasil',
#   'gracas',
#   'lula',
#   'dilma',
#   'paises',
#   'saiu',
#   'mapa',
#   'fome',
#   'pense',
#   'nisto',
#   '#dilma13denovo',
#   '#dilma13',
#   '#dilma',
#   '#dilmapresidente'],
#  ['#dilma',
#   'cresce',
#   'numero',
#   'emprendedores',
#   'formais',
#   'brasil',
#   'aponta',
#   'pnad',
#   'sala',
#   'imprensa'],
#  ['#dilma',
#   '#marina',
#   'empatadas',
#   '#datafolha',
#   'faz',
#   'sentido',
#   'iguais',
#   '#aeciodevirada'],
#  ['artistas',
#   'apoiando',
#   '#dilma',
#   'vamos',
#   'divulgar',
#   'amigos',
#   '#dilma2014'],
#  ['#dilma',
#   'ridiculo',
#   'ligar',
#   'queda',
#   'bolsa',
#   'pesquisas',
#   'eleitorais',
#   'gt',
#   '#jesus',
#   'pode',
#   'ser',
#   'despreparada'],
#  ['ei', 'ai', 'preste', 'bem', 'atencao', '#dilma', 'novo'],
#  ['#acordem',
#   'gnt',
#   'bura',
#   'pretende',
#   'votar',
#   '#dilma',
#   '#marina',
#   'gt',
#   'agora',
#   'oficial',
#   'argentina',
#   'ja',
#   'sob',
#   'regime',
#   'socialista'],
#  ['vamos',
#   '#mulheres',
#   'catar',
#   'votos',
#   'igualmente',
#   'catamos',
#   'flores',
#   'vamos',
#   'somar',
#   'votos',
#   '#dilma',
#   'divulguem',
#   'pra',
#   'juventude'],
#  ['rejeicao',
#   'marina',
#   'silva',
#   'cresce',
#   'medida',
#   'povo',
#   'vai',
#   'descobrindo',
#   'propostas',
#   'contradicoes',
#   'vote',
#   'consciente',
#   'nao',
#   'emocao',
#   '#dilma'],
#  ['boa',
#   'tarde',
#   '#vergonha',
#   'dese',
#   'pais',
#   '#coreios',
#   'abrem',
#   '#excecao',
#   '#pt',
#   '#dilma',
#   'presidente',
#   '#usodamaquina'],
#  ['online', 'pois', 'veio', 'dar', 'dedo', '#dilma'],
#  ['#lula',
#   '#dilma',
#   'realizaram',
#   'sonho',
#   'betinho',
#   'nao',
#   'pode',
#   'realizar',
#   'pao',
#   'pra',
#   'qm',
#   'tm',
#   'fome',
#   'sede',
#   'justica'],
#  ['boa',
#   'tarde',
#   'angela',
#   'portela',
#   'candidata',
#   'governo',
#   'roraima',
#   'apoia',
#   '#dilma'],
#  ['pesquisa',
#   'datafolha',
#   'dilma',
#   'marina',
#   'aecio',
#   'eliminado',
#   '#eleicoes2014',
#   '#dilma',
#   '#marinasilva',
#   '#aecio'],
#  ['so',
#   'chorar',
#   'pra',
#   '#dilma',
#   'manda',
#   'faltam',
#   'implantes',
#   'mamarios',
#   'silicone',
#   '#venezuela',
#   'mulheres',
#   'estao',
#   'panico'],
#  ['conspiracao', 'total', '#dilma'],
#  ['apenas',
#   'programa',
#   'governo',
#   'petista',
#   '#dilma',
#   'mantido',
#   'compromiso',
#   'clase',
#   'trabalhadora'],
#  ['qualidade',
#   'vida',
#   'brasileiros',
#   'avancou',
#   'quase',
#   'todos',
#   'setores',
#   'apo',
#   '#dilma'],
#  ['so', 'lembrar', '#aecio', '#psdb', '#dilma13denovo', '#dilma'],
#  ['#ptebola',
#   'carteiros',
#   'denunciam',
#   '#dilma',
#   'usa',
#   'coreios',
#   'cometer',
#   'crime',
#   'eleitoral'],
#  ['garota',
#   'dise',
#   'camera',
#   'pronta',
#   'fotografar',
#   '#dilma',
#   'enviar',
#   'fotos'],
#  ['centro',
#   'todas',
#   'questoes',
#   'proximo',
#   'governo',
#   'sera',
#   'educacao',
#   'diz',
#   '#dilma'],
#  ['so',
#   'lembrar',
#   '#marinacensuradia2',
#   '#marinacensura',
#   '#dilma13denovo',
#   '#dilma'],
#  ['todo',
#   'mundo',
#   'apenas',
#   'paises',
#   'estao',
#   'mapa',
#   'fome',
#   'brasil',
#   '#dilma'],
#  ['brasil', 'maior', 'rede', 'protecao', 'social', 'mundo', '#dilma'],
#  ['discurso',
#   'pratica',
#   '#marinacensuradia2',
#   '#dilma13denovo',
#   '#dilma',
#   '#marinacensura'],
#  ['brasil',
#   'hoje',
#   'primeira',
#   'geracao',
#   'criancas',
#   'nascendo',
#   'crescendo',
#   'livre',
#   'miseria',
#   'fome',
#   '#dilma'],
#  ['nao',
#   'quero',
#   'entender',
#   'marina',
#   'levaria',
#   'tempo',
#   'eou',
#   'talvez',
#   'imposivel',
#   'quero',
#   'sempre',
#   'ir',
#   'vida',
#   'clarividencia',
#   'vou',
#   '#dilma'],
#  ['nao', 'ero', 'urnas', 'escolha', '#dilma', 'novo'],
#  ['muita',
#   'gente',
#   'contra',
#   '#dilma',
#   'emprego',
#   'facilidades',
#   'muita',
#   'gente',
#   'favor',
#   '#dilma',
#   'ctps',
#   'filhos',
#   'faculdadetc'],
#  ['aqui',
#   'mulheres',
#   'mandam',
#   'mandem',
#   'candidatas',
#   'apoiam',
#   '#dilma',
#   'divulgaremos',
#   '#dilma2014'],
#  ['presidente',
#   'lula',
#   'colocou',
#   'fome',
#   'miseria',
#   'agenda',
#   'politica',
#   'brasil',
#   '#dilma'],
#  ['#dilma', 'espalhada', 'todo', 'brasil', 'nosa', 'guereira', 'viva', '13'],
#  ['boa', 'tarde', 'aqui', 'emplastadas', '#dilma'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['escandalo',
#   'envolvendo',
#   '#dilma',
#   'corja',
#   '#pt',
#   'nao',
#   'nenhum',
#   'respeito',
#   'brasil',
#   'nosas',
#   'instituicoes',
#   'noso',
#   'povo'],
#  ['vamos', 'asim', '#dilma', 'nosa', 'presidenta', '#dilma2014'],
#  ['boa',
#   'tarde',
#   'vamos',
#   'aguardar',
#   'ver',
#   'percentual',
#   'aceitacao',
#   '#dilma',
#   'eleitores'],
#  ['queroajudar',
#   'gestao',
#   'petista',
#   '#dilma',
#   'nao',
#   'ha',
#   'engavetador',
#   'procesos',
#   'contra',
#   'politicos'],
#  ['proposta', '#dilma', 'emprego', 'renda', 'outros', 'desemprego'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina'],
#  ['vamos',
#   '#dilma',
#   'pracas',
#   'parques',
#   'praias',
#   'neste',
#   'final',
#   'semana'],
#  ['vamos',
#   '#dilma',
#   'pracas',
#   'parques',
#   'praias',
#   'neste',
#   'final',
#   'semana'],
#  ['vamos',
#   '#dilma',
#   'pracas',
#   'parques',
#   'praias',
#   'neste',
#   'final',
#   'semana'],
#  ['vamos',
#   '#dilma',
#   'pracas',
#   'parques',
#   'praias',
#   'neste',
#   'final',
#   'semana'],
#  ['vamos',
#   '#dilma',
#   'pracas',
#   'parques',
#   'praias',
#   'neste',
#   'final',
#   'semana'],
#  ['#eunicio',
#   '#marina',
#   '#dilma',
#   '#capwagner',
#   '#lulamorais',
#   '#cabosabino',
#   '#chicolopes',
#   '#luiziane',
#   'votos',
#   'familia',
#   'democracia',
#   'respeito',
#   'todos'],
#  ['#dilma',
#   'abre',
#   'vantagem',
#   'sobre',
#   '#marina',
#   'aecio',
#   'esboca',
#   'reacao'],
#  ['daqui',
#   'pouco',
#   '#dilma',
#   'fala',
#   'imprensa',
#   'entrevista',
#   'coletiva',
#   'sala',
#   'imprensa'],
#  ['#bomba',
#   'eduardo',
#   'campos',
#   'acusa',
#   '#dilma',
#   'fazer',
#   'terorismo',
#   'bolsa',
#   'familia'],
#  ['#bomba',
#   'eduardo',
#   'campos',
#   'acusa',
#   '#dilma',
#   'fazer',
#   'terorismo',
#   'bolsa',
#   'familia'],
#  ['#bomba',
#   'eduardo',
#   'campos',
#   'acusa',
#   '#dilma',
#   'fazer',
#   'terorismo',
#   'bolsa',
#   'familia'],
#  ['fose',
#   'epoca',
#   'fhc',
#   'pobre',
#   'estaria',
#   'chupando',
#   'oso',
#   'galinhadale',
#   '#dilma',
#   'agora',
#   'comem',
#   'carne',
#   'boa'],
#  ['#dilma',
#   'releita',
#   'garantia',
#   'manutencao',
#   'direitos',
#   'sociais',
#   'trabalhistas'],
#  ['#trackings', 'apontam', '#dilma', 'minimo', '#aecio', 'turno'],
#  ['seguranca', 'frei', 'beto', 'vota', '#dilma', 'presidencia'],
#  ['seguranca', 'frei', 'beto', 'vota', '#dilma', 'presidencia'],
#  ['lula',
#   'inspirado',
#   'dilma',
#   'didatica',
#   'artistas',
#   'dilma',
#   '#dilma',
#   '#pt',
#   '#lula'],
#  ['seguranca', 'frei', 'beto', 'vota', '#dilma', 'presidencia'],
#  ['seguranca', 'frei', 'beto', 'vota', '#dilma', 'presidencia'],
#  ['seguranca', 'frei', 'beto', 'vota', '#dilma', 'presidencia'],
#  ['#dilma',
#   'releita',
#   'garantia',
#   'manutencao',
#   'direitos',
#   'sociais',
#   'trabalhistas'],
#  ['#petrobras',
#   'paulo',
#   'roberto',
#   'nomeado',
#   'pfhc#psdb',
#   'pcargos',
#   'so',
#   'descoberto',
#   'gov',
#   '#dilma',
#   'indignacao',
#   '#aecio',
#   'meramente',
#   '#politica'],
#  ['excelente',
#   'programa',
#   'eleitoral',
#   'dilma',
#   'setembro',
#   '#dilma',
#   '#pt',
#   '#lula'],
#  ['datafolha',
#   'dilma',
#   'marina',
#   '#aecio',
#   'segundo',
#   'pesquisa',
#   'datafolha',
#   '#dilma',
#   '#marina',
#   'continuam'],
#  ['#dilma',
#   'recebe',
#   'voto',
#   'frei',
#   'beto',
#   'luta',
#   'contra',
#   'escravidao',
#   'brasil'],
#  ['marina',
#   'cabo',
#   'eleitoral',
#   'voluntario',
#   'governo',
#   'dilma',
#   'nao',
#   'desesperado',
#   'grato',
#   'beraldo',
#   '#dilma'],
#  ['#alo',
#   '#dilma',
#   '#producao',
#   '#industrial',
#   'volta',
#   '#cair',
#   'setor',
#   'fala',
#   '#demitir',
#   '#recesao',
#   '#copae',
#   'agora',
#   '#dilma',
#   '#forapt'],
#  ['#dilma', 'brasil', 'reduz', 'indice', 'desnutridos', 'para7', 'populacao'],
#  ['#dilma', 'rebate', 'diz', 'jamais', 'tocara', 'ba', 'clt'],
#  ['eis',
#   'candidata',
#   'deputada',
#   'federal',
#   'numero',
#   'nao',
#   '#dilma',
#   'continua',
#   'planalto'],
#  ['nasif', 'declara', 'apoio', 'releicao', '#dilma'],
#  ['#dilma',
#   'creches',
#   'publicas',
#   'recebem',
#   'hoje',
#   'investimentos',
#   'novas',
#   'vagas'],
#  ['#dilma', 'cresce', 'numero', 'criancas', 'anos', 'escola'],
#  ['#dilma', 'trabalho', 'infantil', 'registra', 'menor', 'taxa', 'historia'],
#  ['#dilma', 'envia', 'mi', 'rede', 'publica', 'sc', 'pr', 'area', 'saude'],
#  ['jornal', 'record', 'r7', 'entrevistou', '#dilma', 'rousef', 'pt'],
#  ['#lula',
#   '#dilma',
#   '#coracoesvalentes',
#   'lutam',
#   'gente',
#   'dainos',
#   'forcas',
#   'bem'],
#  ['mulheres',
#   'estao',
#   'corendo',
#   'contra',
#   'tempo',
#   'hora',
#   'dizer',
#   'nao',
#   'ha',
#   'duvida',
#   '#dilma',
#   'novo'],
#  ['observem',
#   'tendencia',
#   '#dilma',
#   'subindo',
#   '#aecio',
#   'recuperando',
#   '#marina',
#   'indo',
#   'procurar',
#   'caminhao',
#   'onde',
#   'caiu'],
#  ['jornal', 'record', 'r7', 'entrevistou', '#dilma', 'rousef', 'pt'],
#  ['jornal', 'record', 'r7', 'entrevistou', '#dilma', 'rousef', 'pt'],
#  ['jornal', 'record', 'r7', 'entrevistou', '#dilma', 'rousef', 'pt'],
#  ['jornal', 'record', 'r7', 'entrevistou', '#dilma', 'rousef', 'pt'],
#  ['jornal', 'record', 'r7', 'entrevistou', '#dilma', 'rousef', 'pt'],
#  ['nasif', 'declara', 'apoio', 'releicao', '#dilma'],
#  ['nasif', 'declara', 'apoio', 'releicao', '#dilma'],
#  ['nasif', 'declara', 'apoio', 'releicao', '#dilma'],
#  ['nasif', 'declara', 'apoio', 'releicao', '#dilma'],
#  ['nasif', 'declara', 'apoio', 'releicao', '#dilma'],
#  ['#dilma', 've', 'aspectos', 'positivos', 'pnad'],
#  ['#dilma', '"toda', 'mudanca', 'so', 'comeco"'],
#  ['mulheres', 'agitam', '#dilma', 'outra', 'vez'],
#  ['#eleicoes2014',
#   '#dilma',
#   '#marina',
#   '#aecio',
#   'estrategia',
#   'tirar',
#   'votos',
#   'marina',
#   'funcionando',
#   'dilma',
#   'dificil'],
#  ['#ceara',
#   'candidata',
#   'deputada',
#   'estadual',
#   'ex',
#   'prefeita',
#   'numero',
#   'apoia',
#   '#dilma',
#   'vez'],
#  ['#fgts',
#   '#dilma',
#   '#marina',
#   'dilma',
#   'rebate',
#   'marina',
#   'diz',
#   'jamais',
#   'tocara',
#   'clt',
#   'confira'],
#  ['#ceara',
#   'candiadata',
#   'deputada',
#   'federal',
#   'ex',
#   'prefeita',
#   'fortaleza',
#   'numero',
#   'vai',
#   'tambem',
#   '#dilma'],
#  ['nacamara',
#   'antes',
#   '#dilma',
#   'bastou',
#   'campos',
#   'morer',
#   'marina',
#   'subir',
#   'pesquisas',
#   'ratos',
#   'socialistas',
#   'seguirem'],
#  ['bom',
#   'dia',
#   'anafonso',
#   'rio',
#   'grande',
#   'sul',
#   'tambem',
#   '#dilma',
#   'bem',
#   'vinda'],
#  ['#dilma',
#   'trajetoria',
#   'povo',
#   'rumo',
#   'direitos',
#   'cidadaos',
#   'dignidade',
#   'trabalho',
#   'saude',
#   'educacao',
#   'arte'],
#  ['#dilma', 'rebate', 'diz', 'jamais', 'tocara', 'ba', 'clt'],
#  ['#dilma', 'rebate', 'diz', 'jamais', 'tocara', 'ba', 'clt'],
#  ['#dilma', 'rebate', 'diz', 'jamais', 'tocara', 'ba', 'clt'],
#  ['#dilma', 'rebate', 'diz', 'jamais', 'tocara', 'ba', 'clt'],
#  ['#dilma', 'rebate', 'diz', 'jamais', 'tocara', 'ba', 'clt'],
#  ['maioria',
#   'eleicao',
#   'soma',
#   'voto',
#   'mulheres',
#   'superam',
#   'homens',
#   'vamos',
#   'mulheres',
#   'vamos',
#   'catar',
#   'voto',
#   'voto',
#   '#dilma'],
#  ['#mulheres', 'unidas', 'jamais', 'serao', 'vencidas', 'vamos', '#dilma'],
#  ['#dilma', 'ganha', 'facil', 'aecio', 'never'],
#  ['tearaujo',
#   'dilma',
#   'querida',
#   'amada',
#   'onde',
#   'pasa',
#   'only',
#   'love',
#   '#dilma'],
#  ['vejo',
#   'aqui',
#   'redes',
#   'sociais',
#   'apoio',
#   'chegando',
#   '#dilma',
#   'todos',
#   'rincoes',
#   'pais',
#   'viva',
#   'viva',
#   'estrela',
#   'maior',
#   '#dilma'],
#  ['#dilma', 'toda', 'mudanca', 'so', 'comeco'],
#  ['#dilma', 'toda', 'mudanca', 'so', 'comeco'],
#  ['#dilma', 'toda', 'mudanca', 'so', 'comeco'],
#  ['#dilma', 'toda', 'mudanca', 'so', 'comeco'],
#  ['#dilma', 'toda', 'mudanca', 'so', 'comeco'],
#  ['onu',
#   'so',
#   'paises',
#   'estao',
#   'mapa',
#   'fome',
#   'agora',
#   'brasil',
#   '#lula',
#   '#dilma',
#   'so',
#   'pode',
#   'estar',
#   'abaixo',
#   'linha',
#   'pobrezano',
#   'br',
#   'so'],
#  ['apoios',
#   'presidenta',
#   '#dilma',
#   'infinitos',
#   'noso',
#   'luis',
#   'verisimo',
#   'merece',
#   'abraco',
#   'todas',
#   'brasileiras'],
#  ['#dilma',
#   'nao',
#   'deixe',
#   'enganar',
#   'resultados',
#   'pnad',
#   'apontam',
#   'brasil',
#   'cada',
#   'vez',
#   'inclusivo'],
#  ['olhem', '#dilma', 'acolhida', 'ruas', '#dilma2014'],
#  ['ai',
#   'penso',
#   'nova',
#   'pesquisa',
#   'aponta',
#   '#dilma',
#   '#marina',
#   'segundo',
#   'turno',
#   'eleitores',
#   '#aecio',
#   'nao',
#   'vota',
#   'dilma',
#   'ja',
#   'marina'],
#  ['juventude', 'tambem', '#dilma'],
#  ['vamos',
#   'ver',
#   'imagem',
#   'relembrar',
#   'valeu',
#   'pena',
#   'ter',
#   'escolhido',
#   '#dilma',
#   'primeiro',
#   'mandato'],
#  ['#lula',
#   '#dilma',
#   'realizaram',
#   'sonho',
#   'betinho',
#   'nao',
#   'pode',
#   'realizar'],
#  ['#dilma', 'alunos', 'nao', 'dedicam', 'ciencia', 'fronteiras'],
#  ['#dilma', 'alunos', 'nao', 'dedicam', 'ciencia', 'fronteiras'],
#  ['"queremos',
#   'brasil',
#   'moderno',
#   'inclusivo',
#   'competitivo"',
#   'diz',
#   '#dilma',
#   'sala',
#   'imprensa'],
#  ['#dilma', 'alunos', 'nao', 'dedicam', 'ciencia', 'fronteiras'],
#  ['#dilma', 'alunos', 'nao', 'dedicam', 'ciencia', 'fronteiras'],
#  ['#dilma', 'alunos', 'nao', 'dedicam', 'ciencia', 'fronteiras'],
#  ['#dilma', 'alunos', 'nao', 'dedicam', 'ciencia', 'fronteiras'],
#  ['#dilma', 'alunos', 'nao', 'dedicam', 'ciencia', 'fronteiras'],
#  ['#dilma', 'comemora', 'resultados', 'pnad', 'sala', 'imprensa'],
#  ['#dilma', 'alunos', 'nao', 'dedicam', 'ciencia', 'fronteiras'],
#  ['#dilma', 'alunos', 'nao', 'dedicam', 'ciencia', 'fronteiras'],
#  ['#dilma', 'alunos', 'nao', 'dedicam', 'ciencia', 'fronteiras'],
#  ['#dilma',
#   'vamos',
#   'continuar',
#   'brasil',
#   'sempre',
#   'frente',
#   'viva',
#   'estrela'],
#  ['vamos', '#dilma', 'pracas', 'parques', 'praias', 'sabado', 'domingo'],
#  ['luiz',
#   'marinho',
#   'cordenador',
#   '#dilma',
#   'sp',
#   'pt',
#   'nao',
#   'agride',
#   '#marina',
#   'so',
#   'aborda',
#   'contradicoes'],
#  ['datafolha',
#   '#marina',
#   'cai',
#   '#dilma',
#   'lidera',
#   'primeiro',
#   'turno',
#   'via'],
#  ['vamos', 'presente', '#dilma', 'melhor', 'solucao'],
#  ['vejam',
#   'pesoas',
#   'ruas',
#   'reagem',
#   'ver',
#   '#dilma',
#   'puro',
#   'amor',
#   'reconhecimento',
#   'viva',
#   'nosa',
#   'presidenta',
#   '#dilma'],
#  ['"toda', 'conquista', 'novo', 'comeco"', 'diz', '#dilma', 'record'],
#  ['beleza',
#   '#dilma',
#   'momento',
#   'familia',
#   '#dilma',
#   'core',
#   'bem',
#   'dilma',
#   'netinho',
#   'gabriel'],
#  ['sgil',
#   'so',
#   'espero',
#   '#dilma',
#   'releita',
#   'vai',
#   'ser',
#   'fim',
#   'pais',
#   '#foradilma',
#   '#forapt'],
#  ['datafolha',
#   'dilma',
#   'marina',
#   'aparece',
#   'aecio',
#   'sobre',
#   '#eleicoes2014',
#   '#datafolha',
#   '#dilma',
#   '#marina',
#   '#aecio'],
#  ['#dilma', 'entrevista', 'celso', 'freitas', 'tv', '#dilma', 'novo'],
#  ['cada',
#   'devemos',
#   'explicar',
#   '#dilma',
#   'continua',
#   'sendo',
#   'melhor',
#   'opcao',
#   'pecam',
#   'filhos',
#   'namorado',
#   'marido',
#   'sobrinho',
#   'etc'],
#  ['datafolha',
#   'otimo',
#   'dilma',
#   'bom',
#   'aecio',
#   'pesimo',
#   'marina',
#   '#dilma',
#   '#pt',
#   '#lula'],
#  ['#mulheres', 'vamos', 'apoiar', '#dilma'],
#  ['governo', '#dilma', 'brasil', 'deixa', 'mapa', 'fome', 'segundo', 'onu'],
#  ['tse', 'libera', 'site', 'propaganda', '#dilma'],
#  ['votamos', '#dilma'],
#  ['rio',
#   'grande',
#   'sul',
#   'investimento',
#   'bilhoes',
#   'pac',
#   'mobilidade',
#   'urbana',
#   '#dilma'],
#  ['#copadascopas',
#   'acabou',
#   'brt',
#   '#dilma',
#   'trouxe',
#   'cariocas',
#   'ficou',
#   'legado',
#   'chupa',
#   'seus...'],
#  ['so',
#   'confirmou',
#   'todos',
#   'inclusive',
#   '#lula',
#   '#dilma',
#   '#pt',
#   'peso',
#   'ja',
#   'sabiamos',
#   'gt'],
#  ['#dilma', 'brasil', 'reduz', 'indice', 'desnutridos', 'para7', 'populacao'],
#  ['#dilma', 'brasil', 'reduz', 'indice', 'desnutridos', 'para7', 'populacao'],
#  ['#dilma', 'brasil', 'reduz', 'indice', 'desnutridos', 'para7', 'populacao'],
#  ['#dilma', 'brasil', 'reduz', 'indice', 'desnutridos', 'para7', 'populacao'],
#  ['#dilma', 'brasil', 'reduz', 'indice', 'desnutridos', 'para7', 'populacao'],
#  ['chega', 'planalto', 'concorente', 'ibope', '#dilma', '#pt', '#lula'],
#  ['fhc',
#   'quer',
#   'aecio',
#   'linha',
#   'auxiliar',
#   'marina',
#   '#dilma',
#   '#pt',
#   '#lula'],
#  ['#dilma',
#   'recebe',
#   'voto',
#   'frei',
#   'beto',
#   'luta',
#   'contra',
#   'escravidao',
#   'brasil'],
#  ['#dilma',
#   'recebe',
#   'voto',
#   'frei',
#   'beto',
#   'luta',
#   'contra',
#   'escravidao',
#   'brasil'],
#  ['#dilma',
#   'recebe',
#   'voto',
#   'frei',
#   'beto',
#   'luta',
#   'contra',
#   'escravidao',
#   'brasil'],
#  ['#dilma',
#   'recebe',
#   'voto',
#   'frei',
#   'beto',
#   'luta',
#   'contra',
#   'escravidao',
#   'brasil'],
#  ['#dilma',
#   'recebe',
#   'voto',
#   'frei',
#   'beto',
#   'luta',
#   'contra',
#   'escravidao',
#   'brasil'],
#  ['sei', 'acredito', 'completa', 'lisura', 'presidenta', '#dilma'],
#  ['datafolha', '#dilma#rejeicao', 'dilma', 'intencao', 'voto'],
#  ['#dilma', 'falou', 'falado'],
#  ['dilma', 'amplia', 'vantagem', 'sobre', 'marina', '#dilma', '#pt'],
#  ['governo', '#dilma', 'brasil', 'deixa', 'mapa', 'fome', 'segundo', 'onu'],
#  ['governo', '#dilma', 'brasil', 'deixa', 'mapa', 'fome', 'segundo', 'onu'],
#  ['governo', '#dilma', 'brasil', 'deixa', 'mapa', 'fome', 'segundo', 'onu'],
#  ['governo', '#dilma', 'brasil', 'deixa', 'mapa', 'fome', 'segundo', 'onu'],
#  ['governo', '#dilma', 'brasil', 'deixa', 'mapa', 'fome', 'segundo', 'onu'],
#  ['governo', '#dilma', 'brasil', 'deixa', 'mapa', 'fome', 'segundo', 'onu'],
#  ['governo', '#dilma', 'brasil', 'deixa', 'mapa', 'fome', 'segundo', 'onu'],
#  ['governo', '#dilma', 'brasil', 'deixa', 'mapa', 'fome', 'segundo', 'onu'],
#  ['governo', '#dilma', 'brasil', 'deixa', 'mapa', 'fome', 'segundo', 'onu'],
#  ['governo', '#dilma', 'brasil', 'deixa', 'mapa', 'fome', 'segundo', 'onu'],
#  ['#dilma', 'inclui', 'programa', 'capitulo', 'sobre', 'gestao', 'publica'],
#  ['#dilma', 'inclui', 'programa', 'capitulo', 'sobre', 'gestao', 'publica'],
#  ['#dilma', 'inclui', 'programa', 'capitulo', 'sobre', 'gestao', 'publica'],
#  ['#dilma', 'inclui', 'programa', 'capitulo', 'sobre', 'gestao', 'publica'],
#  ['#dilma', 'inclui', 'programa', 'capitulo', 'sobre', 'gestao', 'publica'],
#  ['#dilma', 'tira', 'milhoes', 'miseria', 'brasil', 'sai', 'mapa', 'fome'],
#  ['#dilma', 'tira', 'milhoes', 'miseria', 'brasil', 'sai', 'mapa', 'fome'],
#  ['#dilma', 'tira', 'milhoes', 'miseria', 'brasil', 'sai', 'mapa', 'fome'],
#  ['#dilma', 'tira', 'milhoes', 'miseria', 'brasil', 'sai', 'mapa', 'fome'],
#  ['#dilma', 'tira', 'milhoes', 'miseria', 'brasil', 'sai', 'mapa', 'fome'],
#  ['mulheres',
#   'dizem',
#   'sim',
#   'nosa',
#   'senadora',
#   '#fatima131',
#   '#souhugomanso',
#   '#dilma',
#   '#robison',
#   '#mineiro136'],
#  ['#lavajato',
#   '#dilma',
#   'oligofrenica',
#   'panico',
#   'delacao',
#   'premiada',
#   'exdiretor',
#   '#petrobras',
#   'sobre',
#   'propina',
#   'compra',
#   'usina',
#   '#pasadena'],
#  ['#dilma', 'oscila', '#marina', '#pesquisa', '#datafolha', '#natal'],
#  ['#foradilma',
#   '#coreios',
#   'entregam',
#   'panfletos',
#   '#dilma',
#   'sp',
#   'registro',
#   'controle'],
#  ['total',
#   'favor',
#   '#dilma',
#   'menos',
#   'nao',
#   'quer',
#   'tirar',
#   'nosoo',
#   'salario'],
#  ['cut', 'proposta', '#dilma', 'emprego', 'renda', 'outros'],
#  ['cut', 'proposta', '#dilma', 'emprego', 'renda', 'outros'],
#  ['cut', 'proposta', '#dilma', 'emprego', 'renda', 'outros'],
#  ['cut', 'proposta', '#dilma', 'emprego', 'renda', 'outros'],
#  ['cut', 'proposta', '#dilma', 'emprego', 'renda', 'outros'],
#  ['cut', 'proposta', '#dilma', 'emprego', 'renda', 'outros'],
#  ['onu',
#   'tirou',
#   'brasil',
#   'mapa',
#   'fome',
#   '#dilmanarecord',
#   'gterado',
#   '#lula',
#   '#dilma',
#   '#betinho',
#   'tiraram',
#   'brasil',
#   'mapa',
#   'fome'],
# ...
#   'so',
#   'poderemos',
#   'mudar',
#   'ese',
#   'pais',
#   'nao',
#   '#dilma'],
#  ['#dilma',
#   'rousef',
#   'entrega',
#   'medalhas',
#   'elogia',
#   'desempenho',
#   'jovens',
#   'piaui',
#   'olimpiada',
#   'matematica'],
#  ['aecio',
#   'neves',
#   'crece',
#   'sera',
#   'blanco',
#   'ataques',
#   '#dilma',
#   'eduardo',
#   'campos',
#   'gt',
#   '#elecionesbrasil'],
#  ['#pig',
#   'partido',
#   'imprensa',
#   'golpista',
#   'alimenta',
#   'oposicao',
#   '#ratucana',
#   'nao',
#   'disfarca',
#   'caca',
#   '#dilma'],
#  ['#dilma',
#   'rousef',
#   'entrega',
#   'medalhas',
#   'elogia',
#   'desempenho',
#   'jovens',
#   'piaui',
#   'olimpiada',
#   'matematica',
#   'brasil'],
#  ['#dilma',
#   'celebra',
#   'aprovacao',
#   'marco',
#   'civil',
#   'defende',
#   'pais',
#   'pode',
#   'garantir',
#   'direitos',
#   'humanos',
#   'internet'],
#  ['#dilma',
#   'rousef',
#   'entrega',
#   'medalhas',
#   'elogia',
#   'desempenho',
#   'jovens',
#   'piaui',
#   'olimpiada',
#   'matematica',
#   'nacional'],
#  ['saude',
#   'libera',
#   'mi',
#   'hospitais',
#   'universitarios',
#   '#maisaude',
#   '#dilma'],
#  ['transplantes',
#   'pulmao',
#   'triplicam',
#   'tres',
#   'anos',
#   '#maisaude',
#   '#dilma'],
#  ['imagine',
#   '#dilma',
#   'trocando',
#   'ideia',
#   'afinadisima',
#   'general',
#   'pra',
#   'colocar',
#   'tropa',
#   'ruas',
#   'durante',
#   '#copadascopas',
#   'queria',
#   'estar',
#   'la',
#   'pra',
#   'ver'],
#  ['governos', '#pt', 'geraram2', 'milhoes', 'empregos', 'pais', '#dilma'],
#  ['#cracolandia',
#   '#hadad',
#   'cresceu',
#   'tanto',
#   'ja',
#   'precisando',
#   '#minhacasaminhavida',
#   '#dilma',
#   'falta',
#   'dialogo',
#   '#respeitesp'],
#  ['copa',
#   'luxo',
#   'pais',
#   'nada',
#   'lixo',
#   '#dilma',
#   '#lula',
#   '#yousef',
#   '#eike',
#   '#gleisi',
#   'lt#quadrilha'],
#  ['ai', 'grande...', 'popularidade', '#dilma'],
#  ['ai', 'grande...', 'popularidade', '#dilma'],
#  ['ame',
#   'odeie',
#   'aecio',
#   'diz',
#   'eleitor',
#   'nao',
#   'vota',
#   '#dilma',
#   'quer',
#   'ouvir',
#   'ver'],
#  ['#dilma',
#   'nao',
#   'quer',
#   'falar',
#   'racionamento',
#   'vai',
#   'conhecer',
#   'brasil',
#   'verde',
#   'amarelo',
#   'vamos',
#   'apagar',
#   'brasil',
#   'copa',
#   'pt'],
#  ['ai', 'salario', 'apoiar', 'governo', '#pt', '#dilma', '#lula', '#brasil'],
#  ['gostaria',
#   '#skaf',
#   'falase',
#   'chapa',
#   'apoia',
#   '#dilma',
#   'pois',
#   'programa',
#   'eleitoral',
#   'nao',
#   'coloca',
#   '#skaf'],
#  ['vamos', '#companheiros', '#dilma', 'vez'],
#  ['#mais',
#   'mudancas',
#   '#mais',
#   'futuro',
#   '#tamos',
#   'juntos',
#   '#dilma',
#   'primeiro',
#   'turno'],
#  ['sertaneja', 'diz', 'ganhou', 'protese', 'antes', 'gravar', '#dilma', 'tv'],
#  ['desligar',
#   'tv',
#   'min',
#   '#dilma',
#   'direito',
#   'horario',
#   'politico',
#   'enconomizaremos',
#   'energia',
#   'pra',
#   'cidade',
#   'de0',
#   'habitantes',
#   'mes'],
#  ['dilma',
#   'defende',
#   'obras',
#   'mobilidade',
#   'diz',
#   'nao',
#   'ha',
#   'situacao',
#   'desemprego',
#   '#eleicoes2014',
#   '#dilma2014',
#   '#dilma'],
#  ['#dilma', 'saude', 'publica', 'educacao', 'nao', 'prioridade', 'pra', 'mim'],
#  ['#pt13', '#dilma', '#camilosantana', 'boa', 'noite'],
#  ['15',
#   'mil',
#   'hoje',
#   'gigantinho',
#   'rs',
#   'moro',
#   'nao',
#   'vejo',
#   'marina',
#   'juntar',
#   'mil',
#   'gauchos',
#   'caminhadas',
#   'pampas',
#   '#dilma'],
#  ['cara',
#   'perfeito',
#   '#idiota',
#   'tirando',
#   'foto',
#   '#selfie',
#   '#dilma',
#   'va',
#   'esperando',
#   'mane',
#   'daqui',
#   'quatro',
#   'anos',
#   'tera',
#   'nova',
#   'chance',
#   '#jn',
#   '#eleicoes2014'],
#  ['#dilma',
#   'iria',
#   'alguma',
#   'especie',
#   'debate',
#   'nao',
#   'precisa',
#   'diso',
#   'joao',
#   'santana',
#   'ajudando',
#   'mostrar',
#   'cara',
#   'riqueza',
#   '12'],
#  ['#dilma',
#   'libera',
#   'credito',
#   'convida',
#   'povo',
#   'trabalha',
#   'comprometer',
#   'dividas',
#   'restante',
#   'salarios',
#   'coroidos',
#   'inflacao'],
#  ['rio',
#   'grande',
#   'brasil',
#   'vao',
#   'continuar',
#   'rumo',
#   'certo',
#   '#maiorcomiciocolaborativo',
#   '#dilmamptarso',
#   '#olivio'],
#  ['#dilma',
#   'dise',
#   'falar',
#   'acabar',
#   'fator',
#   'previdenciario',
#   'vai',
#   'cortar',
#   'programa',
#   'social',
#   'entao',
#   'aposentado',
#   'banca',
#   'bolsa',
#   'familia'],
#  ['igualdade', '#dilma', '#olivio', '#tarso', '#13'],
#  ['#dilma', 'pague', 'face', 'twiter', 'k'],
#  ['avaliacao',
#   'governo',
#   '#dilma',
#   'melhora',
#   'horario',
#   'eleitoral',
#   'blog',
#   'rovai'],
#  ['',
#   'votar',
#   'dilma',
#   'votar',
#   'mudanca',
#   'muita',
#   'gente',
#   'muita',
#   'bandeira',
#   'muita',
#   'vontade',
#   'mudar',
#   '#dilma'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['dilma',
#   'cita',
#   'presal',
#   'horario',
#   'eleitoral',
#   'esconde',
#   'monopolio',
#   'petroquimico',
#   'odebrecht',
#   '#dilma',
#   '#odebrecht'],
#  ['#dilma',
#   'maos',
#   'limpas',
#   'sempre',
#   'lutando',
#   'povo',
#   'brasileiro',
#   '#dilma13denovo'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['#dilma', '#padilha', 'sofreram', 'ditadura'],
#  ['candidata', 'marina', 'ja', 'bate', '#dilma', 'pernambuco'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['#dilma',
#   'minas',
#   'visitar',
#   'cursos',
#   'pronatec',
#   'gravar',
#   'imagens',
#   'campanha'],
#  ['vagas',
#   'ufrgs',
#   'litoral',
#   'norte',
#   'inaugura',
#   'daqui',
#   'mes',
#   '#dilma',
#   '#maisoportunidades',
#   'zh',
#   'noticias'],
#  ['candidatase',
#   'votaria',
#   'nele',
#   'pronto',
#   'falei',
#   '#brunomendiguinho',
#   '#votaemim',
#   '#dilma',
#   '#compartilha'],
#  ['culpa',
#   '#dilma',
#   '#dilma13denovo',
#   'vagas',
#   'ufrgs',
#   'litoral',
#   'norte',
#   'inaugura',
#   'daqui',
#   'mes'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['ate',
#   'queria',
#   'fazer',
#   'desafio',
#   '#baldedegelo',
#   'gracas',
#   'governo',
#   '#dilma',
#   'racionamento'],
#  ['atendendo', 'clamor', 'ruas', '#tarso', '#olivio', '#dilma'],
#  ['#dilma', 'nega', 'atos', 'campanha', 'atrapalhem', 'trabalho'],
#  ['#dilma', 'nega', 'atos', 'campanha', 'atrapalhem', 'trabalho'],
#  ['imagem',
#   'lula',
#   'si',
#   'so',
#   'ja',
#   'campanha',
#   'fala',
#   'entao',
#   'oposicao',
#   'treme',
#   '#dilma',
#   'novo',
#   'neles'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   "'certa",
#   "imprensa'",
#   'esconde'],
#  ['aecio',
#   'pede',
#   'calma',
#   'parte',
#   'guera',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#globo'],
#  ['ridiculo',
#   'apartamento',
#   'graca',
#   'foster',
#   'globo',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#globo'],
#  ['cordena',
#   'erundina',
#   'psb',
#   'manda',
#   'setubal',
#   'itau',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#globo'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['#dilma', '"so', 'nao', 'atrasa', 'obra', 'nao', 'faz"'],
#  ['tijolaco',
#   'todos',
#   'avioes',
#   'dudu',
#   'conversa',
#   'afiada',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#globo'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['dilma',
#   'coracao',
#   'valente',
#   'forca',
#   'brasileira',
#   '#maiorcomiciocolaborativo',
#   '#dilma',
#   '#tarso',
#   '#olivio',
#   '#marcomaia',
#   '#nelsinho13630'],
#  ['caso',
#   'dentadura',
#   'folha',
#   'nao',
#   'mostra',
#   'milhares',
#   'conseguiram',
#   'casa',
#   'propria',
#   'luz',
#   'diploma',
#   'universtario',
#   'gov',
#   '#dilma'],
#  ['alguma', 'duvida', '#euvotodilma', '#dilma', '#dilma13', '#soumaisdilma'],
#  ['#lula',
#   'alem',
#   'ter',
#   'libertado',
#   'povo',
#   '#cupinsainda',
#   'deu',
#   '#presente',
#   'esa',
#   'maravilha',
#   'chamada#dilmak'],
#  ['ver',
#   '#dilma',
#   'pasar',
#   'pro',
#   'dona',
#   'casa',
#   'falta',
#   'respeito',
#   'donas',
#   'casas',
#   'dilma',
#   'bandida',
#   'hora',
#   'chegando',
#   '#forapt'],
#  ['#brasil',
#   'precisa',
#   'continuar',
#   'avancando',
#   '#dilma',
#   '#dilmarousef',
#   'vamos...'],
#  ['rindo',
#   'esa',
#   'foto',
#   'dona',
#   '#dilma',
#   '#aecio',
#   'publicou',
#   '#eleicoes',
#   '#eleicoes2014',
#   '#zueira'],
#  ['abra', '#dilmafoster'],
#  ['cara',
#   'pau',
#   '#lula',
#   'x9',
#   'dedos',
#   'continua',
#   'mentindo',
#   'sobre',
#   'presal',
#   'prpaganda',
#   '#dilma',
#   'dizendo',
#   'vai',
#   'gerar',
#   'milhares',
#   'empregos'],
#  ['dentadura',
#   'vida',
#   'artificios',
#   'antiga',
#   'politica',
#   'paleozoica',
#   '#brasil',
#   '#politica',
#   '#pt',
#   '#dilma'],
#  ['kichalowsk',
#   'vice',
#   '#dilma',
#   'repetindo',
#   'gestao',
#   'vem',
#   'dando',
#   'certo',
#   '#plenoemprego'],
#  ['propaganda',
#   'jackson',
#   'bareto',
#   'pmdbse',
#   'mentirosa',
#   '#dilma',
#   'diz',
#   'lutaram',
#   'redemocratizacao',
#   'pra',
#   'instalar',
#   'ditadura',
#   'cubana'],
#  ['#dilma',
#   'enfiou',
#   'noso',
#   'dinheiro',
#   'destinado',
#   'reforma',
#   'aeroporto',
#   '#cuiaba',
#   'orificio',
#   'anal',
#   'ou...'],
#  ['infelizmente',
#   'carioca',
#   'preferindo',
#   'bosta',
#   'maior',
#   'presidencia',
#   '#dilma'],
#  ['#dilma', 'fodeu', 'tudo', '#mrcatrapresidente'],
#  ['olha',
#   'nivel',
#   '#dilma',
#   'chegou',
#   'pra',
#   'tentar',
#   'ficar',
#   'poder',
#   '#campanhadaperereca',
#   '#minhapererecaminhavida',
#   '#vergonhanacional'],
#  ['#dilmaetarso13denovo',
#   'chegando',
#   'gigantinho',
#   '#dilma',
#   '#tarso',
#   '#olivio',
#   '#marcomaia',
#   '#nelsinho1630'],
#  ['garoto', 'propaganda', '#dilma', '#tarso', '#olivio', '#nelsinho13630'],
#  ...]

# %%
# %%time
from gensim.corpora.dictionary import Dictionary

from gensim.models.ldamodel import LdaModel

from gensim.models.coherencemodel import CoherenceModel

common_dictionary = Dictionary(e_sentences)

common_corpus = [common_dictionary.doc2bow(text) for text in e_sentences]

# Train the model on the corpus.

lda = LdaModel(common_corpus, num_topics=7 )
# Out:
# CPU times: user 24.7 s, sys: 128 ms, total: 24.8 s
# Wall time: 25.4 s

# %%
#lda.print_topics()
print(lda.print_topics())
doc_lda = lda[common_corpus]
# Out:
# [(0, '0.137*"0" + 0.030*"738" + 0.027*"365" + 0.018*"71" + 0.015*"65" + 0.009*"3" + 0.009*"201" + 0.008*"739" + 0.008*"16079" + 0.008*"165"'), (1, '0.057*"0" + 0.031*"439" + 0.021*"585" + 0.013*"519" + 0.012*"1757" + 0.011*"7498" + 0.010*"1578" + 0.010*"497" + 0.010*"1437" + 0.009*"1177"'), (2, '0.129*"0" + 0.022*"71" + 0.015*"358" + 0.014*"602" + 0.013*"72" + 0.012*"65" + 0.012*"167" + 0.011*"315" + 0.011*"652" + 0.011*"263"'), (3, '0.120*"0" + 0.021*"71" + 0.012*"144" + 0.011*"65" + 0.009*"126" + 0.009*"98" + 0.009*"10" + 0.009*"72" + 0.009*"224" + 0.007*"97"'), (4, '0.079*"0" + 0.036*"1451" + 0.035*"1151" + 0.025*"611" + 0.023*"894" + 0.017*"473" + 0.012*"4513" + 0.011*"4512" + 0.010*"1728" + 0.008*"3905"'), (5, '0.041*"0" + 0.029*"4790" + 0.023*"107" + 0.022*"2299" + 0.012*"354" + 0.012*"2666" + 0.011*"219" + 0.010*"217" + 0.010*"2893" + 0.010*"664"'), (6, '0.129*"0" + 0.030*"71" + 0.028*"551" + 0.016*"1023" + 0.014*"165" + 0.013*"80" + 0.013*"214" + 0.013*"163" + 0.010*"552" + 0.009*"3"'), (7, '0.066*"2536" + 0.043*"0" + 0.029*"10674" + 0.025*"4012" + 0.024*"13953" + 0.014*"1391" + 0.012*"1469" + 0.009*"7355" + 0.009*"2523" + 0.008*"473"')]

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()
vis = gensimvis.prepare(lda, common_corpus, common_dictionary)
vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0     -0.207764  0.022817       1        1  24.712990
# 6     -0.201031  0.007419       2        1  21.187086
# 2     -0.171071 -0.013152       3        1  14.851147
# 3     -0.157892  0.018481       4        1  12.894554
# 4      0.188134  0.112277       5        1   9.161292
# 1      0.145491 -0.316931       6        1   6.187206
# 7      0.220540  0.022835       7        1   5.513353
# 5      0.183594  0.146255       8        1   5.492371, topic_info=          Term         Freq          Total Category  logprob  loglift
# 2536    debate  3400.000000    3400.000000  Default  30.0000  30.0000
# 551     #aecio  6403.000000    6403.000000  Default  29.0000  29.0000
# 1151       gov  3023.000000    3023.000000  Default  28.0000  28.0000
# 1451       fez  3547.000000    3547.000000  Default  27.0000  27.0000
# 738      #lula  8477.000000    8477.000000  Default  26.0000  26.0000
# ...        ...          ...            ...      ...      ...      ...
# 1086  politica   393.609883    1181.693232   Topic8  -4.8724   1.8025
# 0       #dilma  2095.324016  104080.000447   Topic8  -3.2003  -1.0036
# 778    emprego   362.195588    1236.392348   Topic8  -4.9556   1.6740
# 1451       fez   471.404058    3547.243973   Topic8  -4.6920   0.8836
# 1430      cara   316.372136    1445.045170   Topic8  -5.0908   1.3828
#
# [432 rows x 6 columns], token_table=       Topic      Freq     Term
# term
# 5748       3  0.995667     "nao
# 733        1  0.436930      #13
# 733        4  0.562548      #13
# 551        1  0.127594   #aecio
# 551        2  0.868638   #aecio
# ...      ...       ...      ...
# 652        8  0.000363     voto
# 843        1  0.108495    votos
# 843        2  0.890506    votos
# 5977       6  0.997379      vox
# 12476      7  0.996013  youtube
#
# [736 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[1, 7, 3, 4, 5, 2, 8, 6])

# %%
#print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda, texts=e_sentences, dictionary=common_dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Coherence Score:  0.3517265835830585

# %% [markdown]
# # N_grams

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder =nltk.collocations.BigramCollocationFinder.from_documents([comment.split() for comment in df['content_clean']])
finder.apply_freq_filter(200)
bigram_scores = finder.score_ngrams(bigram_measures.pmi)
bigram_scores
# Out:
# [(('coracao', 'valente'), 11.111548822224108),
#  (('voa', 'aviaozinho'), 11.109817259857511),
#  (('senta', 'chora'), 10.845332924216333),
#  (('dilmapt', 'portal'), 10.673227706751149),
#  (('sala', 'imprensa'), 10.558718242945705),
#  (('salario', 'minimo'), 10.38666535832743),
#  (('#aeciocheiraderota', 'senta'), 10.23277311036573),
#  (('discurso', 'vazio'), 10.144517170296414),
#  (('eduardo', 'campos'), 10.106913886092947),
#  (('mostra', '#competencia'), 9.914624187615996),
#  (('bolsa', 'familia'), 9.487843792509263),
#  (('reforma', 'politica'), 9.022872513612928),
#  (('#globo', '#jn'), 8.918073652324264),
#  (('noo', 'turno'), 8.617394139025166),
#  (('jornal', 'nacional'), 8.611699943202595),
#  (('ipcinpcipcaigpm', 'iso'), 8.492359151377414),
#  (('querida', 'presidenta'), 8.27616323857653),
#  (('casa', 'vida'), 8.189679101645954),
#  (('marina', 'silva'), 8.075237295708941),
#  (('portal', 'sobre'), 8.046240402447687),
#  (('todo', 'mundo'), 7.91825106849096),
#  (('primeiro', 'turno'), 7.907293779565261),
#  (('segundo', 'turno'), 7.881456962563174),
#  (('#foradilma', '#forapt'), 7.80489425889343),
#  (('povo', 'brasileiro'), 7.325927112104278),
#  (('aecio', 'neves'), 7.313588430293894),
#  (('bom', 'dia'), 7.2879257863910425),
#  (('aviaozinho', 'vai'), 7.27708841435966),
#  (('vai', 'buscar'), 7.135814838822117),
#  (('presos', 'pf'), 6.767795607453728),
#  (('cair', 'numero'), 6.763460145988578),
#  (('coruptos', 'presos'), 6.7553197851766775),
#  (('numero', 'coruptos'), 6.739921316324978),
#  (('pf', 'veja'), 6.656769259707499),
#  (('fez', 'cair'), 6.624843216788133),
#  (('sim', 'voto'), 6.611043882379239),
#  (('iso', 'mostra'), 6.532333762188344),
#  (('#crisenapf', 'gov'), 6.4040021118014785),
#  (('#lula', '#psdb'), 5.9946894087085525),
#  (('#psdb', '#pt'), 5.925625674563296),
#  (('#pt', '#globo'), 5.915052960842541),
#  (('#pt', '#vaitercopa'), 5.845086571146378),
#  (('dilma', 'rousef'), 5.765959326902472),
#  (('psdb', 'aecio'), 5.331890591145619),
#  (('vai', 'ter'), 5.147779806598809),
#  (('sobre', 'presidenta'), 5.081647810126139),
#  (('#pt', '#lula'), 4.9095210418497786),
#  (('vai', 'ser'), 4.650539665431374),
#  (('presidenta', 'dilma'), 4.274128385050716),
#  (('#marina', '#aecio'), 4.164845906064688),
#  (('vai', 'votar'), 4.1593524682489225),
#  (('nao', 'sabe'), 4.091451113634985),
#  (('nao', 'pode'), 3.8207045803924196),
#  (('#dilma', '#aeciocheiraderota'), 3.2206821997874826),
#  (('#competencia', '#dilma'), 3.214708298742849),
#  (('gov', '#dilma'), 3.180645786600806),
#  (('#dilma', 'fez'), 3.088008934626977),
#  (('dilma', 'aecio'), 3.0396419462700557),
#  (('#dilma', 'anuncia'), 2.8927553642786776),
#  (('#dilma', 'investe'), 2.770879282347966),
#  (('#dilma', '#tarso'), 2.686209469520019),
#  (('#dilma', 'defende'), 2.5940094471814916),
#  (('povo', 'nao'), 2.576240804568851),
#  (('brasil', 'vai'), 2.5263727252151966),
#  (('#dilma', 'rousef'), 2.5059014585793733),
#  (('#dilma', 'garante'), 2.4837166056212787),
#  (('vota', '#dilma'), 2.473801136756194),
#  (('presidenta', '#dilma'), 2.3708648576081686),
#  (('releicao', '#dilma'), 2.342183204835191),
#  (('#dilma', 'releita'), 2.1884057967637283),
#  (('#dilma', '#pt'), 2.1869123548679354),
#  (('votar', '#dilma'), 2.186169908224681),
#  (('#lula', '#pt'), 2.1754437270083997),
#  (('#dilma', 'discurso'), 2.153933381932898),
#  (('voto', '#dilma'), 2.1380715117993816),
#  (('#dilma', '#padilha'), 2.134449802143404),
#  (('nao', 'vai'), 2.0843545884848176),
#  (('#dilma', '#13'), 1.8875268494768704),
#  (('vote', '#dilma'), 1.8584461162465828),
#  (('diz', 'nao'), 1.807981925961915),
#  (('governo', '#dilma'), 1.7919597853978502),
#  (('vitoria', '#dilma'), 1.7861871936001528),
#  (('#dilma', '#lula'), 1.6379331494262637),
#  (('#dilma', '#dilma13'), 1.59659336777651),
#  (('apoio', '#dilma'), 1.5551421832192993),
#  (('#dilma', '#aecio'), 1.4591814621323103),
#  (('#dilma', 'diz'), 1.4155089841343198),
#  (('#dilma', 'fala'), 1.4075817701724525),
#  (('campanha', '#dilma'), 1.390703128291296),
#  (('diz', '#dilma'), 1.3284129328691456),
#  (('#dilma', 'mostra'), 1.2664858894006095),
#  (('presidente', '#dilma'), 1.2307158868144619),
#  (('#dilma', '#marina'), 1.2034518291257648),
#  (('#lula', '#dilma'), 1.1805735607900267),
#  (('#dilma', 'faz'), 1.1632881938636466),
#  (('#dilma', 'novo'), 1.1032246182393095),
#  (('brasil', 'nao'), 1.0213540117135018),
#  (('lula', '#dilma'), 0.9741803750723612),
#  (('#dilma', 'ja'), 0.9549982155397423),
#  (('#dilma', 'vai'), 0.9021327833550927),
#  (('contra', '#dilma'), 0.8980256549776087),
#  (('bom', '#dilma'), 0.8499233423678199),
#  (('esa', '#dilma'), 0.7118371144139175),
#  (('programa', '#dilma'), 0.5790908378576205),
#  (('#dilma', 'quer'), 0.5548972193163699),
#  (('#dilma', 'nao'), 0.5389572970782268),
#  (('#eleicoes2014', '#dilma'), 0.5385972321682253),
#  (('#brasil', '#dilma'), 0.4654822568992678),
#  (('via', '#dilma'), 0.42482291656770954),
#  (('turno', '#dilma'), 0.38000370604838807),
#  (('#dilma', '#eleicoes2014'), 0.35909622848458156),
#  (('#aecio', '#dilma'), 0.3491724573518873),
#  (('#dilma', 'k'), 0.28731939281777485),
#  (('#dilma', 'lula'), 0.19269978726160275),
#  (('#dilma', 'so'), 0.17433188346370443),
#  (('agora', '#dilma'), 0.0929266525891137),
#  (('#dilma', '#brasil'), 0.08654873130567253),
#  (('#pt', '#dilma'), 0.06424830814469118),
#  (('#dilma', 'pt'), 0.0493266627387321),
#  (('#dilma', 'presidente'), 0.012127541619783244),
#  (('#marina', '#dilma'), -0.018051959573476495),
#  (('#dilma', 'vamos'), -0.06195676398581895),
#  (('pt', '#dilma'), -0.1433184152036624),
#  (('k', '#dilma'), -0.16988756070501054),
#  (('#dilma', 'sobre'), -0.21698421016614944),
#  (('pra', '#dilma'), -0.24326489997230638),
#  (('#dilma', 'presidenta'), -0.3159772571322037),
#  (('#dilma', 'brasil'), -0.4672487932443268),
#  (('#dilma', 'marina'), -0.49552483421192406),
#  (('#dilma', 'aecio'), -0.5394730217506094),
#  (('brasil', '#dilma'), -0.5518448024289029),
#  (('dilma', '#dilma'), -0.7824824071561949),
#  (('#dilma', 'pra'), -0.9879044220239344),
#  (('nao', '#dilma'), -2.8803271733008025),
#  (('#dilma', '#dilma'), -5.672525861773668)]

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder =nltk.collocations.TrigramCollocationFinder.from_documents([comment.split() for comment in df['content_clean']])
# Filter only those that occur at least 50 times
finder.apply_freq_filter(200)
trigram_scores = finder.score_ngrams(trigram_measures.pmi)
trigram_scores
# Out:
# [(('#aeciocheiraderota', 'senta', 'chora'), 21.116477845454586),
#  (('aviaozinho', 'vai', 'buscar'), 19.235560917850485),
#  (('dilmapt', 'portal', 'sobre'), 18.988734468744145),
#  (('ipcinpcipcaigpm', 'iso', 'mostra'), 18.41895598065949),
#  (('iso', 'mostra', '#competencia'), 18.406983338993417),
#  (('voa', 'aviaozinho', 'vai'), 18.401049856537444),
#  (('portal', 'sobre', 'presidenta'), 15.965118909394374),
#  (('#pt', '#globo', '#jn'), 15.667152299437852),
#  (('#psdb', '#pt', '#globo'), 14.74710147820278),
#  (('#psdb', '#pt', '#vaitercopa'), 14.574850271548101),
#  (('numero', 'coruptos', 'presos'), 13.540627635418907),
#  (('coruptos', 'presos', 'pf'), 13.534510601789037),
#  (('cair', 'numero', 'coruptos'), 13.530175140323898),
#  (('#competencia', '#dilma', 'discurso'), 13.489110156499592),
#  (('presos', 'pf', 'veja'), 13.457475578801422),
#  (('#dilma', '#aeciocheiraderota', 'senta'), 13.453455310153217),
#  (('fez', 'cair', 'numero'), 13.410324415788871),
#  (('#dilma', 'discurso', 'vazio'), 13.347277462086637),
#  (('mostra', '#competencia', '#dilma'), 13.135306387403482),
#  (('#lula', '#psdb', '#pt'), 12.525243021891988),
#  (('sobre', 'presidenta', 'dilma'), 12.173773956597245),
#  (('presidenta', '#dilma', '#aeciocheiraderota'), 11.839532093418178),
#  (('querida', 'presidenta', '#dilma'), 11.475783822836192),
#  (('#dilma', 'fez', 'cair'), 9.845525416575626),
#  (('sim', 'voto', '#dilma'), 9.831726082166725),
#  (('gov', '#dilma', 'fez'), 9.768588636810748),
#  (('#crisenapf', 'gov', '#dilma'), 9.624684311588958),
#  (('#dilma', '#lula', '#psdb'), 9.051459634684328),
#  (('#dilma', '#pt', '#lula'), 8.02901452288586),
#  (('#dilma', '#lula', '#pt'), 5.030254484320928),
#  (('#lula', '#dilma', '#pt'), 4.740196904720584)]

# %% [markdown]
# # Topic Modeling NMF

# %%
# %%time
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

documents = df['content_clean'] 

no_features = 1000

# NMF is able to use tf-idf
tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words=stop_words)
tfidf = tfidf_vectorizer.fit_transform(documents)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

# LDA can only use raw term counts for LDA because it is a probabilistic graphical model
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words=stop_words)
tf = tf_vectorizer.fit_transform(documents)
tf_feature_names = tf_vectorizer.get_feature_names()

no_topics = 9

# Run NMF
nmf = NMF(n_components=no_topics, random_state=42, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf)

# Run LDA
lda = LatentDirichletAllocation(n_components=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=42).fit(tf)

no_top_words = 15
display_topics(nmf, tfidf_feature_names, no_top_words)
display_topics(lda, tf_feature_names, no_top_words)
# Out:
# Topic 0:
# crisenapf presos cair número pf coruptos gov veja fez rj 14 oficial filho santos pimentel
# Topic 1:
# pt psdb globo jn governo contra vaitercopa agora campanha foradilma forapt corupção copa mídia nacional
# Topic 2:
# não povo diz nada iso pode sabe pra ser esa governo país corupção quer presidente
# Topic 3:
# aecio debate psdb eleições2014 pesquisa neves sobre minas eleicoes2014 votos ibope turno datafolha debatenaglobo eleições
# Topic 4:
# brasil copa diz mundo todo melhor vamos presidente governo via ainda desemprego educação continuar sempre
# Topic 5:
# vai pra ser votar ter agora copa presidenta esa ganhar dizer vota rt voa tomar
# Topic 6:
# 13 voto sim votar iso dia todos vamos motivos intenções pra povo presidenta agora hoje
# Topic 7:
# marina diz turno sobre silva governo segundo datafolha pesquisa ibope 2º presidente eleições2014 via política
# Topic 8:
# lula psdb globo rt governos jn vaitercopa petrobras milhões saúde fhc anos campos sobre médicos
# Topic 0:
# aecio marina lula sobre brasil turno todos petrobras corupção bom contra ter nao vota aqui
# Topic 1:
# rt presidenta bem ver ibope falar nosa nacional quero lá vida 10 eleições cuba dar
# Topic 2:
# brasil não governo agora copa quer lula ser pode diz sabe todo segundo debatenaglobo cara
# Topic 3:
# vai 13 voto votar novo ese forapt foradilma debatedaband mundo casa ganhar falando aecio45 dise
# Topic 4:
# veja coruptos cair anos tudo pesquisa eleicoes2014 mostra sim eleições2014 discurso sempre fhc boa datafolha
# Topic 5:
# número iso vamos programa ainda fala gt tv nordeste eleição deu mil imprensa entrevista obras
# Topic 6:
# não povo diz brasil campanha educação milhões melhor saúde nada inflação brasileiro pesoas sp votos
# Topic 7:
# debate país esa brasil presidente dia hoje faz tá gente apoio padilha rousef bolsa via
# Topic 8:
# pt lula fez gov pf presos crisenapf pra psdb globo fazer vez jn vou asim
# CPU times: user 46.9 s, sys: 1.12 s, total: 48 s
# Wall time: 46.3 s

# %% [markdown]
# # BERT Topic

# %%
# %%time
neighbour_cluster = 10
sentence_model = SentenceTransformer('paraphrase-MiniLM-L6-v2') # paraphrase-MiniLM-L6-v2
hdbscan_model = HDBSCAN(min_cluster_size=neighbour_cluster, metric='euclidean', #min_cluster_size=10,100
                        cluster_selection_method='eom', prediction_data=True)
umap_model = UMAP(n_neighbors=neighbour_cluster, n_components=30, min_dist=0.0, metric='cosine', low_memory=True, random_state=42) # n_neighbors=15,30, 100
vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words=stop_words, min_df=5)         # min_df means "ignore terms that appear in less than n documents".

topic_model = BERTopic(#language="multilingual",
                       top_n_words=10,                                                    
                       min_topic_size=10,
                       nr_topics="auto",                                                           # Don't set nr_topics if you're already converging topics to pre-determined labels
                       low_memory=True,                                                            # If you have a big dataset set low_memory to True - but it's slower
                       calculate_probabilities=False,  # Set to False if big data
                       seed_topic_list=None,                                                       # If you want to converge to a list of your own topics
                       embedding_model=sentence_model,
                       umap_model=umap_model,
                       hdbscan_model=hdbscan_model,
                       vectorizer_model=vectorizer_model,
                       verbose=True                                                                # Get logging
                      )
# Out:
# CPU times: user 356 ms, sys: 96.4 ms, total: 452 ms
# Wall time: 8.65 s

# %%
# %%time
docs = df['content_clean'].to_list()  
topics, probs = topic_model.fit_transform(docs)
# Out:
# Batches:   0%|          | 0/3170 [00:00<?, ?it/s]
# 2022-06-03 13:38:08,912 - BERTopic - Transformed documents to Embeddings
# 2022-06-03 13:45:57,860 - BERTopic - Reduced dimensionality
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/dnelub/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 404, in _process_worker
#     call_item = call_queue.get(block=True, timeout=timeout)
#   File "/home/dnelub/.pyenv/versions/3.8.12/lib/python3.8/multiprocessing/queues.py", line 116, in get
#     return _ForkingPickler.loads(res)
# ModuleNotFoundError: No module named 'sklearn.neighbors._dist_metrics'
# """
#
# The above exception was the direct cause of the following exception:
#
# BrokenProcessPool                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/bertopic/_bertopic.py in fit_transform(self, documents, embeddings, y)
#     307
#     308         # Cluster reduced embeddings
# --> 309         documents, probabilities = self._cluster_embeddings(umap_embeddings, documents)
#     310
#     311         # Sort and Map Topic IDs by their frequency
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/bertopic/_bertopic.py in _cluster_embeddings(self, umap_embeddings, documents)
#    1415         """
#    1416         # Fit and extract labels
# -> 1417         self.hdbscan_model.fit(umap_embeddings)
#    1418         documents['Topic'] = self.hdbscan_model.labels_
#    1419
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/hdbscan/hdbscan_.py in fit(self, X, y)
#    1187             self._single_linkage_tree,
#    1188             self._min_spanning_tree,
# -> 1189         ) = hdbscan(clean_data, **kwargs)
#    1190
#    1191         if self.metric != "precomputed" and not self._all_finite:
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/hdbscan/hdbscan_.py in hdbscan(X, min_cluster_size, min_samples, alpha, cluster_selection_epsilon, max_cluster_size, metric, p, leaf_size, algorithm, memory, approx_min_span_tree, gen_min_span_tree, core_dist_n_jobs, cluster_selection_method, allow_single_cluster, match_reference_implementation, **kwargs)
#     819                 )
#     820             else:
# --> 821                 (single_linkage_tree, result_min_span_tree) = memory.cache(
#     822                     _hdbscan_boruvka_kdtree
#     823                 )(
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     350
#     351     def __call__(self, *args, **kwargs):
# --> 352         return self.func(*args, **kwargs)
#     353
#     354     def call_and_shelve(self, *args, **kwargs):
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/hdbscan/hdbscan_.py in _hdbscan_boruvka_kdtree(X, min_samples, alpha, metric, p, leaf_size, approx_min_span_tree, gen_min_span_tree, core_dist_n_jobs, **kwargs)
#     323
#     324     tree = KDTree(X, metric=metric, leaf_size=leaf_size, **kwargs)
# --> 325     alg = KDTreeBoruvkaAlgorithm(
#     326         tree,
#     327         min_samples,
#
# hdbscan/_hdbscan_boruvka.pyx in hdbscan._hdbscan_boruvka.KDTreeBoruvkaAlgorithm.__init__()
#
# hdbscan/_hdbscan_boruvka.pyx in hdbscan._hdbscan_boruvka.KDTreeBoruvkaAlgorithm._compute_bounds()
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# ~/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     442                     raise CancelledError()
#     443                 elif self._state == FINISHED:
# --> 444                     return self.__get_result()
#     445                 else:
#     446                     raise TimeoutError()
#
# ~/.pyenv/versions/3.8.12/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     387         if self._exception:
#     388             try:
# --> 389                 raise self._exception
#     390             finally:
#     391                 # Break a reference cycle with the exception in self._exception
#
# BrokenProcessPool: A task has failed to un-serialize. Please ensure that the arguments of the function are all picklable.

# %% [markdown]
# # Word2Vec Model

# %%
# %%time
#Converting the "clean_tweet" column in the format supported by embeddings.
sent = [row for row in df_pt["content_clean"]]
#use Gensim Phrases package to automatically detect common phrases (bigrams) from a list of sentences.
phrases = Phrases(sent, min_count=1, progress_per=50000)
bigram = Phraser(phrases)
sentences = bigram[sent]
sentences[100]
# Out:
# CPU times: user 1.48 s, sys: 6.93 ms, total: 1.49 s
# Wall time: 1.5 s
# 'muita gente contra #dilma emprego facilidades muita gente favor #dilma têm ctps filhos faculdadeetc'

# %%
e_sentences=[]
for i in range(0,len(sentences)):
    e_sentences.append(sentences[i].split(' '))

e_sentences
# Out:
# [['#dilma', 'recebeu', 'hj', 'atletas', 'destacaram'],
#  ['caminhada', '#dilma', '#padilha', 'santo', 'amaro'],
#  ['marina',
#   'silvacandidata',
#   'banqueiros',
#   'itau',
#   'nao',
#   'povonao',
#   'deixe',
#   'enganarvota',
#   'conscientevota',
#   '#dilma'],
#  ['não',
#   'vota',
#   'marina',
#   'silva',
#   'pro',
#   'brasil',
#   'permanecer',
#   'independente',
#   'sistema',
#   'financeiro',
#   'causou',
#   'atual',
#   'crise',
#   'econômica',
#   'mundial',
#   'vota',
#   '#dilma'],
#  ['governo',
#   'mentirosos',
#   'basta',
#   'ver',
#   'campanha',
#   '#dilma',
#   'não',
#   'honesta',
#   '#vaipracubapt',
#   '#foradilma',
#   '#abaixodecretodadilma'],
#  ['ciro',
#   'gomes',
#   'sobre',
#   'marina',
#   'silvaé',
#   'vazio',
#   'absolutoaproveita',
#   'inocencia',
#   'juventude',
#   'mal',
#   'informada',
#   'pig',
#   'vote',
#   '#dilma'],
#  ['tacalhe', 'pau', '#dilma', '🙌'],
#  ['alô',
#   'coxinha',
#   '#dilma',
#   'agraciou',
#   'sp',
#   '#maismédicos',
#   'municípios',
#   'estado',
#   'beneficiando',
#   'milhões',
#   'pessoas',
#   'suíça'],
#  ['não',
#   'representa',
#   '#marina',
#   '#dilma',
#   '#marinadeverdade',
#   '#atitudeparamudar',
#   '#brasilia',
#   '#fortaleza',
#   '#bahia',
#   '#manaus',
#   '#salvador'],
#  ['alô',
#   'coxinha',
#   '#dilma',
#   'destinou',
#   'municípios',
#   'paulo',
#   'equipamentos',
#   'retroescavadeiras',
#   'moto',
#   'niveladoras',
#   'caminhões',
#   'caçamba'],
#  ['camarada', 'não', 'preço', '#dilma', 'vamos'],
#  ['certo',
#   '#dilma',
#   'ficar',
#   'dando',
#   'entrevistas',
#   'coletivas',
#   'tão',
#   'perto',
#   'eleições'],
#  ['#dilma', 'falou', 'tá', 'falado'],
#  ['alô',
#   'coxinha',
#   '#pac',
#   '#dilma',
#   'colocou',
#   'sp',
#   'rbi',
#   'aeroportos',
#   'rbi',
#   'rodovias',
#   'além',
#   '#luzparatodos',
#   'ligações'],
#  ['#dilma', 'novooo'],
#  ['#dilma', 'povo', 'povo'],
#  ['estudei',
#   'passei',
#   'mereço',
#   'convocação',
#   'não',
#   'fácil',
#   '#chamacaixaaprovados',
#   '#dilma'],
#  ['alô',
#   'coxinha',
#   '#pac',
#   '#dilma',
#   'colocou',
#   'rbi',
#   'setor',
#   'petroleiro',
#   'rbi',
#   'mobilidade',
#   'urbana',
#   'rbi',
#   'transmissão',
#   'energia',
#   'elétrica'],
#  ['bresser', 'pereira', 'explica', 'votará', '#dilma'],
#  ['grandes',
#   'obras',
#   'mobilidade',
#   'urbana',
#   '#dilma',
#   'proporcionam',
#   'rapidez',
#   'segurança',
#   'cariocas',
#   'sala',
#   'imprensa'],
#  ['ações',
#   '#dilma',
#   'enfrentamento',
#   'seca',
#   'destaques',
#   'paraíba',
#   'sala',
#   'imprensa'],
#  ['amanhã',
#   'levará',
#   'material',
#   'candidatos',
#   'dilma',
#   'armando',
#   'joão',
#   'paulo',
#   '#dilma'],
#  ['governo',
#   '#dilma',
#   'quer',
#   'padrão',
#   'copa',
#   'segurança',
#   'pública',
#   'todo',
#   'brasil',
#   'sala',
#   'imprensa'],
#  ['juventude', '#dilma'],
#  ['alô',
#   'coxinha',
#   '#dilma',
#   'investiu',
#   'paulo',
#   'cerca',
#   'rbilhões',
#   'menina',
#   'olhos',
#   'tucanos',
#   'rodoanel',
#   'leste',
#   'r',
#   'bilhões',
#   'bndes'],
#  ['presidenta', '#dilma', 'sendo', 'aclamada', 'povo'],
#  ['#dilma',
#   'rousseff',
#   'faz',
#   'críticas',
#   'bolsistas',
#   'reprovados',
#   'ciências',
#   'presidente',
#   'comenta',
#   'nota',
#   'universi'],
#  ['exatamente', 'presidenta', '#dilma'],
#  ['sente', 'coitadinho', 'não', 'pode', 'ser', 'presidente', 'diz', '#dilma'],
#  ['marina',
#   'hein',
#   'usou',
#   'discursos',
#   'chavões',
#   'futebolísticos',
#   'agora',
#   'cinéfilos',
#   '#dilmadenovo',
#   '#dilmaemalta',
#   '#dilma'],
#  ['não', 'atacado', 'divirjo', 'diz', '#dilma'],
#  ['#dilma',
#   'deveria',
#   'ser',
#   'garota',
#   'propaganda',
#   'tse',
#   'perguntada',
#   'sobre',
#   'escândalo',
#   'petrobras',
#   'fica',
#   'blá',
#   'blá',
#   'blá',
#   'blá'],
#  ['#dilma',
#   'deveria',
#   'ser',
#   'garota',
#   'propaganda',
#   'tse',
#   'perguntada',
#   'sobre',
#   'escândalo',
#   'petrobras',
#   'fica',
#   'blá',
#   'blá',
#   'blá',
#   'blá',
#   'blá'],
#  ['#dilma',
#   'ganhar',
#   'eleições',
#   'vai',
#   'ser',
#   'cima',
#   'muita',
#   'mentira',
#   'povo',
#   'brasileiro',
#   'iludido',
#   'mundo',
#   '#foradilma',
#   '#forapt'],
#  ['contigo', 'presidenta', '#dilma'],
#  ['“', 'toda', 'conquista', 'novo', 'começo', '”', 'diz', '#dilma', 'record'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina', 'queda'],
#  ['#dilma', 'dispara', 'frente', '#marina'],
#  ['caminho',
#   'certo',
#   'presidenta',
#   '#dilma',
#   'contigo',
#   'outra',
#   'vez',
#   'brasil',
#   'seguir',
#   'frente'],
#  ['segundo',
#   '#datafolha',
#   'brasileiro',
#   'acha',
#   'governo',
#   '#dilma',
#   'ótimo',
#   'regular',
#   'aprova',
#   'governo',
#   'mudar'],
#  ['contigo', 'presidenta', '#dilma', 'arretada'],
#  ['uso',
#   'máquina',
#   'pública',
#   '#pt',
#   'propaganda',
#   '#dilma',
#   'crime',
#   'eleitoral',
#   'grave',
#   'gente',
#   'absurdo'],
#  ['dona',
#   '#dilma',
#   'n',
#   'queira',
#   'receber',
#   'bonus',
#   'dizendo',
#   'pfe',
#   'lembrese',
#   'pf',
#   'paga',
#   'brasileiros',
#   'pra',
#   'n',
#   'ptcalada'],
#  ['descarado',
#   'uso',
#   'máquina',
#   'pública',
#   'campanha',
#   'eleitoral',
#   '#pt',
#   '#dilma'],
#  ['dona',
#   '#dilma',
#   'pense',
#   'bem',
#   'antes',
#   'falar',
#   'prc',
#   'tendo',
#   'trabalhado',
#   'govfhc',
#   'venda',
#   'pasadena',
#   'corrupcoes',
#   'oorreu',
#   'govptista'],
#  ['#dilma', 'toda', 'mudança', 'começo'],
#  ['#dilma',
#   'mulher',
#   'fibra',
#   'gestora',
#   'incontestável',
#   'mãe',
#   '#pac',
#   'enfrenta',
#   'dia',
#   'dia',
#   'milhares',
#   'covardes',
#   '#pig',
#   'escondem',
#   'atrás',
#   'jornais'],
#  ['tá',
#   'preocupada',
#   'presidente',
#   '#dilma',
#   'vai',
#   'pedir',
#   '#stf',
#   'acesso',
#   'depoimento',
#   'exdiretor',
#   '#petrobras',
#   'pf'],
#  ['presidente',
#   '#dilma',
#   'vai',
#   'pedir',
#   '#stf',
#   'acesso',
#   'depoimento',
#   'exdiretor',
#   '#petrobras',
#   'paulo',
#   'roberto',
#   'costa',
#   'polícia',
#   'federal'],
#  ['#padilha', '#', '#dilma', 'brasil', 'continuar', 'crescendo'],
#  ['fantasmas',
#   'gafanhotos',
#   'voltam',
#   'assombrar',
#   'reeleição',
#   'beto',
#   'richa',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#globo',
#   '#jn'],
#  ['viralizam',
#   'fotos',
#   'ª',
#   'dama',
#   'fernanda',
#   'richa',
#   'jantar',
#   'suspenso',
#   'blitz',
#   'tre',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#globo',
#   '#jn'],
#  ['dilma',
#   'diz',
#   'caso',
#   'correios',
#   'factoide',
#   'campanha',
#   'saiba',
#   '#dilma',
#   '#correios'],
#  ['mentem',
#   'descaradamente',
#   '#juventude',
#   'precisa',
#   'saber',
#   'país',
#   'governado',
#   'pe',
#   'pres',
#   '#dilma',
#   'rede',
#   'globo',
#   'nao',
#   'divulga'],
#  ['#dilma',
#   'diz',
#   'especulação',
#   'limite',
#   'ridículo',
#   'associar',
#   'reuters',
#   'brasil'],
#  ['obras',
#   'eixo',
#   'energia',
#   'pac',
#   'concluídas',
#   'cadê',
#   'mãe',
#   'pac',
#   '#dilma'],
#  ['cut', 'proposta', '#dilma', 'emprego', 'renda', 'outros', 'desemprego'],
#  ['#dilma',
#   'influência',
#   'pesquisa',
#   'eleitoral',
#   '#bolsa',
#   'ridícula',
#   'gt',
#   'entende',
#   '#nada',
#   'economia',
#   'logo',
#   'vê'],
#  ['#dilma',
#   'diz',
#   'alguns',
#   'estudantes',
#   'desmerecem',
#   'país',
#   'dilma',
#   'rousseff',
#   'afirmou',
#   'nesta',
#   'sextafeira',
#   'durante',
#   'co'],
#  ['toda',
#   'vida',
#   'frente',
#   'hermano',
#   'quer',
#   'falem',
#   'jamais',
#   'parecerá',
#   'viva',
#   'chavez',
#   'viva',
#   '#dilma',
#   'viva',
#   '#lula'],
#  ['#dilma',
#   'políticas',
#   'incentivo',
#   'preparam',
#   'atletas',
#   'brasileiros',
#   'olimpíadas',
#   'sala',
#   'imprensa'],
#  ['juventude',
#   'começa',
#   'espertar',
#   'pleito',
#   'passado',
#   'anos',
#   'tirou',
#   'título',
#   'pra',
#   'votar',
#   '#dilma'],
#  ['amanhã',
#   '#dilma',
#   'participa',
#   'caminhada',
#   'paulo',
#   'santo',
#   'amaro',
#   'sala',
#   'imprensa'],
#  ['hoje', 'ato', '#dilma', 'baixada', 'fluminense'],
#  ['#dilma',
#   'estratosferainalcançáveluns',
#   'pontos',
#   'acima',
#   'damelhor',
#   'performance',
#   'pesquisasnósvestidos',
#   'vermelho',
#   'paixãoltvalente'],
#  ['dilma',
#   'diz',
#   'caso',
#   'correios',
#   'factoide',
#   'campanha',
#   '#dilma',
#   '#política',
#   '#hojeemdia'],
#  ['rt', 'não', 'voto', '#dilma', '#eleicao', '#brasil', 'pt', '#eleicoes'],
#  ['#dilma',
#   'certa',
#   'não',
#   'invisto',
#   'bovespa',
#   'meio',
#   'rico',
#   'especulador',
#   'manter',
#   'luxo',
#   'dinheiro',
#   'trabalhador'],
#  ['feldman',
#   'diz',
#   '#dilma',
#   'votos',
#   'dependência',
#   'verdadedependentes',
#   'moradiassaúdeeducaçãoculturaempregosdignidade',
#   'cidadã'],
#  ['sim',
#   '#dilma',
#   'lula',
#   'subjacente',
#   'tudo',
#   'projeto',
#   'social',
#   'sintetizado',
#   'discurso',
#   'posse',
#   '#lula',
#   'jan'],
#  ['#dilma',
#   'pedirá',
#   '#stf',
#   'acesso',
#   '#depoimento',
#   '#delator',
#   'gt',
#   '#medo',
#   'óbvio',
#   '#stf',
#   'vai',
#   '#conceder'],
#  ['boa',
#   'notícia',
#   'pra',
#   '#dilma',
#   'não',
#   'elevar',
#   'juros',
#   'fed',
#   'frustra',
#   'oposição',
#   'tupiniquim',
#   'catastrofista'],
#  ['#dilma', 'obrigado', 'trem', 'bala'],
#  ['tanto',
#   'calor',
#   'vou',
#   'banhar',
#   'igarapé',
#   'sabonete',
#   'biodegradável',
#   'pra',
#   'ser',
#   'sustentável',
#   'opiniões',
#   '#eleicoes',
#   '#dilma',
#   '#aecio'],
#  ['vou',
#   'soltar',
#   'coque',
#   'menos',
#   'cabelo',
#   'armado',
#   'proteje',
#   'queda',
#   '#perdendomaispontosqueogoias',
#   '#eleicoes',
#   '#marinasilva',
#   '#dilma',
#   '#aecio'],
#  ['#dilma',
#   'quer',
#   'saber',
#   'alista',
#   'petrolão',
#   '#',
#   'siga',
#   'tweeter',
#   'todo',
#   'brasil',
#   'sabe'],
#  ['presidente',
#   'comitê',
#   'paralímpico',
#   'brasileiro',
#   'defende',
#   'reeleição',
#   'dilma',
#   '#dilma',
#   '#política'],
#  ['#dilma',
#   'pedirá',
#   'stf',
#   'acesso',
#   'depoimento',
#   'paulo',
#   'roberto',
#   'costa',
#   'jornal',
#   'brasil'],
#  ['toda',
#   'conquista',
#   'novo',
#   'começo',
#   '“',
#   'toda',
#   'conquista',
#   'novo',
#   'começo',
#   '”',
#   'diz',
#   '#dilma',
#   'record',
#   '”',
#   'disse',
#   'presidenta',
#   'dilma'],
#  ['#dilma',
#   'fundos',
#   'pensão',
#   'vão',
#   'cair',
#   'nessa',
#   'ceo',
#   'odebrecht',
#   'ambiental',
#   'diz',
#   'empresa',
#   'planeja',
#   'ipo'],
#  ['#dilma',
#   'lixo',
#   'pt',
#   'podem',
#   'chegar',
#   'ganhar',
#   'eleição',
#   'não',
#   'voto'],
#  ['adorei', 'entrevista', 'rede', 'record', '#dilma'],
#  ['vamos', 'deixar', '#dilma', 'onde', '#dilma', 'novo'],
#  ['#juventude',
#   'precisa',
#   'saber',
#   'país',
#   'governado',
#   'presidenta',
#   '#dilma',
#   'rede',
#   'globo',
#   'nao',
#   'divulga'],
#  ['olha', '#dilma', 'treinando', 'dança', 'break', 'juventude', 'adorou'],
#  ['presidenta', 'pluralidade', 'cultural', '#dilma'],
#  ['grande',
#   'notícia',
#   'políticas',
#   'sociais',
#   'vitoriosas',
#   'governos',
#   '#lula',
#   '#dilma',
#   'brasil',
#   'destacou',
#   'combate'],
#  ['deixem', 'mulher', '#dilma', 'trabalhar'],
#  ['#dilma',
#   '#minhacasamelhor',
#   'crédito',
#   'facilitado',
#   'p',
#   'compra',
#   'móveis',
#   'eletrodomésticos',
#   'injeta',
#   'r',
#   'bilhões',
#   'economia'],
#  ['sempre',
#   'somando',
#   'apoios',
#   '#dilma',
#   'agora',
#   'leonardo',
#   'boff',
#   'bem',
#   'vindo',
#   'abraço'],
#  ['#dilma',
#   'conhece',
#   '#minhacasaminhavida',
#   'rural',
#   'entregues',
#   'mil',
#   'casas',
#   'campo',
#   'ampliado'],
#  ['metade', 'mim', 'vota', '#dilma', 'outra', 'metade'],
#  ['#dilma',
#   '#minhacasaminhavida',
#   'garante',
#   'moradia',
#   'digna',
#   'milhões',
#   'brasileiros',
#   'ampliado'],
#  ['lembrar', '#marinacensuradia', '#marinacensura', '#dilmadenovo', '#dilma'],
#  ['todo', 'mundo', 'apenas', 'paises', 'mapa', 'fome', 'brasil', '#dilma'],
#  ['brasil', 'maior', 'rede', 'proteção', 'social', 'mundo', '#dilma'],
#  ['discurso',
#   'prática',
#   '#marinacensuradia',
#   '#dilmadenovo',
#   '#dilma',
#   '#marinacensura'],
#  ['brasil',
#   'hoje',
#   'primeira',
#   'geração',
#   'crianças',
#   'nascendo',
#   'crescendo',
#   'livre',
#   'miseria',
#   'fome',
#   '#dilma'],
#  ['não',
#   'quero',
#   'entender',
#   'marina',
#   'levaria',
#   'tempo',
#   'eou',
#   'talvez',
#   'impossível',
#   'quero',
#   'sempre',
#   'ir',
#   'vida',
#   'clarividencia',
#   'vou',
#   '#dilma'],
#  ['não', 'erro', 'urnas', 'escolha', '#dilma', 'novo'],
#  ['muita',
#   'gente',
#   'contra',
#   '#dilma',
#   'emprego',
#   'facilidades',
#   'muita',
#   'gente',
#   'favor',
#   '#dilma',
#   'têm',
#   'ctps',
#   'filhos',
#   'faculdadeetc'],
#  ['aqui',
#   'mulheres',
#   'mandam',
#   'mandem',
#   'candidatas',
#   'apoiam',
#   '#dilma',
#   'divulgaremos',
#   '#dilma'],
#  ['presidente',
#   'lula',
#   'colocou',
#   'fome',
#   'miseria',
#   'agenda',
#   'politica',
#   'brasil',
#   '#dilma'],
#  ['#dilma', 'espalhada', 'todo', 'brasil', 'guerreira', 'viva'],
#  ['boa', 'tarde', 'aqui', 'emplastadas', '#dilma'],
#  ['escândalo',
#   'envolvendo',
#   '#dilma',
#   'corja',
#   '#pt',
#   'não',
#   'nenhum',
#   'respeito',
#   'brasil',
#   'instituições',
#   'povo'],
#  ['vamos', 'assim', '#dilma', 'presidenta', '#dilma'],
#  ['boa',
#   'tarde',
#   'vamos',
#   'aguardar',
#   'ver',
#   'percentual',
#   'aceitação',
#   '#dilma',
#   'eleitores'],
#  ['gestão',
#   'petista',
#   '#dilma',
#   'não',
#   'ñ',
#   'engavetador',
#   'processos',
#   'contra',
#   'políticos'],
#  ['rt', 'proposta', '#dilma', 'emprego', 'renda', 'outros', 'desemprego'],
#  ['datafolha', '#dilma', 'amplia', 'vantagem', 'sobre', 'marina'],
#  ['vamos',
#   '#dilma',
#   'praças',
#   'parques',
#   'praias',
#   'neste',
#   'final',
#   'semana'],
#  ['#eunício',
#   '#marina',
#   '#dilma',
#   '#capwagner',
#   '#lulamorais',
#   '#cabosabino',
#   '#chicolopes',
#   '#luizianne',
#   'votos',
#   'família',
#   'democracia',
#   'respeito',
#   'todos'],
#  ['#dilma',
#   'abre',
#   'vantagem',
#   'sobre',
#   '#marina',
#   'aécio',
#   'esboça',
#   'reação'],
#  ['daqui',
#   'pouco',
#   '#dilma',
#   'fala',
#   'imprensa',
#   'entrevista',
#   'coletiva',
#   'sala',
#   'imprensa'],
#  ['#bomba',
#   'eduardo',
#   'campos',
#   'acusa',
#   '#dilma',
#   'fazer',
#   'terrorismo',
#   'bolsa',
#   'família',
#   '…'],
#  ['#dilma',
#   'recebe',
#   'voto',
#   'frei',
#   'betto',
#   'luta',
#   'contra',
#   'escravidão',
#   'brasil'],
#  ['sei', 'acredito', 'completa', 'lisura', 'presidenta', '#dilma'],
#  ['datafolha', '#dilma', '#rejeição', 'dilma', 'intenção', 'voto'],
#  ['dilma', 'amplia', 'vantagem', 'sobre', 'marina', '#dilma', '#pt'],
#  ['governo', '#dilma', 'brasil', 'deixa', 'mapa', 'fome', 'segundo', 'onu'],
#  ['#dilma', 'inclui', 'programa', 'capítulo', 'sobre', 'gestão', 'pública'],
#  ['#brasil',
#   'não',
#   'jeito',
#   '#dilma',
#   '#aécio',
#   '#marina',
#   'resolvem',
#   'esculhambação',
#   'problema',
#   'falta',
#   'caráter',
#   'vergonha',
#   'cara'],
#  ['aonde', '#dilma'],
#  ['datafolha', 'dilma', 'marina', 'aécio', '#dilma', '#pt', '#lula'],
#  ['gt',
#   'chorosos',
#   'pessimistas',
#   'buscam',
#   'cada',
#   'vez',
#   'pêlo',
#   'ovo',
#   'lt',
#   'contra',
#   'haddad',
#   '#dilma',
#   'gté',
#   'lamentável',
#   'catendem',
#   'patrões'],
#  ['dados',
#   '#pnad',
#   'não',
#   'mostram',
#   'nenhuma',
#   'novidade',
#   'analfabetismo',
#   'desemprego',
#   'concentração',
#   'renda',
#   'dona',
#   '#dilma',
#   'fez',
#   'bom',
#   'trabalho'],
#  ['brasileiro', 'burro', 'vota', '#dilma', 'rt', 'dilma', 'marina', 'aécio'],
#  ['desastre', 'rt', 'dilma', 'marina', 'aécio', 'tudo', 'menos', '#dilma'],
#  ['#lula',
#   '#dilma',
#   'assumiram',
#   'existia',
#   'brasil',
#   'energia',
#   'elétricagt',
#   'muuuitos',
#   'analfabetosgt',
#   '#globocalaaboca'],
#  ['#dilma',
#   'mostra',
#   'plano',
#   'governo',
#   '#ėmarina',
#   '#marinadeverdade',
#   '#coragempramudar'],
#  ['#dilma',
#   'vai',
#   'marina',
#   'cai',
#   'primeiro',
#   'turno',
#   'diz',
#   'reuters',
#   'brasil'],
#  ['dilma',
#   'representa',
#   'penso',
#   'todos',
#   'não',
#   'mim',
#   '#dilmadenovo',
#   '#dilmamaiseducação',
#   '#dilma'],
#  ['não',
#   'sei',
#   'cidadão',
#   'sã',
#   'consciência',
#   'vota',
#   '#dilma',
#   'além',
#   'fantoche',
#   'lula',
#   'destrói',
#   'país',
#   'corrupção'],
#  ['operação',
#   'porto',
#   'seguro',
#   'denuncia',
#   'lula',
#   '#marina',
#   '#dilma',
#   '#fortaleza',
#   '#brasilia',
#   '#ceara',
#   '#acre'],
#  ['marina',
#   'mora',
#   'favor',
#   'ap',
#   'dum',
#   'cara',
#   'dem',
#   'enrolado',
#   'justiça',
#   'voa',
#   'jato',
#   'fantasma',
#   'censura',
#   'site',
#   'imagina',
#   'gritaria',
#   '#dilma',
#   'faz'],
#  ['marina',
#   'muda',
#   'opinião',
#   'facilidade',
#   'número',
#   'mágico',
#   'deste',
#   'primeiro',
#   'turno',
#   '#dilma'],
#  ['ibge',
#   'veio',
#   'mostrar',
#   'classe',
#   'c',
#   'não',
#   'c',
#   '#lula',
#   '#dilma',
#   '#mudamaisbrasil',
#   '#valeudilma',
#   '#obrigadolula'],
#  ['desigualdade', 'continua', 'queda', 'brasil', 'tacalhe', 'pau', '#dilma'],
#  ['marina', 'direitos', 'trabalhistas', 'tacalhe', 'pau', '#dilma'],
#  ['dilma',
#   'sobre',
#   'bláblá',
#   'nunca',
#   'sei',
#   'pensa',
#   'tacalhe',
#   'pau',
#   '#dilma'],
#  ['dilma',
#   'reeleita',
#   'garantia',
#   'manutenção',
#   'direitos',
#   'sociais',
#   'trabalhistas',
#   'tacalhe',
#   'pau',
#   '#dilma'],
#  ['nda',
#   'dsso',
#   'vmos',
#   'pra',
#   'luta',
#   'fr',
#   'presidente',
#   'espero',
#   'sja',
#   '#dilma'],
#  ['#aecio',
#   '#dilma',
#   '#marina',
#   'participassem',
#   'pgm',
#   'queria',
#   'ver',
#   'iria',
#   'querer',
#   'time',
#   'kkkk'],
#  ['petrobras',
#   'paulo',
#   'roberto',
#   'costa',
#   'diz',
#   'propina',
#   'compra',
#   'pasadena',
#   '#dilma'],
#  ['marina',
#   'silva',
#   'reduzirá',
#   'poder',
#   'bancos',
#   'publicos',
#   'favorecendo',
#   'itau',
#   'amiga',
#   'neca',
#   'bancos',
#   'privadosnao',
#   'deixe',
#   'enganarvota',
#   '#dilma'],
#  ['industria',
#   'naval',
#   'faliu',
#   'anos',
#   'lula',
#   'dilma',
#   'resgataram',
#   'elasendo',
#   'hoje',
#   'quarta',
#   'maior',
#   'mundonao',
#   'deixe',
#   'enganar',
#   'vote',
#   '#dilma'],
#  ['pesquisa', 'mídia', 'não', 'mostra', 'carta', 'maior', '#dilma'],
#  ['“',
#   'dez',
#   'anos',
#   'suficientes',
#   'pra',
#   'corrigir',
#   'desigualdade',
#   'gerada',
#   'séculos',
#   '”',
#   'portal',
#   'fórum',
#   '#dilma'],
#  ['rt',
#   'dou',
#   'vida',
#   'brasil',
#   'continuar',
#   'nesse',
#   'rumo',
#   'rumo',
#   'certo',
#   '#dilma'],
#  ['#dilma',
#   '#pmdb',
#   '#guarujá',
#   'garante',
#   '#habitação',
#   '#saúde',
#   '#educação',
#   '#brasil'],
#  ['#dilma',
#   'apoio',
#   'alguns',
#   'artistas',
#   '#marina',
#   'melhores',
#   'artistas',
#   'povo',
#   'brasileiro',
#   '#fortaleza'],
#  ['marina',
#   'silva',
#   'favorável',
#   'lei',
#   'tira',
#   'royalties',
#   'rio',
#   'eleições',
#   'dia',
#   'via',
#   '#dilma'],
#  ['pt',
#   'tirou',
#   'brasil',
#   'mapa',
#   'fome',
#   'onu',
#   'psdb',
#   'marina',
#   'querem',
#   'tirar',
#   'pt',
#   'mapa',
#   'brasilé',
#   'fome',
#   'poder',
#   '#dilma'],
#  ['#dilma',
#   'sérios',
#   'problemas',
#   'enquanto',
#   'estadista',
#   'fhc',
#   'derrubava',
#   'plataforma',
#   'p',
#   'inaugura',
#   'assim',
#   'não',
#   'dá'],
#  ['#dilma',
#   'apoio',
#   'alguns',
#   'artistas',
#   '#marina',
#   'apoio',
#   'povo',
#   '#marinaemfortaleza',
#   '#brasilia',
#   '#atitudeparamudar'],
#  ['lulasou',
#   'cabo',
#   'eleitoral',
#   '#dilma',
#   'vou',
#   'pra',
#   'rua',
#   'fazer',
#   'campanha'],
#  ['pig',
#   'oposição',
#   '#dilma',
#   'faça',
#   'vão',
#   'continuar',
#   'ignorando',
#   'boicotando',
#   'mentindo',
#   'jogando',
#   'cara',
#   'falta',
#   'fazer',
#   'tudo'],
#  ['cretinos',
#   'rádio',
#   'estadão',
#   'governo',
#   '#dilma',
#   'não',
#   'faz',
#   'obras',
#   'kkkk'],
#  ['brasil',
#   'caminho',
#   'certo',
#   'acabando',
#   'miséria',
#   'brasil',
#   'nao',
#   'pa',
#   'todos',
#   'nao',
#   'p',
#   'ninguem',
#   '#dilma'],
#  ['dou',
#   'vida',
#   'brasil',
#   'continuar',
#   'nesse',
#   'rumo',
#   'rumo',
#   'certo',
#   '#dilma'],
#  ['marina',
#   'censura',
#   'crítica',
#   'bc',
#   'independente',
#   'vez',
#   'defendêlo',
#   'programa',
#   '#dilma',
#   '#pt'],
#  ['vergonha',
#   'país',
#   'vergonha',
#   '#dilma',
#   '#copa',
#   '#preisdentadilma',
#   '#futebol',
#   '#copadomundo',
#   '…'],
#  ['não',
#   'receberá',
#   'pcampanha',
#   'rmil',
#   'unimed',
#   'operadoras',
#   'cplanos',
#   'suspensosans',
#   '#dilma',
#   '#lula',
#   '#psdb'],
#  ['mídia',
#   'concentrada',
#   'dá',
#   'marinho',
#   'us',
#   'bilhões',
#   '#dilma',
#   '#pt',
#   '#lula'],
#  ['eleição',
#   'passar',
#   '#dilma',
#   'ficar',
#   'brasil',
#   'campeão',
#   'quero',
#   'ver',
#   'black',
#   'pagos',
#   'entregarem',
#   'falta',
#   'pagamentos',
#   'contratantes'],
#  ['“',
#   'discurso',
#   'medo',
#   '”',
#   'psdb',
#   'usou',
#   'hoje',
#   'faz',
#   'sentido',
#   '#dilma',
#   '#pt',
#   '#lula'],
#  ['rt',
#   '#choraaecio',
#   'mg',
#   '#dilma',
#   'pmdb',
#   'mg',
#   'sp',
#   'fecham',
#   'apoio',
#   'dilma',
#   'brasil'],
#  ['aloisyo',
#   '#psdb',
#   'manda',
#   'suíça',
#   'pqp',
#   'vezes',
#   'descoberta',
#   'nova',
#   'conta',
#   'secreta',
#   'trensalão',
#   '#dilma',
#   '#lula',
#   '#pt',
#   '#vaitercopa'],
#  ['#choraaecio',
#   'minas',
#   '#dilma',
#   'pmdb',
#   'minas',
#   'sp',
#   'fecham',
#   'apoio',
#   'dilma',
#   'brasil'],
#  ['“',
#   '#lula',
#   '#dilma',
#   'trouxa',
#   'vai',
#   'votar',
#   '#pt',
#   'ano',
#   '#forapt',
#   '#foradilma',
#   '#foralula',
#   'não',
#   'vote',
#   'pt'],
#  ['blogueiro',
#   'pará',
#   'estoura',
#   'mensalão',
#   'psdb',
#   'estado',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['barbosa',
#   'sociopata',
#   'mundo',
#   'jurídico',
#   'agora',
#   'rechaça',
#   'unanimidade',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['kakay',
#   'barbosa',
#   'quis',
#   'vingar',
#   'plenário',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['brasil',
#   'bolsa',
#   'família',
#   '“',
#   'padrão',
#   'fifa',
#   '”',
#   'marinho',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['apareceu',
#   '“',
#   'gambiarra',
#   '”',
#   'hídrica',
#   'alckmin',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['gigantes',
#   'própria',
#   'natureza',
#   '#dilma',
#   '#integraçãosãofrancisco',
#   '#vaidilma',
#   '#velhochico'],
#  ['pedir',
#   '#dilma',
#   'papuda',
#   '#escroque',
#   '#farsa',
#   'sindical',
#   'vira',
#   'alvo',
#   'brasil',
#   'via'],
#  ['camisa',
#   'oficial',
#   '#brasil',
#   '#copa',
#   '#vergonhadomeubrasil',
#   '#dilma',
#   '#pt'],
#  ['#dilma', 'veta', 'medida', 'reduziria', 'valor', 'multas'],
#  ['faz',
#   'dias',
#   'conivente',
#   'massacre',
#   'mata',
#   'censura',
#   'fere',
#   'manifestantes',
#   'venezuela',
#   '#dilma',
#   '#maduro'],
#  ['#dilma',
#   'pergunta',
#   'vai',
#   'colocar',
#   'exercicito',
#   'p',
#   'trabalhar',
#   'lugar',
#   'aeroviários'],
#  ['precisamos', 'quantos', 'pessoas', 'acabar', 'brasil', 'hm', '#dilma'],
#  ['bem',
#   'vindo',
#   'brasil',
#   'y',
#   '#governodilma',
#   '#democracia',
#   '#liberdade',
#   '#cidadania',
#   '#dilma',
#   '#vaitercopa',
#   '#copadomundo'],
#  ['governo',
#   'sp',
#   '#psdb',
#   'gastou',
#   'publicidade',
#   'educação',
#   'segurança',
#   '#dilma',
#   '#lula',
#   '#pt',
#   '#vaitercopa'],
#  ['#dilma',
#   '#lula',
#   'quebraram',
#   'grandes',
#   'tabus',
#   'seca',
#   'nordeste',
#   'fim',
#   'extrema',
#   'miséria',
#   'saúde',
#   'todos'],
#  ['#dilma', 'motivo', 'progresso', '#vaidilma'],
#  ['#dilma', 'motivo', 'orgulho'],
#  ['parabéns',
#   '#dilma',
#   'rousseff',
#   '#vetou',
#   '#perdão',
#   'dois',
#   'bilhões',
#   'reais',
#   'deputados',
#   'senadores',
#   'queria',
#   'dá',
#   '#planos',
#   'milionários',
#   'saúdegt'],
#  ['bom',
#   'estude',
#   'investigue',
#   'procure',
#   'saber',
#   'sobre',
#   'grande',
#   'mulher',
#   '#dilma',
#   'vai',
#   'constatar'],
#  ['dilma',
#   'ignora',
#   'brasil',
#   'rural',
#   'veta',
#   'fim',
#   'emplacamento',
#   'licenciamento',
#   'veículos',
#   'agrícolas',
#   '#dilma',
#   '#rural'],
#  ['dilma',
#   'vira',
#   'alvo',
#   'aécio',
#   'campos',
#   'durante',
#   'marcha',
#   'prefeitos',
#   'leia',
#   '#dilma',
#   '#alvo'],
#  ['ganhou', '#respeito', 'eai', '#dilma'],
#  ['atraso',
#   'geral',
#   'gestão',
#   '#dilma',
#   'fará',
#   'brasil',
#   'passar',
#   'vergonha',
#   '#copa',
#   'diz',
#   'líder',
#   '#apagãodegestão',
#   '#copa',
#   '#eleições'],
#  ['notícia',
#   'boa',
#   '#dilma',
#   '#educação',
#   'mec',
#   'autoriza',
#   'vagas',
#   'novos',
#   'cursos',
#   'engenharia',
#   '#fb'],
#  ['sempre',
#   'lembro',
#   'correntinha',
#   'ouro',
#   'virou',
#   'puro',
#   'nóno',
#   'brasil',
#   'desenosou',
#   'ainda',
#   'nó',
#   'frente',
#   '#dilma'],
#  ['#dilma',
#   'corrupta',
#   'gestão',
#   'temerária',
#   'petrobras',
#   'fachada',
#   'lavagens',
#   'desvios',
#   '…'],
#  ['pode', '#ptqpariu', '#forapt', '#dilma'],
#  ['video',
#   '#dilma',
#   'rousseff',
#   'visita',
#   'obras',
#   'projeto',
#   'integração',
#   'rio',
#   'francisc',
#   'via'],
#  ['video',
#   '#dilma',
#   'cabrobó',
#   'estação',
#   'bombeamento',
#   'água',
#   'vai',
#   'beneficiar',
#   'milhões',
#   'pessoas',
#   'r',
#   'via'],
#  ['reta',
#   'final',
#   'mandato',
#   '#dilma',
#   'lançará',
#   'licitações',
#   'tentar',
#   'tirar',
#   'papel',
#   'obras',
#   'todas',
#   'regiões',
#   'paíshoje',
#   'dia'],
#  ['#dilma',
#   'programa',
#   'acadêmico',
#   'levará',
#   'jovens',
#   'negros',
#   'indígenas',
#   'estudarem',
#   'universidades',
#   'exterior'],
#  ['#dilma',
#   'creches',
#   'inauguradas',
#   'municípios',
#   'rio',
#   'grande',
#   'sul',
#   'novo',
#   'hamburgo',
#   'canoas'],
#  ['#dilma',
#   'rousseff',
#   'garante',
#   '•',
#   'eixo',
#   'transposição',
#   'paraíba',
#   '#rasil',
#   'via',
#   '@rnpbse',
#   'dica',
#   '@cacobrasil',
#   '”'],
#  ['criação',
#   'milhões',
#   'empregos',
#   'gov',
#   '#dilma',
#   '#lula',
#   'reduziu',
#   'desigualdade',
#   'social',
#   'brasil'],
#  ['fodasso',
#   'além',
#   'triste',
#   'revoltante',
#   'welcome',
#   'to',
#   '#brazil',
#   '#world',
#   '#cup',
#   '#fifa',
#   '#lula',
#   '#dilma',
#   '#aecio'],
#  ['todos', 'sabem', 'acabar', 'brasil', 'preciso', '#dilma', 'pessoa'],
#  ['vamos',
#   'ter',
#   'beber',
#   'água',
#   'morta',
#   '#caralho',
#   '#dilma',
#   '#fora',
#   '#pt'],
#  ['vejam', 'maracutaias', '#petralhas', '#lula', '#dilma'],
#  ['centenas',
#   'prefeitos',
#   'brasília',
#   'presidenta',
#   '#dilma',
#   'não',
#   'evento',
#   'além',
#   'fugir',
#   'povo',
#   'agora',
#   'foge',
#   'prefeitos',
#   '#pt'],
#  ['#dilma',
#   'veta',
#   'fim',
#   'emplacamento',
#   'veículos',
#   'agrícolas',
#   'agricultura',
#   'ruralbr'],
#  ['invés',
#   '#dilma',
#   'pagar',
#   'salario',
#   'professores',
#   'pra',
#   'mim',
#   'não',
#   'ter',
#   '#greve',
#   'prefere',
#   'construir',
#   'estádios'],
#  ['#dilma', 'mil', 'trabalhadores', 'situação', 'escravidão', 'resgatados'],
#  ['#bandida', '#dilma', '#pt', '#brasil', '@', 'pau', 'ferro', 'rn'],
#  ['#dilma',
#   'autoriza',
#   'abertura',
#   'vagas',
#   'cursos',
#   'medicina',
#   'universidades',
#   'federais'],
#  ['rt',
#   'desgoverno',
#   '#dilma',
#   '#pt',
#   'renan',
#   'segue',
#   'impedindo',
#   'qualquer',
#   'investigação',
#   'cont'],
#  ['#dilma',
#   'visita',
#   'obras',
#   'rio',
#   'francisco',
#   'petistas',
#   'elogiam',
#   '“',
#   'revolução',
#   '”',
#   'segurança',
#   'hídrica'],
#  ['#dilma',
#   'corrupta',
#   'gestão',
#   'temerária',
#   'petrobras',
#   'fachada',
#   'lavagens',
#   'desvios',
#   '#petroralo'],
#  ['presidenta', '#dilma', 'recebe', 'homenagem', 'foz'],
#  ['rt', '#dilma', 'defendendo', 'direitos', 'manos', 'dimenor'],
#  ['presidenta',
#   '#dilma',
#   'recebe',
#   'homenagem',
#   'foz',
#   'nilce',
#   'triznina',
#   'franciellemilenamarta',
#   'helena',
#   'reisana',
#   'alves'],
#  ['pt',
#   'vai',
#   'tv',
#   'vídeo',
#   'sobre',
#   'fantasmas',
#   'passado',
#   'brasil',
#   'via',
#   'contra',
#   'retrocesso',
#   'vote',
#   '#dilma',
#   '#pt'],
#  ['brasileiro',
#   'não',
#   'humilhado',
#   'estrangeiros',
#   '#dilma',
#   'outros',
#   'componentes',
#   'circo',
#   'brasil'],
#  ['contra',
#   'fantasmas',
#   'passado',
#   '#eutôcomela',
#   '#prafazermaisemelhor',
#   '#dilma'],
#  ['morri', '#dilma'],
#  ['sabe', '#dilma', 'não', 'casa', 'difícil', 'encontrar', 'homem', 'homem'],
#  ['não',
#   'fatalista',
#   'gente',
#   'querendo',
#   'comer',
#   'partes',
#   '#dilma',
#   '#agoraetarde',
#   '😂',
#   '😂'],
#  ['simplesmente',
#   'melhor',
#   'parte',
#   '#dilma',
#   'rafinhabastos',
#   'gustavommendes',
#   '#agoraétarde',
#   '😂',
#   '😂',
#   '😂',
#   '👊',
#   '👏',
#   '❤',
#   '️',
#   '👌'],
#  ['espero',
#   'ver',
#   'dia',
#   'outubro',
#   '#dilma',
#   'reeleita',
#   'º',
#   'turno',
#   '#pt',
#   'maior',
#   'surto',
#   'geral',
#   'desta',
#   'gente'],
#  ['#alexnaband',
#   'trabalho',
#   'pro',
#   'cara',
#   '#dilma',
#   '#dilmaravilhosaresponde'],
#  ['#dilma',
#   'anuncia',
#   'investimento',
#   'r',
#   'bilhões',
#   'duplicação',
#   'rodovia',
#   'minas',
#   'gerais'],
#  ['gostaria', 'mandar', '#lula', '#dilma', 'cuba', 'rt'],
#  ['#lula',
#   'tremendo',
#   'junto',
#   '#dilma',
#   'resto',
#   'pt',
#   'cara',
#   'pau',
#   'mentiroso',
#   'nunca',
#   'convenceu'],
#  ['obrigado',
#   '#dilma',
#   'vou',
#   'poder',
#   'encher',
#   'cara',
#   'cerveja',
#   'ver',
#   'brasil',
#   'ganhar',
#   'copa',
#   '#jornaldaglobo'],
#  ['não', 'deixa', 'ser', 'culpa', '#dilma', 'hahahaha'],
#  ['#dilma',
#   'enem',
#   'instrumento',
#   'fundamental',
#   'abrir',
#   'oportunidades',
#   'todos',
#   'jovens'],
#  ['daqui',
#   'uns',
#   'dias',
#   'não',
#   'espantem',
#   '#lula',
#   '#dilma',
#   'aparecerem',
#   'novo',
#   'câncer',
#   'vésperas',
#   'eleição',
#   'p',
#   'comover',
#   'idiotas'],
#  ['#presidenta',
#   '#dilma',
#   'veio',
#   'vistoriar',
#   'bilhões',
#   'gastos',
#   'projeto',
#   'menina',
#   'olhos',
#   '#pt',
#   'gt'],
#  ['#lula',
#   'quer',
#   'arrumar',
#   'motivo',
#   '#dilma',
#   'sofre',
#   'preconceitos',
#   'p',
#   'ganhar',
#   'votos',
#   'quotas',
#   'pretexto',
#   'p',
#   'transformar',
#   '#dilma',
#   'vitima'],
#  ['#lula',
#   'politica',
#   'descriminação',
#   'quotas',
#   'quer',
#   'arrumar',
#   'motivo',
#   'dizendo',
#   '#dilma',
#   'sofre',
#   'preconceitos',
#   'p',
#   'ganhar',
#   'votos',
#   'quotas'],
#  ['tucanos',
#   'encontram',
#   'solução',
#   'falta',
#   'dágua',
#   'paulo',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['pr',
#   '#marcofeliciano',
#   'denuncia',
#   '#dilma',
#   '#assassina',
#   '#terrorista',
#   '#forapt',
#   'lula',
#   'satanizado',
#   'br'],
#  ['câmara',
#   'petistas',
#   'elogiam',
#   'veto',
#   '#dilma',
#   'anistia',
#   'multas',
#   'planos',
#   'saúde'],
#  ['leitão',
#   'sardemberg',
#   'ter',
#   'dizer',
#   'ficam',
#   'contra',
#   'pdv',
#   'petrobras',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['faltam',
#   'dias',
#   'fim',
#   'mundo',
#   'claro',
#   'não',
#   'vai',
#   'acabar',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['#dilma', 'garante', 'direito', 'manifestação', 'prejuízo', 'copa'],
#  ['geraldo',
#   'faça',
#   '#dilma',
#   'visite',
#   'obras',
#   'contra',
#   'seca',
#   'ué',
#   'não',
#   'filme',
#   'tv',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['dilma',
#   '“',
#   'nunca',
#   'fez',
#   'desanda',
#   'cobrar',
#   'fez',
#   '”',
#   'brasil',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['dirceu',
#   'oea',
#   'supremo',
#   'violou',
#   'pacto',
#   'josé',
#   'brasil',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['ives',
#   'gandra',
#   'condenados',
#   'ser',
#   'indenizados',
#   'brasil',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['stf',
#   'barbosa',
#   'usou',
#   'advogado',
#   'graça',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['leia',
#   'via',
#   'lula',
#   'diz',
#   '#dilma',
#   'sobre',
#   'preconceito',
#   'ser',
#   'mulher'],
#  ['#dilma',
#   'vai',
#   'ter',
#   'copa',
#   'sim',
#   'continuar',
#   'reclamando',
#   'vai',
#   'ter',
#   'duas'],
#  ['nunca',
#   'deixem',
#   'folha',
#   'fazer',
#   'obra',
#   'conversa',
#   'afiada',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['rt',
#   'comercial',
#   'pt',
#   'enlouquece',
#   'pig',
#   'conversa',
#   'afiada',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#vaitercopa'],
#  ['#dilma',
#   'anuncia',
#   'investimento',
#   'r',
#   'bi',
#   'duplicação',
#   'rodovia',
#   'mg'],
#  ['precisamos', 'quantas', 'pessoas', 'acaba', 'brasil', '#dilma'],
#  ['agora',
#   'onda',
#   'vermelha',
#   'falta',
#   'dias',
#   'maior',
#   'evento',
#   'esportivo',
#   'terra',
#   'qtos',
#   '#reeleição',
#   '#dilma'],
#  ['#dilma',
#   'critica',
#   'crise',
#   'hídrica',
#   'sp',
#   'evento',
#   'transposição',
#   'rio',
#   'francisco',
#   'pd',
#   'ser',
#   'brincadeira',
#   '#obrasilvaiadilma',
#   '#foradilma'],
#  ['presidenta',
#   '#dilma',
#   'participou',
#   'noite',
#   'desta',
#   'terçafeira',
#   'brasília',
#   'cerimônia',
#   'posse',
#   'ministro'],
#  ['#dilma', 'força', 'mulher', 'nova', 'força', 'move', 'brasil', 'pt', 'via'],
#  ['rt',
#   'vamos',
#   'continuar',
#   'olhando',
#   'frente',
#   'não',
#   'voltar',
#   'arrocho',
#   '#psdb',
#   'passado',
#   '#dilma'],
#  ['dane', 'fantasmas', 'passado', 'agora', '#dilma', 'rsrrrsrsrs'],
#  ['vamos',
#   'continuar',
#   'olhando',
#   'frente',
#   'não',
#   'voltar',
#   'arrocho',
#   'passado',
#   '#dilma'],
#  ['novo',
#   'filme',
#   '#pt',
#   'amedronta',
#   'eleitor',
#   'menos',
#   'instruído',
#   'estratégia',
#   'desespero',
#   'entrou',
#   'campo',
#   '#joaosantana',
#   '#dilma',
#   '#eleicoes'],
#  ['obrigado',
#   '#dilma',
#   'rt',
#   'boa',
#   'tarde',
#   'fifa',
#   'lucra',
#   'r',
#   'bi',
#   'cont'],
#  ['rt',
#   'nei',
#   'papagaio',
#   'pirata',
#   'sabe',
#   'nada',
#   'inocente',
#   'rt',
#   'ney',
#   'carinho',
#   '#dilma',
#   '#lula'],
#  ['recadinho', 'tia', '#dilma'],
#  ['#dilma',
#   'falando',
#   'maravilhas',
#   'tv',
#   'obstáculos',
#   'disse',
#   'encontrar',
#   'governo',
#   'maioria'],
#  ['#dilma',
#   'cara',
#   'pau',
#   'vangloriar',
#   'obra',
#   'anos',
#   'atraso',
#   'deveria',
#   'envergonha',
#   'transposição',
#   'francisco'],
#  ['todas',
#   'mães',
#   'especial',
#   '#dilma',
#   'mãe',
#   'avó',
#   'parabéns',
#   'obrigadão'],
#  ['“', '#pt', 'gerou', 'milhões', 'empregos', 'orgulho', 'ser', '#dilma'],
#  ['dá', 'orgulho', 'ser', '#dilma'],
#  ['feliz', 'dia', 'mães', 'dona', 'dilma', '#dilma'],
#  ['feliz',
#   'dia',
#   'mães',
#   'especial',
#   'pra',
#   'pariu',
#   'ordinário',
#   'médico',
#   'plantão',
#   'chegou',
#   'horas',
#   '#cadeosmedicos',
#   '#dilma'],
#  ['ética', 'tempos', 'cólera', '#dilma', '#pt', '#lula'],
#  ['rede', 'cegonha', '#brasilsemmiseria', '#dilma'],
#  ['campanha',
#   'pede',
#   'democratização',
#   'transmissões',
#   'esportivas',
#   '#dilma',
#   '#pt',
#   '#lula'],
#  ['sentido', 'manifestações', 'copa', '#dilma', '#pt', '#lula'],
#  ['desigualdade', 'cai', 'dilma', 'lula', 'brasil', 'via', '#dilma'],
#  ['#dilma', '#lula', 'avante', '#brasi'],
#  ['lula',
#   'dilma',
#   'representam',
#   'nova',
#   'fase',
#   'desenvolvimento',
#   'brasil',
#   'mundo',
#   'todo',
#   'admira',
#   '#dilma',
#   'novo'],
#  ['#conquista',
#   'rt',
#   '“',
#   'governos',
#   '#pt',
#   'geraram',
#   'milhões',
#   'empregos',
#   'pais',
#   '#dilma'],
#  ['“', 'governos', '#pt', 'geraram', 'milhões', 'empregos', 'pais', '#dilma'],
#  ['rt',
#   '“',
#   'ranking',
#   'banco',
#   'mundial',
#   'traz',
#   'brasil',
#   '°',
#   'maior',
#   'economia',
#   'mundo',
#   '#dilma'],
#  ['#dilma', 'libera', 'r', 'bi', 'saneamento', 'básico'],
#  ['vamos',
#   'parar',
#   'reclamar',
#   'copa',
#   'ir',
#   'estudar',
#   'poderemos',
#   'mudar',
#   'país',
#   'não',
#   '#dilma'],
#  ['#dilma',
#   'rousseff',
#   'entrega',
#   'medalhas',
#   'elogia',
#   'desempenho',
#   'jovens',
#   'piauí',
#   'olimpíada',
#   'matemática'],
#  ['aécio',
#   'neves',
#   'crece',
#   'y',
#   'blanco',
#   'ataques',
#   '#dilma',
#   'y',
#   'eduardo',
#   'campos',
#   'gt',
#   '#eleccionesbrasil'],
#  ['#pig',
#   'partido',
#   'imprensa',
#   'golpista',
#   'alimenta',
#   'oposição',
#   '#ratucana',
#   'não',
#   'disfarça',
#   'caça',
#   '#dilma'],
#  ['ate',
#   'queria',
#   'fazer',
#   'desafio',
#   '#baldedegelo',
#   'graças',
#   'governo',
#   '#dilma',
#   'racionamento'],
#  ['atendendo', 'clamor', 'ruas', '#tarso', '#olívio', '#dilma'],
#  ['#dilma', 'nega', 'atos', 'campanha', 'atrapalhem', 'trabalho'],
#  ['imagem',
#   'lula',
#   'si',
#   'campanha',
#   'fala',
#   'então',
#   'oposição',
#   'treme',
#   '#dilma',
#   'novo',
#   'neles'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   '‘',
#   'certa',
#   'imprensa',
#   '’',
#   'esconde'],
#  ['aécio',
#   'pede',
#   'calma',
#   'parte',
#   'guerra',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#globo'],
#  ['rídículo',
#   'apartamento',
#   'graça',
#   'foster',
#   'globo',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#globo'],
#  ['coordena',
#   'erundina',
#   'psb',
#   'manda',
#   'setúbal',
#   'itaú',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#globo'],
#  ['#dilma', '“', 'não', 'atrasa', 'obra', 'não', 'faz', '”'],
#  ['tijolaço',
#   'todos',
#   'aviões',
#   'dudu',
#   'conversa',
#   'afiada',
#   '#dilma',
#   '#lula',
#   '#psdb',
#   '#pt',
#   '#globo'],
#  ['#dilma', '#padilha', 'sofreram', 'diatadura'],
#  ['propaganda',
#   'jackson',
#   'barreto',
#   'pmdbse',
#   'mentirosa',
#   '#dilma',
#   'diz',
#   'lutaram',
#   'p',
#   'redemocratização',
#   'pra',
#   'instalar',
#   'ditadura',
#   'cubana'],
#  ['#dilma',
#   'enfiou',
#   'dinheiro',
#   'destinado',
#   'reforma',
#   'aeroporto',
#   '#cuiabá',
#   'orifício',
#   'anal',
#   '…'],
#  ['infelizmente',
#   'carioca',
#   'tá',
#   'preferindo',
#   'bosta',
#   'maior',
#   'p',
#   'presidência',
#   '#dilma'],
#  ['#dilma', 'fodeu', 'tudo', '#mrcatrapresidente'],
#  ['olha',
#   'nível',
#   '#dilma',
#   'chegou',
#   'pra',
#   'tentar',
#   'ficar',
#   'poder',
#   '#campanhadaperereca',
#   '#minhapererecaminhavida',
#   '#vergonhanacional'],
#  ['#dilmaetarsodenovo',
#   'rt',
#   'chegando',
#   'gigantinho',
#   '#dilma',
#   '#tarso',
#   '#olivio',
#   '#marcomaia',
#   '#nelsinho'],
#  ['garoto', 'propaganda', '#dilma', '#tarso', '#olivio', '#nelsinho'],
#  ['chegando',
#   'gigantinho',
#   '#dilma',
#   '#tarso',
#   '#olivio',
#   '#marcomaia',
#   '#nelsinho'],
#  ['aprontando', 'tudo', 'receber', '#dilma', '#maiorcomiciocolaborativo'],
#  ['vamos',
#   'fazer',
#   'pesquisa',
#   'justa',
#   'vai',
#   'votar',
#   'pra',
#   'presidente',
#   '#aécio',
#   '#dilma',
#   '#marina',
#   '#preveraldo',
#   'retwitte',
#   'hastag',
#   'voto'],
#  ['integração', 'rio', 'francisco', '#dilma'],
#  ['rt',
#   '@ptbrasil',
#   'aprovação',
#   'governo',
#   '#dilma',
#   'cresce',
#   'seis',
#   'pontos',
#   'supera',
#   'avalanche',
#   'notícias',
#   'negativas'],
#  ['mídia',
#   'oposição',
#   'não',
#   'acertam',
#   'umagt',
#   'previsões',
#   'furadas',
#   'sobre',
#   'brasil',
#   '…',
#   'via',
#   '#dilma',
#   '#tarso',
#   '#olívio'],
#  ['foro',
#   '#sp',
#   'realizado',
#   'la',
#   'paz',
#   'agosto',
#   '#comunismo',
#   '#cuba',
#   '#lula',
#   '#dilma'],
#  ['gasolina',
#   'tão',
#   'cara',
#   'então',
#   '#dilma',
#   'diz',
#   'campos',
#   'présal',
#   'produzirão',
#   'bilhões',
#   'barris',
#   'petróleo'],
#  ['campanha',
#   'eleitoral',
#   '‘',
#   'financial',
#   'times',
#   '’',
#   'ironiza',
#   'vídeo',
#   '#dilma',
#   'encarna',
#   'dona',
#   'casa',
#   'comum',
#   'jornal'],
#  ['#dilma',
#   'aprovou',
#   'leis',
#   'favoráveis',
#   'trabalhadores',
#   'lula',
#   'diz',
#   'diap'],
#  ['eleições',
#   'rui',
#   'promete',
#   'inaugurar',
#   'porto',
#   'sul',
#   'não',
#   'fixa',
#   'data',
#   '#política',
#   '#rui',
#   '#dilma',
#   '#dilma',
#   '#prabahiamudarmais'],
#  ['ainda',
#   'sobre',
#   'entrevista',
#   'dilma',
#   'bonner',
#   'aqle',
#   'amigo',
#   'so',
#   'fala',
#   'verdade',
#   'gente',
#   'não',
#   'qr',
#   'escutar',
#   'kkkk',
#   '#dilma'],
#  ['#lula',
#   '#dilma',
#   'deram',
#   'recado',
#   'brasil',
#   'não',
#   'aceita',
#   'presidente',
#   'meiaboca',
#   'aécio',
#   'marina',
#   'não',
#   'têem',
#   'capacidade'],
#  ['setmbro',
#   'efeito',
#   'comoção',
#   'instituts',
#   'acharam',
#   'pra',
#   'forçar',
#   '˚',
#   'turno',
#   'vai',
#   'continuarmta',
#   'calma',
#   'nessa',
#   'horacampanha',
#   '#dilma',
#   'não',
#   'mudou',
#   'estratégia'],
#  ['nu', 'fudeuuu', '#dilma'],
#  ['#brasil',
#   'rt',
#   'campanha',
#   '#dilma',
#   'mostra',
#   'brasil',
#   'virtual',
#   'diz',
#   '#aécio',
#   '#eleições',
#   '#marinaplanobdopt'],
#  ['além',
#   '#dilma',
#   'ninguém',
#   'capaz',
#   'manter',
#   'ciclo',
#   'progressista',
#   'curso',
#   'brasil',
#   '#aécio',
#   '#marinasilva',
#   'ñ',
#   'sequer',
#   'projeto',
#   'governo'],
#  ['preste',
#   'atenção',
#   'time',
#   '#globo',
#   '#aecioneves',
#   'marina',
#   'silva',
#   'carrasco',
#   '#jb',
#   'time',
#   'povo',
#   '#dilma',
#   '#lula',
#   'abre',
#   'olho',
#   'brasil'],
#  ['#aecioneves',
#   'blablarina',
#   'silva',
#   'ameça',
#   'tudo',
#   'país',
#   'conquistou',
#   '#lula',
#   '#dilma',
#   'não',
#   'deixe',
#   'br',
#   'andar',
#   'pra',
#   'trás'],
#  ['rt',
#   '“',
#   'brasil',
#   'avança',
#   'plano',
#   'nacional',
#   'segurança',
#   'hidrica',
#   '#dilma'],
#  ['educação', '#dilma'],
#  ['verdade', 'vai', 'vencer', 'mentira', '#dilma'],
#  ['respeito',
#   'dignidade',
#   'sabedoria',
#   'qualidades',
#   'verdadeiros',
#   'política',
#   'vieram',
#   'mente',
#   'três',
#   'nomes',
#   'lula',
#   '#dilma',
#   'suplicy'],
#  ['#sertaneja',
#   'diz',
#   'ganhou',
#   'prótese',
#   'antes',
#   '#gravar',
#   '#dilma',
#   '#tv',
#   '#brasil',
#   '#corrupção',
#   '#eleicoes',
#   '#corruption'],
#  ['enganado',
#   'irmão',
#   'não',
#   'filiado',
#   'condidato',
#   'apenas',
#   'preocupação',
#   'jamais',
#   'apoiaria',
#   '#dilma',
#   '#marina'],
#  ['#dilma',
#   'não',
#   'disse',
#   'boa',
#   'gestora',
#   'atrasa',
#   'obra',
#   'constrói',
#   'realmente',
#   '#pt',
#   '#piada'],
#  ['tudo',
#   'aconteceu',
#   'ano',
#   'passado',
#   'torna',
#   'ridículo',
#   '#dilma',
#   'reeleger',
#   '#forapt',
#   'filhos',
#   'putaaa'],
#  ['#coisadopt',
#   '#dilma',
#   'sertaneja',
#   'diz',
#   'ganhou',
#   'prótese',
#   'antes',
#   'gravar',
#   'dilma',
#   'tv'],
#  ['#dilma',
#   'gosta',
#   'fugir',
#   'perguntas',
#   '#professorgirafales',
#   'conseguiu',
#   '…'],
#  ['orgulho', 'fazendo', 'parte', 'desta', 'luta', '#dilma'],
#  ['parabens',
#   'jovens',
#   'brasil',
#   'povo',
#   'precisam',
#   '#dilma',
#   '#dilmatrabalhadora'],
#  ['#lula',
#   'exalta',
#   'obras',
#   'governo',
#   '#dilma',
#   'certa',
#   'imprensa',
#   'esconde',
#   'via'],
#  ['“', 'não', 'atrasa', 'obra', 'não', 'faz', '”', 'diz', '#dilma'],
#  ['voa',
#   'voa',
#   'aviãozinho',
#   '✈',
#   '✈',
#   '✈',
#   'vai',
#   'buscar',
#   'pozi',
#   '✈',
#   '✈',
#   'querida',
#   'presidenta',
#   '#dilma',
#   '#aeciocheiraaderrota'],
#  ['@psdb',
#   '@psb',
#   'mulher',
#   'ganhou',
#   'dentes',
#   'novos',
#   'gravar',
#   '#dilma',
#   'via'],
#  ['onu',
#   'guerra',
#   'síria',
#   'provocou',
#   'mil',
#   'mortes',
#   '#dilma',
#   'não',
#   'diz',
#   'nada',
#   '#vaipracubapt'],
#  ['#dilma',
#   'amp',
#   '#armandomonteiro',
#   'ganharem',
#   'vão',
#   'destruir',
#   '#pernambuco'],
#  ['aladim',
#   'saias',
#   'dilma',
#   'abusa',
#   'mitomania',
#   'faz',
#   'declarações',
#   'absurdas',
#   'horário',
#   'eleitoral',
#   '#dilma',
#   '#pt'],
#  ['reinaldo',
#   'azevedo',
#   '#marinasilva',
#   '#fhc',
#   '#lula',
#   '#dilma',
#   'apóstolo',
#   'paulo'],
#  ['tambem', 'conservadora', 'vamos', 'conservar', '#dilma', 'presidencia'],
#  ['vendo',
#   'baile',
#   'candidatos',
#   '#dilma',
#   'unica',
#   'apresentar',
#   'projetos',
#   'realizados',
#   'podem',
#   'ser',
#   'verificados',
#   '#dilmadenovo'],
#  ['hey', '#dilma', 'vou', 'votar', 'en'],
#  ['photo',
#   'linda',
#   'diva',
#   '#nossapresidenta',
#   '#dilma',
#   '#mãedanação',
#   'brasil',
#   'país',
#   'rico',
#   'pobreza'],
#  ['linda',
#   'diva',
#   '#nossapresidenta',
#   '#dilma',
#   '#mãedanação',
#   '@',
#   'brasil',
#   'país',
#   'rico',
#   'pobreza'],
#  ['#veja', 'cara', '#dilma', 'nessa', 'vista', 'gente'],
#  ['espero',
#   'dentadura',
#   'presente',
#   '#dilma',
#   'ganhe',
#   'voto',
#   'perca',
#   'provem',
#   'contrario',
#   'p',
#   'mim',
#   'compra',
#   'voto'],
#  ['#dilma', 'visita', 'coluna', 'vertebral', 'ferroviária', 'brasil'],
#  ['obras',
#   'infraestrutura',
#   'vão',
#   'garantir',
#   'novo',
#   'ciclo',
#   'crescimento',
#   'economico',
#   '#dilma'],
#  ['obras', '#dilma', 'lula', 'transformam', 'nordeste'],
#  ['visitando',
#   'comércio',
#   'morada',
#   'vale',
#   'gravatai',
#   'vereador',
#   'alemão',
#   'kipão',
#   '#dilma',
#   '#tarso',
#   '#olivio'],
#  ['brasil', 'avança', 'plano', 'nacional', 'segurança', 'hidrica', '#dilma'],
#  ['#dilma', 'hoje', 'porto', 'alegre'],
#  ['#dilma', 'falando', 'pleno', 'emprego', '#foradilma'],
#  ['#dilma', 'visita', 'obras', 'integração', 'rio', 'francisco', '#soudilma'],
#  ['violência',
#   'realidade',
#   'rn',
#   'cada',
#   'segundo',
#   'mulher',
#   'sofre',
#   'violencia',
#   'domestica',
#   '#aforçadasmulheres',
#   '#fatima',
#   '#robison',
#   '#dilma'],
#  ['claro',
#   'vou',
#   'votar',
#   '#dilma',
#   'algum',
#   'outro',
#   'candidato',
#   'ser',
#   'considerado'],
#  ['agora', '#treba', 'fica', '#', '#dilma'],
#  ['eaí',
#   '#',
#   '#dilma',
#   'compra',
#   '#voto',
#   'alô',
#   '#treba',
#   'tomada',
#   'atitude'],
#  ['rt',
#   'não',
#   'sabia',
#   'aniversário',
#   'parabéns',
#   'grande',
#   'dilma',
#   'pra',
#   'obrigada',
#   '#dilma',
#   'vida',
#   'avenida'],
#  ['gestão',
#   'pt',
#   'la',
#   'vai',
#   'brasil',
#   'descendo',
#   'ladeira',
#   'deficit',
#   'dividas',
#   'governo',
#   '#dilma'],
#  ['votar', '#pt', 'ganhar', 'algumas', 'bolsas', '#dilma'],
#  ['alô',
#   '#pt',
#   '#dilma',
#   '#dilma',
#   'vizinha',
#   'tbem',
#   'quer',
#   'gravar',
#   '#brasil'],
#  ['milhões',
#   'pessoas',
#   'recebem',
#   'bolsa',
#   'família',
#   'nordeste',
#   'eleitores',
#   'potencial',
#   '#dilma',
#   '#pt',
#   '#politicadocircoepão'],
#  ['“',
#   'recife',
#   'humberto',
#   'costa',
#   'chama',
#   'marina',
#   'silva',
#   'autoritária',
#   'queria',
#   'saber',
#   'acha',
#   '#dilma'],
#  ['⛔',
#   '️',
#   '#pt',
#   '🚫',
#   'gosta',
#   'marcão',
#   '😂',
#   '😂',
#   '😂',
#   'discurso',
#   'super',
#   'esclarecedor',
#   '#dilma',
#   '…'],
#  ['#dilma',
#   '#aécio',
#   'intensificam',
#   'agenda',
#   'nordeste',
#   'olho',
#   'votos',
#   '#campos'],
#  ['mulher',
#   'diz',
#   'ganhou',
#   'prótese',
#   'dentária',
#   'antes',
#   'gravar',
#   '#dilma',
#   'tv',
#   '#eleições',
#   'ahahaha',
#   'ok'],
#  ['mulher',
#   'diz',
#   'ganhou',
#   'prótese',
#   'dentária',
#   'antes',
#   'gravar',
#   '#dilma',
#   'tv',
#   '#eleições',
#   'benefício',
#   'cassação'],
#  ['rt', '#dilma', 'visita', 'obras', 'integração', 'rio', 'francisco'],
#  ['#dilma', 'visita', 'obras', 'integração', 'rio', 'francisco'],
#  ['rt',
#   'mulher',
#   'diz',
#   'ganhou',
#   'prótese',
#   'dentária',
#   'antes',
#   'gravar',
#   '#dilma',
#   'tv',
#   '#eleições',
#   '#foradilma'],
#  ['curta', 'compartilhe', 'assine', 'manifesto', '#dilma', '#tamojunto'],
#  ['pra',
#   'sair',
#   'bonita',
#   'mulher',
#   'diz',
#   'ganhou',
#   'prótese',
#   'dentária',
#   'antes',
#   'gravar',
#   '#dilma',
#   'tv'],
#  ['ih',
#   'rapaz',
#   'rt',
#   'mulher',
#   'diz',
#   'ganhou',
#   'prótese',
#   'dentária',
#   'antes',
#   'gravar',
#   '#dilma',
#   'tv',
#   '#eleições'],
#  ['não',
#   'atrasa',
#   'obra',
#   'não',
#   'faz',
#   'diz',
#   'dilma',
#   'sobre',
#   'transposição',
#   'diário',
#   'regional',
#   '#eleições',
#   '#dilma'],
#  ['alguém',
#   'percebeu',
#   'todos',
#   'dias',
#   'desta',
#   'semana',
#   '#dilma',
#   'apareceu',
#   'inaugurando',
#   'obra',
#   'inacabada',
#   'tempo',
#   'verbal',
#   'sempre',
#   'futuro'],
#  ['assim',
#   'pt',
#   'ganha',
#   'voto',
#   '“',
#   'mulher',
#   'diz',
#   'ganhou',
#   'prótese',
#   'dentária',
#   'antes',
#   'gravar',
#   '#dilma',
#   'tv'],
#  ['não', 'atrasa', 'obras', 'faz', '#dilma', '#lindakkk'],
#  ['#padilha',
#   'ligado',
#   '#lula',
#   '#dilma',
#   'fazer',
#   'parte',
#   'partido',
#   'vem',
#   'mostrando',
#   'incapacidade',
#   'governo',
#   'anos'],
#  ['#dilma',
#   'defende',
#   '#graça',
#   '#foster',
#   '#denúncia',
#   '#hummm',
#   'tudo',
#   'farinha',
#   'saco'],
#  ['#esseanoeu',
#   'qro',
#   '#dilma',
#   'queda',
#   'pobreza',
#   'desigualdade',
#   'não',
#   'acaso',
#   'resulta',
#   'políticas',
#   'certas',
#   'p',
#   'enorme',
#   'vontade',
#   'política'],
#  ['país',
#   'justo',
#   'igualitário',
#   'não',
#   'pode',
#   'deixar',
#   'ser',
#   'objetivo',
#   'primordial',
#   'cada',
#   'brasileiro',
#   'decente',
#   '#dilma',
#   '#lula'],
#  ['candidato',
#   'psdb',
#   'presidência',
#   'aécio',
#   'neves',
#   'classificou',
#   'nesta',
#   'quintafeira',
#   'gestão',
#   '#dilma',
#   'rousseff'],
#  ['reinaldo',
#   'so',
#   'prega',
#   'contra',
#   '#dilma',
#   'fala',
#   'outros',
#   'presidenciaveis'],
#  ['bom',
#   'dia',
#   'viva',
#   '#dilma',
#   'viva',
#   '#lula',
#   '#viva',
#   'pt',
#   '#dilmanatvdia'],
#  ['bom', '#dilma', 'todos'],
#  ['espera',
#   'dias',
#   '#dilma',
#   '#ptralha',
#   'pega',
#   'volta',
#   'sertaneja',
#   'diz',
#   'ganhou',
#   'prótese',
#   'antes',
#   'gravar',
#   'dilma',
#   'tv'],
#  ['brasil',
#   'cada',
#   'dia',
#   'fudido',
#   'mãos',
#   '#dilma',
#   'corja',
#   '#ptralha',
#   'editorial',
#   'problema',
#   'maquiado'],
#  ['mídia',
#   'máscara',
#   'rússia',
#   'prepara',
#   'guerra',
#   'putim',
#   'hitler',
#   'séc',
#   'xxi',
#   'amigo',
#   '#dilma'],
#  ['#dilma',
#   'defende',
#   'foster',
#   'ação',
#   'governo',
#   'evitar',
#   'bloqueio',
#   'bens'],
#  ['urra', 'repórter', 'pergunta', 'pra', '#dilma', 'gay'],
#  ['palavra', 'rei', '#robertocarlos', 'sobre', '#dilma'],
#  ['cadê',
#   'capa',
#   'graças',
#   'gov',
#   '#lula',
#   '#dilma',
#   '#bolsafamília',
#   'gt',
#   'mi',
#   'pessoas',
#   'deixaram',
#   'extrema',
#   'pobreza'],
#  ['#horariopoliticotirando',
#   'palhaçadas',
#   'bom',
#   'tomamos',
#   'conhecimentos',
#   'entendemos',
#   'presidente',
#   '#dilma',
#   'não',
#   'apoio',
#   '#evangélicos'],
#  ['dilma',
#   'lula',
#   'devem',
#   'abrir',
#   'programa',
#   'respondendo',
#   'manipulações',
#   'jornal',
#   'nacional',
#   'noite',
#   'anterior',
#   'desmascarando',
#   'farsa',
#   'globo',
#   '#dilma'],
#  ['outro',
#   'dirigente',
#   'psb',
#   'deixa',
#   'campanha',
#   'marina',
#   'silva',
#   'via',
#   'folha',
#   'poder',
#   '#dilma',
#   '#denovo',
#   '#politicanossa',
#   '#voudedilma'],
#  ['#vamos', 'reeleiger', 'dilma', '#dilma', 'mudança', '#dilma', 'coragem'],
#  ['#dilma',
#   'concluirá',
#   'rt',
#   'concluir',
#   'transposição',
#   'rio',
#   's',
#   'fco',
#   'prioridade',
#   'gov',
#   'disse',
#   'aécio',
#   'patospb',
#   '#equipean'],
#  ['situação', 'atual', 'eleição', '#dilma', '#dilmadenovo'],
#  ['campanha',
#   'economizar',
#   'energia',
#   'racionamento',
#   'inevitável',
#   'hora',
#   '#dilma',
#   '…'],
#  ['não',
#   'atrasa',
#   'obra',
#   'não',
#   'faz',
#   'palavras',
#   'presidenta',
#   '#dilma',
#   'nome',
#   'disso',
#   'irresponsabilidade',
#   'cidadã'],
#  ['não',
#   'atrasa',
#   'obra',
#   'não',
#   'faz',
#   'roussef',
#   '#dilma',
#   'boa',
#   'noiteagora',
#   'sim'],
#  ['ka',
#   'ka',
#   'ka',
#   'boa',
#   '#dilma',
#   'gt',
#   'nunca',
# ...
#   'horrores',
#   '#dilma',
#   '#anajulia'],
#  ['#dilma',
#   'conselheiros',
#   'vão',
#   'devolver',
#   'jetons',
#   'recebidos',
#   '#petrobras'],
#  ['certeza',
#   'emoções',
#   'fortes',
#   '“',
#   '#ciro',
#   'gomes',
#   'convidado',
#   'coordenação',
#   'campanha',
#   '#dilma',
#   '#política',
#   '”'],
#  ['não',
#   'primeiro',
#   'bilhão',
#   '#dilma',
#   'perdeteve',
#   'porto',
#   '#cuba',
#   'perdão',
#   '#dívidas',
#   '#áfricatá',
#   'sobrando',
#   'dinheiro'],
#  ['#ciro',
#   'gomes',
#   'convidado',
#   'coordenação',
#   'campanha',
#   '#dilma',
#   '#eleições',
#   '#política'],
#  ['vão',
#   'ganhar',
#   'fácil',
#   'c',
#   'povo',
#   'deseducado',
#   'rt',
#   'nota',
#   '#lula',
#   'nega',
#   'ter',
#   'dito',
#   '#dilma',
#   'deu',
#   'tiro',
#   'pé'],
#  ['simples',
#   'ódio',
#   'pt',
#   'qualquer',
#   'coisa',
#   'governo',
#   'culpa',
#   '#dilma',
#   '#pt',
#   'governo',
#   'malásia',
#   'via'],
#  ['sobre',
#   'legalizar',
#   'digo',
#   'coisaa',
#   '#dilma',
#   'acha',
#   'fazer',
#   'joguinho',
#   'ai',
#   'vão',
#   'desistir',
#   'fumar',
#   'proibido',
#   'melhor',
#   'ainda'],
#  ['sempre',
#   'negou',
#   'tudo',
#   'rt',
#   'uol',
#   'notícias',
#   'nota',
#   '#lula',
#   'nega',
#   'ter',
#   'dito',
#   '#dilma',
#   'deu',
#   'tiro',
#   'pé'],
#  ['batendo',
#   'cabeça',
#   'rt',
#   'nota',
#   '#lula',
#   'nega',
#   'ter',
#   'dito',
#   '#dilma',
#   'deu',
#   'tiro',
#   'pé'],
#  ['nota', '#lula', 'nega', 'ter', 'dito', '#dilma', 'deu', 'tiro', 'pé'],
#  ['#dilma',
#   'turno',
#   'aécio',
#   'reza',
#   'brava',
#   'curioso',
#   'campos',
#   'acaba',
#   'herdar',
#   'desabamento',
#   'marina'],
#  ['caso',
#   'gemini',
#   'gt',
#   '…',
#   'gt',
#   'outro',
#   'grande',
#   'escândalo',
#   '#petrobras',
#   'patrocinado',
#   '#dilma'],
#  ['qto',
#   'maior',
#   'ódio',
#   'dudumalcaráter',
#   'tanto',
#   'maior',
#   'admiração',
#   '#dilmaela',
#   'impediu',
#   'roubalheira',
#   'dudu',
#   'governoeis',
#   'razão',
#   'ódio'],
#  ['caso',
#   'gemini',
#   'gt',
#   'gt',
#   'outro',
#   'grande',
#   'escândalo',
#   '#petrobras',
#   'patrocinado',
#   '#dilma',
#   'corruptos',
#   'associados'],
#  ['rt',
#   'visite',
#   'comprove',
#   '#dilma',
#   'sempre',
#   'soube',
#   'tudo',
#   'compra',
#   '#petrobras',
#   'omissa',
#   'conivente'],
#  ['visite',
#   'comprove',
#   '#dilma',
#   'sempre',
#   'soube',
#   'tudo',
#   'contra',
#   '#petrobras',
#   'omissa',
#   'conivente'],
#  ['caso',
#   'sociedade',
#   'gemini',
#   '“',
#   'fraudulento',
#   'acordo',
#   'ferrou',
#   'petrobras',
#   '”',
#   'anuência',
#   '#dilma'],
#  ['reconhecimento',
#   'trabalho',
#   'feito',
#   'amor',
#   'carinho',
#   'não',
#   'preço',
#   'obrigado',
#   '#dilma',
#   'mimo',
#   '✌',
#   '️',
#   '\U000fe823'],
#  ['faliu',
#   'loja',
#   'pode',
#   'autorizar',
#   'compra',
#   'refinaria',
#   'us',
#   'bilhão',
#   '#dilma',
#   'cowgirl',
#   'tx'],
#  ['#dilma',
#   'ñ',
#   'rouba',
#   'ñ',
#   'deixa',
#   'roubar',
#   'ñ',
#   'sonega',
#   'impostos',
#   'ñ',
#   'inventa',
#   'notícia',
#   'ñ',
#   'concessionária',
#   'mídias',
#   'bilionária',
#   'quer',
#   'apenas',
#   'governar',
#   'br'],
#  ['gerentona', '#dilma', '#elesnaomerepresentam'],
#  ['#gabrielli', 'põe', 'xeque', 'versão', '#dilma'],
#  ['#tse', 'multa', '#dilma', 'exministro', 'integração', 'nacional'],
#  ['agora',
#   'sim',
#   'vi',
#   'vantagem',
#   'golpe',
#   'assim',
#   'bilhão',
#   'dona',
#   'dilma',
#   'parabéns',
#   '#pt',
#   '#dilma',
#   '#brasilvaiadilma'],
#  ['#dilma',
#   'vem',
#   'pará',
#   'distribui',
#   'uns',
#   'maquinários',
#   'centavos',
#   'reais',
#   'faz',
#   'promessas',
#   'não',
#   'vai',
#   'cumprir',
#   'antes',
#   'investiu',
#   'bilhões',
#   '#cuba'],
#  ['#jornal',
#   't',
#   '#falapará',
#   '#presidenta',
#   'hahaha',
#   '#dilma',
#   'stev',
#   'ak',
#   '#belémdopará',
#   'dps',
#   '#discurso',
#   'aqui',
#   '#ceará',
#   '#cidadedasmangueiras'],
#  ['anteseu',
#   'perguntavac',
#   'receiose',
#   'pessoas',
#   'votariam',
#   '#dilma',
#   'hojeeu',
#   'pergunto',
#   'achando',
#   'governo',
#   'saem',
#   'várias',
#   'críticas'],
#  ['vizinhas',
#   'colegas',
#   'academia',
#   'sp',
#   'ninguém',
#   'vota',
#   '#dilma',
#   'ninguém',
#   'pessoal',
#   'criticando',
#   'governo'],
#  ['ideia', 'amigo', 'boa', '#dilma', 'rt', '…', '…'],
#  ['ideia', 'amigo', 'boa', '#dilma', 'rt', '…'],
#  ['tal', 'ideia', 'amigo', 'deu', 'agora', 'p', 'fazer', '#dilma', 'rt', '…'],
#  ['#dilma', 'quase', 'chegando', 'lá', 'daqui', 'pouco', 'nessa', 'situação'],
#  ['pode',
#   'acaba',
#   'sistema',
#   'não',
#   'quer',
#   'sistema',
#   'acabe',
#   '#politica',
#   '#dilma',
#   '#brasil',
#   '#umabosta'],
#  ['perto',
#   '#dilma',
#   'santo',
#   'não',
#   'precisa',
#   'pedir',
#   'desculpas',
#   'palavrão'],
#  ['#dilma',
#   'receber',
#   '#palanque',
#   'ainda',
#   'cumprimentar',
#   'dep',
#   'fed',
#   '#criminoso',
#   '#asdrubal',
#   '#bendes',
#   'máximo',
#   'absurdo',
#   '#país',
#   '#cego'],
#  ['rt',
#   'josé',
#   'nêumanne',
#   'pinto',
#   'gerentona',
#   'dilma',
#   'sempre',
#   'coloca',
#   'culpa',
#   'alguém',
#   '#dilma',
#   'pilantra'],
#  ['#dilma',
#   'pede',
#   'defecar',
#   'saia',
#   'jáserá',
#   'menos',
#   'vergonhoso',
#   'perder',
#   'eleição'],
#  ['rt',
#   'exdiretor',
#   'petrobras',
#   'preso',
#   'acusado',
#   'lavagem',
#   'dinheiro',
#   'turma',
#   '#dilma',
#   'corja',
#   'bandida'],
#  ['rt',
#   'contabilidade',
#   'criativa',
#   'desmoraliza',
#   'contas',
#   'públicas',
#   'gov',
#   '#dilma',
#   'falcatruas',
#   'roubalheira',
#   'corja'],
#  ['deixa',
#   'entender',
#   'collor',
#   'cassado',
#   'uso',
#   'privado',
#   '#dilma',
#   'faz',
#   'negociata',
#   'u',
#   'bi',
#   'vai',
#   'ficar',
#   'td'],
#  ['aqui',
#   'estados',
#   'unidos',
#   'porquê',
#   'lá',
#   'povo',
#   'sério',
#   '#dilma',
#   'estaria',
#   'sendo',
#   'algemada',
#   'perdendo',
#   'cargo',
#   'presidente'],
#  ['quantos',
#   'policiais',
#   'militares',
#   'vai',
#   'assassinar',
#   'ainda',
#   'turma',
#   '#dilma'],
#  ['vamos',
#   'falar',
#   '#dilma',
#   'cometeu',
#   'crime',
#   'lesapátria',
#   'cadê',
#   'povo'],
#  ['jornal',
#   'globo',
#   'compartilhada',
#   'publicamente',
#   'ontem',
#   '#dilma',
#   '#dilma',
#   'venceria',
#   '#eleições'],
#  ['vamos',
#   'acordar',
#   'falta',
#   'prender',
#   '#dilma',
#   'presidente',
#   'conselho',
#   'petrobrás',
#   'crime',
#   'responsabilidade'],
#  ['pensa', 'escândalo', '#dilma'],
#  ['vagabundos',
#   'pt',
#   'conseguiram',
#   'quebrar',
#   'petrobrás',
#   '#dilma',
#   'ir',
#   'cadeia',
#   'crime',
#   'responsabilidade'],
#  ['petrobrás',
#   '#dilma',
#   'comandou',
#   'roubalheira',
#   '#petrobrás',
#   'vamos',
#   'suportar',
#   'corja',
#   'bandida'],
#  ['terrorista',
#   'mentirosa',
#   'diz',
#   'doutorado',
#   'diploma',
#   '#dilma',
#   'deveria',
#   'ter',
#   'sido',
#   'presa',
#   'menos'],
#  ['iniciativa',
#   'privada',
#   '#dilma',
#   'sido',
#   'demitida',
#   'começar',
#   'dizer',
#   'doutorado',
#   'diploma'],
#  ['triste',
#   'realidade',
#   'brasileira',
#   'novo',
#   'escândalo',
#   'envolvendo',
#   '#lula',
#   '#dilma',
#   '#pt',
#   'tv',
#   'calada',
#   'ainda',
#   'estranho',
#   '#corruption',
#   '#brazil'],
#  ['#alckmin',
#   'solicitou',
#   'presidenta',
#   '#dilma',
#   'ajuda',
#   'programa',
#   'estadual',
#   '#minhacisternaminhavida',
#   'primeiras',
#   'unidades',
#   'instaladas',
#   'av',
#   'paulista'],
#  ['ibope',
#   'mexida',
#   'ontem',
#   'p',
#   'hj',
#   'rt',
#   'não',
#   'acreditem',
#   'nessa',
#   'pesquisa',
#   '#ibope',
#   '#dilma',
#   'máximo',
#   'aguardem'],
#  ['#dilma', 'nanicos', 'todos', 'caem', 'nanicos'],
#  ['#ibope', '#dilma', 'aécio', 'campos', 'via', 'saiu', '#jn'],
#  ['#dilma',
#   'reeleita',
#   'não',
#   'pode',
#   'vandalismo',
#   'desse',
#   'anta',
#   'partido',
#   'merda',
#   'vai',
#   'destruir',
#   'país'],
#  ['iniciadas',
#   '#lula',
#   'continuadas',
#   '#dilma',
#   'educação',
#   'saúde',
#   'desenvolvimento',
#   'sustentabilidade',
#   'inclusão',
#   'participação'],
#  ['#dilma', 'visto', 'vários', 'arakyris', 'baianos', 'kkkk'],
#  ['ibope', '#dilma', 'mantém', 'vitória', 'º', 'turno'],
#  ['#globosonegou',
#   'pesquisa',
#   'ibope',
#   '#dilma',
#   '#naovaiteroturno',
#   'jn',
#   'atestado',
#   '#golpismo',
#   'junjul',
#   'adorava',
#   '#globomente',
#   '#golpe'],
#  ['alegria',
#   'saber',
#   'pesquisa',
#   'ibope',
#   'gtgtgtgtgtgt',
#   '#dilma',
#   'primeiro',
#   'turno'],
#  ['estabilidade', '#dilma', 'pesquisas', 'veja', 'quadro'],
#  ['visto',
#   '#globosonega',
#   'não',
#   'vai',
#   'mostrar',
#   'ibope',
#   'hoje',
#   '#dilma',
#   'não',
#   'notícia',
#   'globo',
#   'aécio',
#   'dudu',
#   'mals'],
#  ['#dilma', 'mantém', 'liderança', 'intenções', 'voto', 'aponta', '#ibope'],
#  ['rt',
#   '#dilma',
#   'venceria',
#   'º',
#   'turno',
#   'indica',
#   'pesquisa',
#   'ibope',
#   '#dilmasim'],
#  ['#dilma',
#   'começou',
#   'levantar',
#   'olhos',
#   'enquanto',
#   'discursa',
#   '#lula',
#   'faz',
#   'my',
#   'god',
#   'mentira',
#   'roubalheira'],
#  ['olha', 'presiburra', 'ai', '#dilma'],
#  ['explicação',
#   'pertence',
#   'categoria',
#   'fumei',
#   'não',
#   'traguei',
#   'chupei',
#   'não',
#   'engoli',
#   'incompetente',
#   '#dilma',
#   '#canalha'],
#  ['evolução',
#   'preços',
#   'ações',
#   '#bovespa',
#   'ñ',
#   'feitas',
#   'c',
#   'base',
#   'preços',
#   'balanços',
#   'feitas',
#   'c',
#   'base',
#   'ibope',
#   '#dilma',
#   '#petr'],
#  ['programa',
#   'politico',
#   'tv',
#   '#dilma',
#   'hoje',
#   'dia',
#   'crianças',
#   'belissimo',
#   'emocionante',
#   'maravilhoso'],
#  ['#dilma',
#   'caso',
#   'eleita',
#   'vai',
#   'lançar',
#   'carro',
#   'popular',
#   'ecológico',
#   'movido',
#   'lama',
#   'produzida',
#   'abundância',
#   '#petrobras'],
#  ['orgulho',
#   'ser',
#   '#pt',
#   'hoje',
#   'jovem',
#   'oportunidade',
#   'cursar',
#   'faculdade',
#   'qualidade',
#   'conhece',
#   'vota',
#   '#dilma',
#   'conhece',
#   'vota',
#   '#'],
#  ['#aeciodesdecriancinha',
#   '#souaéciodesdecriancinha',
#   'dia',
#   'brasil',
#   'demitira',
#   '#dilma',
#   'governo',
#   'petralha'],
#  ['voto', '#dilma', 'casa', 'todos', 'empregados', '#psdb', 'desemprego'],
#  ['#aecio', '#dilma', 'voto', 'votocomente'],
#  ['mai',
#   'quero',
#   'saber',
#   'voto',
#   '#dilma',
#   'vida',
#   'familia',
#   'melhor',
#   'maiores',
#   'comentários'],
#  ['#propagandapolitica',
#   '#dilma',
#   'criança',
#   'deve',
#   'aprender',
#   'ler',
#   'escrever',
#   'operações',
#   'matemáticas',
#   'anos'],
#  ['aécio',
#   'diz',
#   'mudançamas',
#   'plano',
#   'ações',
#   'realizadas',
#   '#dilma',
#   'não',
#   'nenhuma',
#   'inovaçãosó',
#   'rindo',
#   'rsrs',
#   '#foraaecio'],
#  ['programa',
#   'eleitoral',
#   '#dilma',
#   'percebi',
#   'coisa',
#   'governo',
#   '#pt',
#   'tão',
#   'ruim',
#   'falam',
#   'governo',
#   'novo',
#   '#mudabrasil',
#   '#aécio',
#   '#aecio'],
#  ['orgulho',
#   'dizer',
#   'governo',
#   'mudou',
#   'país',
#   'finalmente',
#   'brasil',
#   'cresceu',
#   'conhece',
#   'vota',
#   '#dilma',
#   'conhece',
#   'vota',
#   '#'],
#  ['futura',
#   'ex',
#   'presidanta',
#   '#afff',
#   '#wtf',
#   '#dilma',
#   '#presidanta',
#   '#regram',
#   '#socorro',
#   '#help',
#   '#instafunny',
#   '#igers',
#   '#vote'],
#  ['futura',
#   'ex',
#   'presidanta',
#   '😂',
#   '🙊',
#   '🙉',
#   '🙊',
#   '#afff',
#   '#wtf',
#   '#dilma',
#   '#presidanta',
#   '#regram',
#   '#socorro',
#   '#help',
#   '…'],
#  ['vamos',
#   'retomar',
#   'crescimento',
#   'diminuir',
#   'prejuízo',
#   'anos',
#   'desgoverno',
#   '#lula',
#   '#dilma',
#   '#pt',
#   '#vote'],
#  ['mensagem',
#   'militantes',
#   'psb',
#   'povo',
#   'brasileiro',
#   'roberto',
#   'amaral',
#   '#dilma',
#   '#pt',
#   '#lula'],
#  ['#dilma', '#aecio', '#atiliopereira'],
#  ['amanhã', 'dia', 'amanhã', 'dia', 'traje', 'vermelho', '#dilma'],
#  ['toda', 'obra', '#dilma', 'atraso', 'superfaturamento', 'desvio', '#pt'],
#  ['#dilma',
#   'cara',
#   'pau',
#   'falando',
#   'compromissos',
#   'morais',
#   'fazme',
#   'rir'],
#  ['gov',
#   '#dilma',
#   'engavetou',
#   'projeto',
#   'melhorias',
#   'condições',
#   'trabalho',
#   'aeronautas',
#   'brasileiros',
#   'classe',
#   'pode',
#   'contar'],
#  ['declarações',
#   '#dilma',
#   'fazem',
#   'lembrar',
#   '#paulomaluf',
#   'qdo',
#   'dizia',
#   'roubo',
#   'faço',
#   '#equipean'],
#  ['inflação',
#   'voltou',
#   'economia',
#   'parou',
#   'dívida',
#   'aumentou',
#   'falar',
#   'corrupção',
#   'graças',
#   '#lula',
#   '#dilma',
#   '#pt',
#   '#acordabrasil',
#   '#vote'],
#  ['mudamos', 'vida', 'precisou', '#dilma'],
#  ['não',
#   'urnas',
#   'revelaram',
#   'aqui',
#   'vereador',
#   'não',
#   'preocupe',
#   'revelarão',
#   'mossoró',
#   '#dilma',
#   '#mudamais'],
#  ['aviões', 'fab', 'hoje', 'aracaju', 'campanha', '#dilma'],
#  ['chamadas',
#   '#dilma',
#   'tá',
#   'parecendo',
#   'diálogos',
#   'vizinhos',
#   'fala',
#   'mal',
#   'não',
#   'mostra',
#   'pode',
#   'fazer'],
#  ['guia',
#   '#dilma',
#   'feito',
#   'basicamente',
#   'ataquesesse',
#   'indicativo',
#   'ruimnivela',
#   'campanha',
#   'baixo',
#   'esquece',
#   'debater',
#   'pros',
#   'país'],
#  ['dilma',
#   'não',
#   'aécio',
#   'gttexto',
#   'excelente',
#   'gt',
#   'coronelismo',
#   'utópico',
#   'matta',
#   'márcio',
#   'valley',
#   '#dilma'],
#  ['ouvindo',
#   'mal',
#   'governanta',
#   'chamada',
#   '#dilma',
#   'senhora',
#   'ja',
#   'perdeuu',
#   'vamos',
#   'tira',
#   'cadeiraja',
#   'arruma',
#   'outro',
#   'emprego',
#   'senhora',
#   'defazada'],
#  ['chamada',
#   '#dilma',
#   'tá',
#   'parecendo',
#   'diálogos',
#   'vizinhos',
#   'fala',
#   'mal',
#   'não',
#   'mostra',
#   'pode',
#   'fazer'],
#  ['#dilma', 'fará', 'creches', 'canis', 'sacou'],
#  ['começa',
#   'propaganda',
#   'eleitora',
#   'presidente',
#   '#dilma',
#   'desligo',
#   'tv',
#   'mente'],
#  ['#brasil', '#eleicoes', 'votar', '#dilma', 'suicídio'],
#  ['#dilma',
#   'põe',
#   'sigla',
#   '#pt',
#   'deve',
#   'ter',
#   'nojo',
#   'partidinho',
#   'tão',
#   'fajuto',
#   'desonesto',
#   'sabe',
#   'roubar',
#   'corromper',
#   'afunda',
#   'país'],
#  ['#dilma',
#   'dizo',
#   'governo',
#   'não',
#   'compactua',
#   'corrupçãorenanmalufcollorsarneygarotinhojenuinodirceu',
#   'paloccicosta',
#   'youssef',
#   'lula'],
#  ['familia',
#   'duduno',
#   'fantastico',
#   'acidente',
#   'duducampanha',
#   'eleitoral',
#   'globo',
#   '#mudamais',
#   '#dilma'],
#  ['ñ',
#   'medo',
#   'tirála',
#   'lá',
#   'certeza',
#   'filho',
#   'agradecerá',
#   'futuro',
#   'qdo',
#   'nascer',
#   'história',
#   'contada',
#   'verdade',
#   '#fora',
#   '#dilma'],
#  ['qualquer',
#   'coisa',
#   'qualquer',
#   'lugar',
#   'melhor',
#   '#pt',
#   '#lula',
#   '#dilma',
#   'não',
#   'necessariamente',
#   'nesta',
#   'ordem',
#   '#brasil',
#   'poder'],
#  ['#dilma',
#   'invés',
#   'mostrar',
#   'pretende',
#   'fazer',
#   'povo',
#   'brasil',
#   'melhor',
#   'fica',
#   'falando',
#   'mal',
#   '#aécio',
#   'não',
#   'quero',
#   'ver'],
#  ['fica', 'dica', '#dilma', 'fica', '#coraçãovalente'],
#  ['#nuncaantesnahistória',
#   'desse',
#   'país',
#   'trabalhadores',
#   'ficaram',
#   'tão',
#   '#endividados',
#   '#dilma',
#   'empurrou',
#   'trabalhadores',
#   'p',
#   'consumismo',
#   'caro',
#   'enganador'],
#  ['vai',
#   'ficar',
#   'difícil',
#   'agora',
#   'campanha',
#   '#dilma',
#   'denunciou',
#   'justiça',
#   'eleitoral'],
#  ['#dilma',
#   'não',
#   'irei',
#   'punir',
#   'provas',
#   'presidenta',
#   'quer',
#   'desenhe',
#   'pra',
#   'delação',
#   'premiada',
#   'ser',
#   'aceita',
#   'ter',
#   'provas',
#   'documentais',
#   'etc'],
#  ['roubaram',
#   '#petrobrás',
#   'magnífico',
#   'editorial',
#   '#estadão',
#   'hoje',
#   'legítimo',
#   'esperar',
#   '#lula',
#   '#dilma',
#   'viessem',
#   'dar',
#   'explicações'],
#  ['#dilma',
#   'diz',
#   'não',
#   'acredita',
#   'transferência',
#   'votos',
#   '#marina',
#   '#aécio'],
#  ['falando',
#   'sério',
#   '#dilma',
#   'comércio',
#   'familia',
#   'crescendo',
#   'anos',
#   'establidade',
#   '#psdb',
#   'falimos',
#   'vezes',
#   'nao',
#   'arrisco',
#   'voto',
#   '#dilma'],
#  ['#marinasilva',
#   'declara',
#   'apoio',
#   'presidente',
#   '#dilma',
#   'tão',
#   'boa',
#   'ninguém',
#   'prestou',
#   'apoio',
#   '#aecio'],
#  ['grande', 'prado', '#dilma', '#dilma', '#pt'],
#  ['#dilma',
#   'youssef',
#   'roubou',
#   'bilhão',
#   'questão',
#   'banco',
#   'central',
#   'não',
#   'detectou',
#   'movimentação',
#   'bancos',
#   'p',
#   'youssef',
#   'deu',
#   'golpe',
#   'pt'],
#  ['#puleomuro',
#   'emoções',
#   'caminhos',
#   'energia',
#   'ondas',
#   'invadem',
#   'combatem',
#   'cáries',
#   'ondas',
#   'levam',
#   'coração',
#   'permanecemos',
#   '#dilma'],
#  ['#dilma', '#dilma', '#pt', 'contra', 'toda', 'qualquer', '#mentira'],
#  ['#dilma',
#   '#pedeprasair',
#   'manifestação',
#   'débil',
#   'cardozo',
#   'sobre',
#   'vazamentos'],
#  ['companheirosas',
#   'copiem',
#   'hashtag',
#   '#nãoqueremosdebatenaglobo',
#   'enviem',
#   'presidenta',
#   '#dilma',
#   '#pt',
#   'vamos',
#   'alcançar',
#   'trend',
#   'topics'],
#  ['presidenta',
#   '#nãoqueremosdebatenaglobo',
#   '#pt',
#   '#dilma',
#   'vamos',
#   'todos',
#   'participar',
#   'dessa',
#   'campanha'],
#  ['anoso',
#   'brasil',
#   'saiu',
#   'enfim',
#   'mapa',
#   'fome',
#   'apenas',
#   'grandes',
#   'motivos',
#   'fazem',
#   'votar',
#   '#dilma',
#   'c',
#   'muita',
#   'convicção'],
#  ...]

# %%
# %%time
#Initializing the word2vec model

import multiprocessing

w2v_model = Word2Vec(min_count=4,
                     window=5,
                     vector_size =300,
                     sample=1e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     seed= 42,
                     workers=multiprocessing.cpu_count()-1)


#building vocab of the word2vec model from the custom data
w2v_model.build_vocab(e_sentences, progress_per=50000)

# https://towardsdatascience.com/unsupervised-sentiment-analysis-a38bf1906483
# Out:
# CPU times: user 205 ms, sys: 149 µs, total: 205 ms
# Wall time: 208 ms

# %%
# %%time
w2v_model.train(e_sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)
# Out:
# CPU times: user 12.8 s, sys: 122 ms, total: 12.9 s
# Wall time: 5.21 s
# (1716223, 7703040)

# %%
#w2v_model.wv.key_to_index
w2v_model.wv.most_similar("dilma")
# Out:
# [('faz', 0.9995744228363037),
#  ('enqto', 0.999555230140686),
#  ('viajando', 0.9995530247688293),
#  ('vou', 0.999552845954895),
#  ('el', 0.9995509386062622),
#  ('bem', 0.9995501041412354),
#  ('novos', 0.9995485544204712),
#  ('#veja', 0.999548077583313),
#  ('real', 0.9995476007461548),
#  ('cresce', 0.9995447993278503)]

# %%
# %%time
model = KMeans(n_clusters=3, max_iter=1000, random_state=42, n_init=50).fit(X=w2v_model.wv.vectors.astype('double'))
# Out:
# CPU times: user 7.1 s, sys: 3.35 s, total: 10.4 s
# Wall time: 3.6 s

# %%
# check what we have in each cluster to label the clusters
w2v_model.wv.similar_by_vector(model.cluster_centers_[0], topn=100, restrict_vocab=None)
# Out:
# [('excelente', 0.9998299479484558),
#  ('comandar', 0.9998290538787842),
#  ('dna', 0.9998289942741394),
#  ('jornais', 0.9998283386230469),
#  ('acredita', 0.9998263716697693),
#  ('coitada', 0.9998262524604797),
#  ('palavrão', 0.9998262524604797),
#  ('maiores', 0.9998261332511902),
#  ('#eunaovejonaglobo', 0.9998258948326111),
#  ('única', 0.9998252391815186),
#  ('continuará', 0.9998244643211365),
#  ('#maiseducação', 0.999824047088623),
#  ('sinto', 0.9998239278793335),
#  ('exemplar', 0.9998228549957275),
#  ('finaliza', 0.9998227953910828),
#  ('lavada', 0.9998227953910828),
#  ('rápido', 0.9998226165771484),
#  ('sanepar', 0.9998222589492798),
#  ('putz', 0.999821662902832),
#  ('culpar', 0.9998214840888977),
#  ('#coracaovalente', 0.9998212456703186),
#  ('ampliação', 0.9998209476470947),
#  ('#naovamosdesistirdobrasil', 0.9998207092285156),
#  ('especialidades', 0.9998201131820679),
#  ('estourou', 0.9998197555541992),
#  ('emoção', 0.9998196363449097),
#  ('gratidão', 0.9998192191123962),
#  ('defesa', 0.9998189210891724),
#  ('#propaganda', 0.9998188018798828),
#  ('torcedores', 0.9998183846473694),
#  ('urubus', 0.9998183250427246),
#  ('#parabéns', 0.9998180270195007),
#  ('hahaha', 0.9998176097869873),
#  ('novamente', 0.9998176097869873),
#  ('boleto', 0.9998174905776978),
#  ('deseja', 0.999817430973053),
#  ('fátima', 0.9998172521591187),
#  ('grito', 0.9998172521591187),
#  ('desista', 0.99981689453125),
#  ('brinca', 0.9998166561126709),
#  ('fechar', 0.9998164176940918),
#  ('deposita', 0.9998161792755127),
#  ('#agora', 0.9998155236244202),
#  ('esquecer', 0.9998151659965515),
#  ('deus', 0.999815046787262),
#  ('moça', 0.9998148679733276),
#  ('praga', 0.9998144507408142),
#  ('apelar', 0.9998138546943665),
#  ('engana', 0.9998136758804321),
#  ('data', 0.9998136758804321),
#  ('obrigação', 0.9998133182525635),
#  ('visto', 0.9998132586479187),
#  ('guerreira', 0.9998131394386292),
#  ('muuuito', 0.9998130798339844),
#  ('muitas', 0.9998130798339844),
#  ('existe', 0.9998128414154053),
#  ('aviso', 0.999812662601471),
#  ('próximos', 0.999812662601471),
#  ('vencedor', 0.9998126029968262),
#  ('atitude', 0.9998124837875366),
#  ('inocente', 0.9998122453689575),
#  ('espelho', 0.9998120665550232),
#  ('#tenso', 0.9998120665550232),
#  ('#tomorrowland', 0.9998120069503784),
#  ('#rousseff', 0.9998120069503784),
#  ('ido', 0.9998120069503784),
#  ('teste', 0.9998118281364441),
#  ('#petralhas', 0.9998117089271545),
#  ('afff', 0.9998114109039307),
#  ('responda', 0.9998113512992859),
#  ('#mudamaisbrasil', 0.9998112320899963),
#  ('empréstimo', 0.999811053276062),
#  ('eleicoes', 0.9998109340667725),
#  ('alerta', 0.9998108744621277),
#  ('#ditadura', 0.9998108148574829),
#  ('olhada', 0.9998107552528381),
#  ('escárnio', 0.9998106956481934),
#  ('covardia', 0.9998105764389038),
#  ('sindical', 0.999810516834259),
#  ('descoberto', 0.999810516834259),
#  ('caixa', 0.999810516834259),
#  ('#espntemlinhadia', 0.9998102784156799),
#  ('mafia', 0.9998102784156799),
#  ('aguardem', 0.9998098015785217),
#  ('ladrona', 0.9998098015785217),
#  ('possibilidade', 0.999809741973877),
#  ('copiando', 0.9998096823692322),
#  ('condena', 0.9998096227645874),
#  ('vagabunda', 0.9998095631599426),
#  ('vermelhas', 0.9998095035552979),
#  ('#oremos', 0.999809205532074),
#  ('concordar', 0.999809205532074),
#  ('cagou', 0.9998091459274292),
#  ('saibam', 0.9998090863227844),
#  ('aecistas', 0.9998090267181396),
#  ('dirá', 0.9998090267181396),
#  ('cidadã', 0.9998087882995605),
#  ('podres', 0.9998087286949158),
#  ('conversar', 0.9998087286949158),
#  ('importante', 0.9998086094856262)]

# %% [markdown]
# # Build Your own embedding

# %%
#Cretae your own embedding
# This initializes a Keras utilities that does all the tokenization for you
tokenizer = Tokenizer()

# The tokenization learns a dictionary that maps a token (integer) to each word
# It can be done only on the train set - we are not supposed to know the test set!
# This tokenization also lowercases your words, apply some filters, and so on 
tokenizer.fit_on_texts(X_train)
    
# We apply the tokenization to the train and test set
X_train_token = tokenizer.texts_to_sequences(X_train)
X_test_token = tokenizer.texts_to_sequences(X_test)

X_train_pad = pad_sequences(X_train_token, dtype='float32', padding='post')
X_test_pad = pad_sequences(X_test_token, dtype='float32', padding='post')

#Your X_train_token and X_test_token contain sequences of different lengths.
#a neural network has to have a tensor as input. For this reason, you have to pad your data.

vocab_size = len(tokenizer.word_index)

# %% [markdown]
# # Use pretrained embeddings

# %%
# %%time
word_vectors= KeyedVectors.load_word2vec_format('glove_s100.txt') # load pretrained glove_s100,
# Out:
# CPU times: user 1min 23s, sys: 2.2 s, total: 1min 26s
# Wall time: 1min 28s

# %%
result = word_vectors.most_similar('política')
result
# Out:
# [('económica', 0.8212239146232605),
#  ('politica', 0.7895896434783936),
#  ('políticas', 0.781465470790863),
#  ('estratégia', 0.7725036144256592),
#  ('social', 0.7609491348266602),
#  ('perspectiva', 0.7572699189186096),
#  ('reforma', 0.7452260851860046),
#  ('europeia', 0.7418079972267151),
#  ('externa', 0.7416183948516846),
#  ('opinião', 0.73964524269104)]

# %%
embedding_dimension = 300

model = Sequential()
model.add(layers.Embedding(input_dim=vocab_size + 1, output_dim=embedding_dimension, mask_zero=True))
model.add(layers.LSTM(20))
model.add(layers.Dense(10, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %%
# Function to convert a sentence (list of words) into a matrix representing the words in the embedding space
def embed_sentence(word2vec, sentence):
    embedded_sentence = []
    for word in sentence:
        if word in word2vec.wv:
            embedded_sentence.append(word2vec.wv[word])
        
    return np.array(embedded_sentence)

# Function that converts a list of sentences into a list of matrices
def embedding(word2vec, sentences):
    embed = []
    
    for sentence in sentences:
        embedded_sentence = embed_sentence(word2vec, sentence)
        embed.append(embedded_sentence)
        
    return embed

# Embed the training and test sentences
X_train_embed = embedding(word2vec, X_train)
X_test_embed = embedding(word2vec, X_test)
# First, train a word2vec model (with the arguments that you want) on your training sentence. Store it into the word2vec variable.
word2vec = Word2Vec(sentences=X_train, vector_size=60, min_count=10, window=10)
