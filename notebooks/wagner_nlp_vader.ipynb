# %%
#imports
import os
import pandas as pd
from twitterelectionbr.LeIA.leia import SentimentIntensityAnalyzer

# %%
def sentiment(analyzer, data):
    temp=[]
    for row in data:
        tmp=analyzer.polarity_scores(row)
        temp.append(tmp)
    return temp

# %%
def nlp_vader(path, column):
    files = []
    datasets = []

    analyzer = SentimentIntensityAnalyzer()

    for dirname, _, filenames in os.walk(path):
        for filename in filenames:
            files.append(os.path.join(dirname, filename))

    for file in files:
        datasets.append(pd.read_csv(file))
        print(f'Dataset {file} carregado...')

    for dataset in datasets:

        query = dataset['query'][0]
        filename = query + "_vader.csv"

        print(f'Realizando analise de sentimento em {query}...')

        dataset['VADAR'] = sentiment(analyzer, dataset[column])
        dataset['compound']  = dataset['VADAR'].apply(lambda score_dict: score_dict['compound'])
        dataset['sentiment']  = dataset['compound'].apply(lambda x: 'pos' if x > 0.05 else ('neg' if x < -0.05 else 'neu'))

        print(f'Dataset {query} analisado.')
        print(dataset['sentiment'].value_counts())

        dataset.to_csv(os.path.join(path, filename))

        print(f'Dataset {query} salvo.')

# %%
# !ls ../raw_data/data
# Out:
# 2014  2018  2022  totals

# %%
nlp_vader('../raw_data/data/2022/JAIR_BOLSONARO', 'content')
# Out:
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-08.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-01.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-15.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-12.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-27.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-18.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-03.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-17.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-23.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-07.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-10.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-06-02.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-02.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-31.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-04.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-15.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-05.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-14.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-01.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-30.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-14.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-21.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-15.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-03.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-07.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-24.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-11.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-01.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-11.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-25.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-29.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-24.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-12.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-04.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-18.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-13.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-13.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-30.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-20.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-29.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-17.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-02.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-25.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-05.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-27.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-14.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-06.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-29.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-26.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-19.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-22.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-23.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-09.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-10.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-16.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-22.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-16.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-02.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-26.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-25.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-22.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-17.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-28.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-27.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-23.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-03.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-13.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-06.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-09.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-19.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-21.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-16.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-19.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-06.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-24.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-08.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-26.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-28.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-12.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-28.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-20.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-30.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-08.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-05.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-04.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-09.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-11.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-07.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-31.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-06-01.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-04-21.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-20.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-05-10.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/total_tweets.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/"Jair Bolsonaro"/2022-03-18.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-08.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-01.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-15.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-12.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-27.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-18.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-03.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-17.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-23.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-07.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-10.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-06-02.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-02.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-31.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-04.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-15.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-05.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-14.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-01.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-30.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-14.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-21.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-03.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-07.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-24.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-11.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-01.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-11.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-25.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-29.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-24.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-12.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-18.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-13.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-13.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-20.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-29.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-02.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-25.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-27.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-14.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-06.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-29.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-26.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-19.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-22.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-23.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-09.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-10.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-16.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-16.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-02.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-26.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-25.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-22.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-17.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-27.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-03.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-13.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-06.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-09.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-19.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-21.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-16.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-19.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-06.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-24.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-08.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-26.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-28.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-12.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-28.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-20.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-30.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-08.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-05.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-09.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-07.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-31.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-04-21.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-20.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-05-10.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/total_tweets.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(from:jairbolsonaro)/2022-03-18.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-08.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-01.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-15.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-12.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-27.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-18.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-03.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-17.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-23.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-07.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-10.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-06-02.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-02.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-31.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-04.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-15.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-05.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-14.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-01.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-30.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-14.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-21.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-15.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-03.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-07.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-24.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-11.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-01.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-11.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-25.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-29.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-24.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-12.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-04.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-18.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-13.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-13.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-30.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-20.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-29.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-17.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-02.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-25.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-05.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-27.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-14.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-06.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-29.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-26.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-19.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-22.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-23.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-09.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-10.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-16.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-22.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-16.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-02.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-26.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-25.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-22.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-17.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-28.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-27.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-23.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-03.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-13.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-06.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-09.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-19.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-21.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-16.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-19.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-06.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-24.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-08.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-26.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-28.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-12.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-28.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-20.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-30.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-08.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-05.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-04.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-09.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-03-11.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-07.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-31.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-06-01.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-04-21.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-20.csv carregado...
# Dataset ../raw_data/data/2022/JAIR_BOLSONARO/(to:jairbolsonaro)/2022-05-10.csv carregado...
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 nlp_vader('../raw_data/data/2022/JAIR_BOLSONARO', 'content')
#
# Input In [3], in nlp_vader(path, column)
#       9         files.append(os.path.join(dirname, filename))
#      11 for file in files:
# ---> 12     datasets.append(pd.read_csv(file))
#      13     print(f'Dataset {file} carregado...')
#      15 for dataset in datasets:
#
# File ~/.pyenv/versions/3.8.12/envs/twitterelectionbr/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.pyenv/versions/3.8.12/envs/twitterelectionbr/lib/python3.8/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.8.12/envs/twitterelectionbr/lib/python3.8/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~/.pyenv/versions/3.8.12/envs/twitterelectionbr/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File ~/.pyenv/versions/3.8.12/envs/twitterelectionbr/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~/.pyenv/versions/3.8.12/envs/twitterelectionbr/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/.pyenv/versions/3.8.12/envs/twitterelectionbr/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/.pyenv/versions/3.8.12/envs/twitterelectionbr/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/.pyenv/versions/3.8.12/envs/twitterelectionbr/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.
