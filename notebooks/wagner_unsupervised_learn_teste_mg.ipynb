# %% [markdown]
# ### Imports

# %%
# import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#gensim
from gensim.models.phrases import Phrases, Phraser
from gensim.models import Word2Vec


from sklearn.cluster import KMeans

# %% [markdown]
# #### Jupyter Configuration

# %%
pd.options.display.max_colwidth = 100

# %% [markdown]
# ### Analysing data

# %% [markdown]
# #### Loading CSV

# %%
#df = pd.read_csv('../raw_data/Tweets_Mg.csv', encoding='utf-8')
df = pd.read_csv('../raw_data/mito_total_tweets.csv', encoding='utf-8')
df.sample(10).T
# Out:
#                                                                                                               438595  \
# url                                                    https://twitter.com/ParaisoLeandro/status/1050799278380208128
# date                                                                                             2018-10-12 17:24:05
# content          @org_conservador @leandroruschel E isso está acontecendo, mas não são os apoiadores de Bolsonaro...
# id                                                                                               1050799278380208128
# reply_count                                                                                                        0
# retweet_count                                                                                                      0
# like_count                                                                                                         0
# quote_count                                                                                                        0
# lang                                                                                                              pt
# username                                                                                              ParaisoLeandro
# displayname                                                                                          Leandro Paraíso
# description                                                                                                      NaN
# verified                                                                                                       False
# created                                                                                          2018-10-12 15:00:47
# followers_count                                                                                                    0
# friends_count                                                                                                     30
# location                                                                                                         NaN
# protected                                                                                                      False
# profile_img                             https://pbs.twimg.com/profile_images/1177242323387932675/ME1UUW8D_normal.jpg
# query                                                                                                           mito
# crawled_date                                                                                              2022-05-31
#
#                                                                                        372526  \
# url                               https://twitter.com/lucaskorzoff/status/1056691363289460736
# date                                                                      2018-10-28 23:37:08
# content                                          Agora a bosta da Globo vem babar ovo do mito
# id                                                                        1056691363289460736
# reply_count                                                                                 0
# retweet_count                                                                               0
# like_count                                                                                  2
# quote_count                                                                                 0
# lang                                                                                       pt
# username                                                                         lucaskorzoff
# displayname                                                                              𝒌𝒐𝒓𝒛
# description                                         zero quatro sete | @flamengo @fcbarcelona
# verified                                                                                False
# created                                                                   2016-05-28 04:03:43
# followers_count                                                                          1079
# friends_count                                                                             492
# location                                                                                  NaN
# protected                                                                               False
# profile_img      https://pbs.twimg.com/profile_images/1523067004013404168/beKTKBh1_normal.jpg
# query                                                                                    mito
# crawled_date                                                                       2022-05-31
#
#                                                                                                  276790  \
# url                                        https://twitter.com/DiogoFrenandes/status/986732903018180609
# date                                                                                2018-04-18 22:27:11
# content          Gostei de um vídeo @YouTube https://t.co/qYqHtaVEpm canal que fez minha Cartoon (mito)
# id                                                                                   986732903018180609
# reply_count                                                                                           0
# retweet_count                                                                                         0
# like_count                                                                                            0
# quote_count                                                                                           0
# lang                                                                                                 pt
# username                                                                                 DiogoFrenandes
# displayname                                                                              DiogoFrenandes
# description                                      meu jogo favolito e minecraft   naruto e muito foda 😀😀
# verified                                                                                          False
# created                                                                             2017-08-24 00:01:39
# followers_count                                                                                       3
# friends_count                                                                                         5
# location                                                                                            NaN
# protected                                                                                         False
# profile_img                 https://pbs.twimg.com/profile_images/902697557356417024/oG090HSy_normal.jpg
# query                                                                                              mito
# crawled_date                                                                                 2022-05-31
#
#                                                                                                               186142  \
# url                                                         https://twitter.com/EdsonSilva/status/976126931245633536
# date                                                                                             2018-03-20 16:02:50
# content                                                    @churrycristaldo Churry mito volta, eu te amo, #ajudanoix
# id                                                                                                976126931245633536
# reply_count                                                                                                        0
# retweet_count                                                                                                      0
# like_count                                                                                                         0
# quote_count                                                                                                        0
# lang                                                                                                              pt
# username                                                                                                  EdsonSilva
# displayname                                                                              💚🥇🏆 (1999/2020/2021) اديسون
# description      Aqui falo prioritariamente do meu @Palmeiras e encho o saco com outras coisinhas, não gosta é só...
# verified                                                                                                       False
# created                                                                                          2009-04-03 19:24:42
# followers_count                                                                                                  222
# friends_count                                                                                                    660
# location                                                                                Governador Valadares, Brasil
# protected                                                                                                      False
# profile_img                             https://pbs.twimg.com/profile_images/1355464551106539521/10v6lTPm_normal.jpg
# query                                                                                                           mito
# crawled_date                                                                                              2022-05-31
#
#                                                                                        261418  \
# url                             https://twitter.com/erickcassiaano/status/1039360324099559424
# date                                                                      2018-09-11 03:49:46
# content                                                            Nico López é um mito kkkkk
# id                                                                        1039360324099559424
# reply_count                                                                                 0
# retweet_count                                                                               0
# like_count                                                                                  0
# quote_count                                                                                 0
# lang                                                                                       pt
# username                                                                       erickcassiaano
# displayname                                                                                 👹
# description                                                  Salmo 23•🙏🏽/ @scinternacional 🇦🇹
# verified                                                                                False
# created                                                                   2016-02-09 03:10:48
# followers_count                                                                          1349
# friends_count                                                                            1213
# location                                                                             Gravataí
# protected                                                                               False
# profile_img      https://pbs.twimg.com/profile_images/1530968033442799616/TjE98yqX_normal.jpg
# query                                                                                    mito
# crawled_date                                                                       2022-05-31
#
#                                                                                              378494  \
# url                                  https://twitter.com/garciajoaoedua1/status/1056580855299260416
# date                                                                            2018-10-28 16:18:00
# content          @SchuldinerSieg Aeeee  é Bolsonaro fazendo milagres e causas impossíveis é mito!!!
# id                                                                              1056580855299260416
# reply_count                                                                                       0
# retweet_count                                                                                     0
# like_count                                                                                        0
# quote_count                                                                                       0
# lang                                                                                             pt
# username                                                                            garciajoaoedua1
# displayname                                                                            Joao Eduardo
# description                                                                                     NaN
# verified                                                                                      False
# created                                                                         2015-10-11 20:24:27
# followers_count                                                                                 111
# friends_count                                                                                   245
# location                                                          Subsetor Oeste 10, Ribeirão Preto
# protected                                                                                     False
# profile_img            https://pbs.twimg.com/profile_images/1519011458893365249/YUdNR4bC_normal.jpg
# query                                                                                          mito
# crawled_date                                                                             2022-05-31
#
#                                                                                                               523680  \
# url                                                       https://twitter.com/razevedorsa/status/1036655373355241472
# date                                                                                             2018-09-03 16:41:15
# content          Cadê o alto índice de rejeição do Mito??? Eles estão desesperados!!! KKKKKKKK https://t.co/niAQ9...
# id                                                                                               1036655373355241472
# reply_count                                                                                                        0
# retweet_count                                                                                                      0
# like_count                                                                                                         0
# quote_count                                                                                                        0
# lang                                                                                                              pt
# username                                                                                                 razevedorsa
# displayname                                                                                       Rogerio S. Azevedo
# description                                                                 BOLSONARO PRESIDENTE ATÉ 2026! EU APÓIO.
# verified                                                                                                       False
# created                                                                                          2015-07-26 17:05:52
# followers_count                                                                                                  101
# friends_count                                                                                                    228
# location                                                                                      Rio de Janeiro, Brasil
# protected                                                                                                      False
# profile_img                              https://pbs.twimg.com/profile_images/739571949454667777/NuPS5uv6_normal.jpg
# query                                                                                                           mito
# crawled_date                                                                                              2022-05-31
#
#                                                                                                               548478  \
# url                                                        https://twitter.com/DalmaMusic_/status/974307849407889408
# date                                                                                             2018-03-15 15:34:27
# content                                                                                @MetaErmal Ahahahaha mito 😂😂😂
# id                                                                                                974307849407889408
# reply_count                                                                                                        0
# retweet_count                                                                                                      0
# like_count                                                                                                         0
# quote_count                                                                                                        0
# lang                                                                                                              tl
# username                                                                                                 DalmaMusic_
# displayname                                                                                                  DALMA 🎧
# description      HR & Payroll Officer 💻 - Degree in Political Science 🎓 - Master in Tax Law 💼 - Concert Goer 🎸 - ...
# verified                                                                                                       False
# created                                                                                          2015-02-02 22:14:48
# followers_count                                                                                                  307
# friends_count                                                                                                    304
# location                                                                                            Palermo, Sicilia
# protected                                                                                                      False
# profile_img                             https://pbs.twimg.com/profile_images/1449819833042935818/62wqTAMd_normal.jpg
# query                                                                                                           mito
# crawled_date                                                                                              2022-05-31
#
#                                                                                        270538  \
# url                                    https://twitter.com/crvgeira/status/972148447695564800
# date                                                                      2018-03-09 16:33:46
# content                                                                            MIOTO MITO
# id                                                                         972148447695564800
# reply_count                                                                                 1
# retweet_count                                                                               0
# like_count                                                                                  0
# quote_count                                                                                 0
# lang                                                                                       es
# username                                                                             crvgeira
# displayname                                                                                 j
# description                                                      sobretudo sóbria I xingrid ❤
# verified                                                                                False
# created                                                                   2016-07-15 03:10:15
# followers_count                                                                           857
# friends_count                                                                             618
# location                                                                                  NaN
# protected                                                                               False
# profile_img      https://pbs.twimg.com/profile_images/1508756593495748612/sIYIDnR2_normal.jpg
# query                                                                                    mito
# crawled_date                                                                       2022-05-31
#
#                                                                                                               501095
# url                                                      https://twitter.com/xcelestiales/status/1046420019343708166
# date                                                                                             2018-09-30 15:22:28
# content          @Guerra00001 @Darthmau1 @asgardicn @Aisu_boi @beyoncedefense fico com a frase mais clichê do mun...
# id                                                                                               1046420019343708166
# reply_count                                                                                                        0
# retweet_count                                                                                                      0
# like_count                                                                                                         0
# quote_count                                                                                                        0
# lang                                                                                                              pt
# username                                                                                                xcelestiales
# displayname                                                                                                     fefe
# description                                     ⇝ my life is a perfect graveyard of buried hopes ও〈📚28 / 50〉ela/dela
# verified                                                                                                       False
# created                                                                                          2012-05-18 23:10:22
# followers_count                                                                                                 1179
# friends_count                                                                                                   1064
# location                                                                                              Verona, Veneto
# protected                                                                                                      False
# profile_img                             https://pbs.twimg.com/profile_images/1531389367146754050/4wORbbDq_normal.jpg
# query                                                                                                           mito
# crawled_date                                                                                              2022-05-31

# %% [markdown]
# #### Cheking type of data and missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559591 entries, 0 to 559590
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              559591 non-null  object
#  1   date             559591 non-null  object
#  2   content          559591 non-null  object
#  3   id               559591 non-null  int64
#  4   reply_count      559591 non-null  int64
#  5   retweet_count    559591 non-null  int64
#  6   like_count       559591 non-null  int64
#  7   quote_count      559591 non-null  int64
#  8   lang             559591 non-null  object
#  9   username         559591 non-null  object
#  10  displayname      559386 non-null  object
#  11  description      450439 non-null  object
#  12  verified         559591 non-null  bool
#  13  created          559591 non-null  object
#  14  followers_count  559591 non-null  int64
#  15  friends_count    559591 non-null  int64
#  16  location         413345 non-null  object
#  17  protected        559591 non-null  bool
#  18  profile_img      559409 non-null  object
#  19  query            559591 non-null  object
#  20  crawled_date     559591 non-null  object
# dtypes: bool(2), int64(7), object(12)
# memory usage: 82.2+ MB

# %% [markdown]
# #### Dataset considerations

# %% [markdown]
# - Most of the content has NaN values
# - 26 columns in total. 7 columns are object type, 2 columns are int type, 17 columns are float type
# - 15 columns are complety empty, latitude and longitude only has 1% of values filled, the user location is present in 67% of the total rows

# %% [markdown]
# #### Check for unique values

# %%
df.nunique()
# Out:
# Unnamed: 0                   8199
# Created At                   7945
# Text                         5765
# Geo Coordinates.latitude       57
# Geo Coordinates.longitude      57
# User Location                1591
# Username                     3907
# User Screen Name             3966
# Retweet Count                 113
# Classificacao                   3
# Observação                      1
# Unnamed: 10                     0
# Unnamed: 11                     0
# Unnamed: 12                     0
# Unnamed: 13                     0
# Unnamed: 14                     0
# Unnamed: 15                     0
# Unnamed: 16                     0
# Unnamed: 17                     0
# Unnamed: 18                     0
# Unnamed: 19                     0
# Unnamed: 20                     0
# Unnamed: 21                     0
# Unnamed: 22                     0
# Unnamed: 23                     0
# Unnamed: 24                     0
# dtype: int64

# %%
df['User Location'].value_counts()
# Out:
# Brasil                           591
# Minas Gerais                     354
# Belo Horizonte - Minas Gerais    234
# Belo Horizonte, Brasil           227
# Belo Horizonte                   131
#                                 ...
# SABARÁ-MG                          1
# SABARÁ MG                          1
# João Monlevade, Brasil             1
# zimbabwe                           1
# Brasil - Angola - Portugal         1
# Name: User Location, Length: 1591, dtype: int64

# %% [markdown]
# #### Observations

# %% [markdown]
# - There's 3907 unique users 47% of the total number of tweets observed
# - There's only 3 classification types (Positivo, Negativo, Neutro)
# - The dataset are 'balanced' not 100% but it's okay
# - The most common regions of the tweets are Brasil, Minas Gerais, Belo Horizonte respectively

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# dropping all columns that:
#
# - all null records
# - less than 40% data
# - all unique records such as id's

# %%
df = df[['Created At', 'Text', 'User Location', 'Username', 'Retweet Count', 'Classificacao']]

# %% [markdown]
# #### Removing duplicates based on Text

# %%
df = df.drop_duplicates(subset=['Text'], keep='first')

# %% [markdown]
# #### Defining a clean encoder

# %%
import re
import string

from sklearn.pipeline import make_pipeline
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import  make_column_transformer
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords 


class CleaningEncoder(BaseEstimator, TransformerMixin):
    '''
    Receives raw text data from the tweets and returns clean, ready to process data:
    turns all into lower case;
    removes punctuation;
    removes stopwords;
    removes numbers;
    removes users' handles
    
    '''
    def __init__(self):
        pass
                        
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        #assert isinstance(X, pd.DataFrame)
        X_ = X.copy()      
        
        #removin NaN values
        X_ = X_.fillna('nenhuma descrição')
        
        #removing links
        X_ = X_.apply(lambda x: re.sub(r"http\S+", "", x))
        X_ = X_.apply(lambda x: re.sub(r"www.\S+", "", x))
                
        #removing punctuation from each tweet
        new_punc = list(string.punctuation)
        del new_punc[2]
        del new_punc[-11]
        for punctuation in new_punc:
            X_ = X_.str.replace(punctuation, '')
            
        #removing numbers
        X_ = X_.str.replace('\d+', '')
        
        #tokenizing - removes handles, applies lowercase, keeps #, shortens letter repetitions to three
        #ex: kkkkk, kkkkkk, kkkkkkkkk = kkk
        tkn = TweetTokenizer(preserve_case=False, reduce_len=True, strip_handles=True)
        X_ = X_.apply(lambda x: tkn.tokenize(x))
        
        #removing stopwords
        stop_words = stopwords.words('portuguese')
        stop_words.remove('não')
        addicional = [
            'd', 'ta', 'q', 'tah', 'tao', 'eh', 'vc', 'voce',
            'pq', 'quedê', 'mto', 'mt', 'bj', 'bjs','vcs','bb',
            'b', 'sao', 'axo', 'mano', 'ae', 'neh', 'aí', '...', 'rt',
            'kkk', 'porque', 'né', 'no', 'iai', 'tbm', 'msm', 'jah']
        stop_words.extend(addicional)
        
        #X_ = X_.apply(lambda x: [word for word in x if len(word) > 1])
        X_ = X_.apply(lambda x: ' '.join(word for word in x if word not in (stop_words)))
        
        return X_

# %% [markdown]
# #### Execute cleaning process on text column

# %%
clean = CleaningEncoder()

df['text_clean'] = clean.fit_transform(df['Text'])
# Out:
# /tmp/ipykernel_17887/3813258320.py:44: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   X_ = X_.str.replace(punctuation, '')
# /tmp/ipykernel_17887/3813258320.py:47: FutureWarning: The default value of regex will change from True to False in a future version.
#   X_ = X_.str.replace('\d+', '')

# %%
df['text_clean']
# Out:
# 0                                            catedral santo antônio governador valadaresmg
# 1                                                        governador valadares minas gerais
# 2                                                        governador valadares minas gerais
# 3
# 4         psol vai questionar aumento vereadores prefeito bh justiça politica estado minas
#                                                ...
# 8176                             trio preso suspeito roubo tráfico abuso sexual uberlândia
# 8186            trio preso suspeito roubo tráfico abuso sexual uberlândia #operaçãobetalab
# 8191                    trio preso suspeito roubo tráfico abuso sexual uberlândia #timbeta
# 8197    trio preso suspeito roubo tráfico abuso sexual uberlândia autores molestado vítima
# 8198                   trio suspeito roubo cargas preso santa luzia mg #rmg #recordtvminas
# Name: text_clean, Length: 3484, dtype: object

# %% [markdown]
# #### Removing duplicates again on cleaned data

# %%
df = df.drop_duplicates(subset=['text_clean'], keep='first')

# %% [markdown]
# #### Converting Date column to DateTime Object and creating two new columns:month and year

# %%
df['Created At'] = pd.to_datetime(df['Created At'])
df['month'] = df['Created At'].dt.month
df['year'] = df['Created At'].dt.year
# Out:
# /tmp/ipykernel_17887/607463297.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Created At'] = pd.to_datetime(df['Created At'])
# /tmp/ipykernel_17887/607463297.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['Created At'].dt.month
# /tmp/ipykernel_17887/607463297.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['Created At'].dt.year

# %% [markdown]
# #### Storing column 'Classificacao' as our y_pred

# %%
y_pred = df['Classificacao']
df.drop(columns=['Classificacao'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.8.12/envs/twitterelectionbr/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.pyenv/versions/3.8.12/envs/twitterelectionbr/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.pyenv/versions/3.8.12/envs/twitterelectionbr/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Classificacao'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [94], in <cell line: 1>()
# ----> 1 y_pred = df['Classificacao']
#       2 df.drop(columns=['Classificacao'], inplace=True)
#
# File ~/.pyenv/versions/3.8.12/envs/twitterelectionbr/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/.pyenv/versions/3.8.12/envs/twitterelectionbr/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Classificacao'

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# #### Converting the "text_clean" column in the format supported by embeddings.

# %%
sent = [row for row in df["text_clean"]]
#use Gensim Phrases package to automatically detect common phrases (bigrams) from a list of sentences.
# phrases = Phrases(sent, min_count=1, progress_per=50000)
# bigram = Phraser(phrases)
# sentences = bigram[sent]

sentences = []
for i in range(0, len(sent)):
    sentences.append(sent[i].split(' '))

#sentences

# %%
#Initializing the word2vec model

import multiprocessing

w2v_model = Word2Vec(min_count=4,
                     window=5,
                     vector_size =300,
                     sample=1e-5, 
                     alpha=0.03, 
                     min_alpha=0.0007, 
                     negative=20,
                     seed= 42,
                     workers=multiprocessing.cpu_count()-1)


#building vocab of the word2vec model from the custom data
w2v_model.build_vocab(sentences, progress_per=50000)

# https://towardsdatascience.com/unsupervised-sentiment-analysis-a38bf1906483

# %%
#training the word2vec model
w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=30, report_delay=1)
# Out:
# (68412, 890970)

# %%
# checking similar words to battery in the corpus
w2v_model.wv.most_similar(positive=["lula"])
# Out:
# [('minas', 0.9997169375419617),
#  ('estado', 0.9996999502182007),
#  ('mg', 0.9996914863586426),
#  ('drogas', 0.9996911287307739),
#  ('#timbeta', 0.999688446521759),
#  ('governo', 0.9996777176856995),
#  ('presos', 0.9996697902679443),
#  ('en', 0.99966961145401),
#  ('pimentel', 0.9996667504310608),
#  ('gerais', 0.9996564388275146)]

# %%
#saving the word2vec model
w2v_model.save("../raw_data/word2vec.model")

# %%
#Loading the word2vec model
word_vectors = Word2Vec.load("../raw_data/word2vec.model").wv

# %%
#Feeding the embeddings to a KMeans model to cluster words into positive, negative, and neutral clusters
model = KMeans(n_clusters=3, max_iter=1000, random_state=42, n_init=50).fit(X=word_vectors.vectors.astype('double'))

# %%
# check what we have in each cluster to label the clusters
word_vectors.similar_by_vector(model.cluster_centers_[0], topn=200, restrict_vocab=None)
# Out:
# [('minas', 0.9999662637710571),
#  ('estado', 0.9999570846557617),
#  ('drogas', 0.9999457597732544),
#  ('mg', 0.9999454021453857),
#  ('gerais', 0.9999250173568726),
#  ('presídio', 0.9999250173568726),
#  ('governo', 0.9999234080314636),
#  ('governador', 0.9999186396598816),
#  ('pimentel', 0.999916136264801),
#  ('el', 0.9999133348464966),
#  ('tráfico', 0.9999099373817444),
#  ('amarela', 0.9999091029167175),
#  ('en', 0.999907374382019),
#  ('#timbeta', 0.9999069571495056),
#  ('roubo', 0.9999060034751892),
#  ('sobre', 0.9999038577079773),
#  ('un', 0.9999029636383057),
#  ('le', 0.9999009966850281),
#  ('las', 0.9998959898948669),
#  ('bh', 0.999895453453064),
#  ('após', 0.9998951554298401),
#  ('secretaria', 0.9998944997787476),
#  ('presos', 0.9998908638954163),
#  ('dois', 0.9998884201049805),
#  ('mi', 0.9998874664306641),
#  ('lo', 0.9998872876167297),
#  ('não', 0.9998862743377686),
#  ('ter', 0.9998840689659119),
#  ('contra', 0.9998803734779358),
#  ('politica', 0.999878466129303),
#  ('#mg', 0.9998780488967896),
#  ('la', 0.9998777508735657),
#  ('apreende', 0.9998770356178284),
#  ('pm', 0.9998766779899597),
#  ('los', 0.9998754262924194),
#  ('brasil', 0.9998746514320374),
#  ('febre', 0.9998746514320374),
#  ('#raynniere', 0.9998739957809448),
#  ('anos', 0.9998738169670105),
#  ('#operacaobetalab', 0.9998735189437866),
#  ('todo', 0.9998730421066284),
#  ('prende', 0.9998704791069031),
#  ('#somostodosdilma', 0.9998698830604553),
#  ('new', 0.9998685717582703),
#  ('más', 0.9998655319213867),
#  ('juiz', 0.9998641014099121),
#  ('#betalab', 0.9998627305030823),
#  ('todos', 0.999862551689148),
#  ('#globo', 0.999862551689148),
#  ('ser', 0.9998593926429749),
#  ('massacre', 0.9998590350151062),
#  ('fica', 0.9998588562011719),
#  ('presídios', 0.9998584985733032),
#  ('#beta', 0.9998541474342346),
#  ('pra', 0.9998528957366943),
#  ('vai', 0.9998527765274048),
#  ('si', 0.999850869178772),
#  ('ponen', 0.9998506903648376),
#  ('preso', 0.9998494386672974),
#  ('nacional', 0.9998471736907959),
#  ('dias', 0.9998448491096497),
#  ('detido', 0.9998428821563721),
#  ('via', 0.9998418688774109),
#  ('#sigodevolta', 0.9998416304588318),
#  ('outros', 0.9998416304588318),
#  ('una', 0.9998413920402527),
#  ('#buyraynniereonitunes', 0.9998409152030945),
#  ('es', 0.9998400211334229),
#  ('recursos', 0.9998378753662109),
#  ('polícia', 0.9998360276222229),
#  ('crise', 0.9998352527618408),
#  ('dia', 0.9998349547386169),
#  ('cobra', 0.999832272529602),
#  ('surto', 0.9998317360877991),
#  ('retaliações', 0.9998310208320618),
#  ('con', 0.9998304843902588),
#  ('novo', 0.9998304843902588),
#  ('ipatinga', 0.9998301267623901),
#  ('menor', 0.9998301267623901),
#  ('temer', 0.9998289942741394),
#  ('aqui', 0.9998284578323364),
#  ('vacinas', 0.9998278617858887),
#  ('municípios', 0.9998270273208618),
#  ('financeira', 0.9998252391815186),
#  ('homem', 0.999824047088623),
#  ('horizonte', 0.9998234510421753),
#  ('post', 0.9998224377632141),
#  ('yo', 0.9998219609260559),
#  ('nega', 0.9998218417167664),
#  ('autores', 0.9998198747634888),
#  ('calamidade', 0.9998195767402649),
#  ('montes', 0.999817967414856),
#  ('fernando', 0.9998164176940918),
#  ('atentado', 0.9998160600662231),
#  ('suspeito', 0.9998157024383545),
#  ('educação', 0.9998155236244202),
#  ('segurança', 0.9998146891593933),
#  ('ajuda', 0.9998146295547485),
#  ('semanário', 0.9998142719268799),
#  ('armas', 0.9998142123222351),
#  ('ni', 0.9998140335083008),
#  ('jornal', 0.999812126159668),
#  ('diz', 0.9998120069503784),
#  ('arma', 0.9998109340667725),
#  ('vacinação', 0.9998101592063904),
#  ('câmara', 0.9998100996017456),
#  ('ficam', 0.999809980392456),
#  ('bueno', 0.9998084306716919),
#  ('emcom', 0.9998083710670471),
#  ('militares', 0.9998079538345337),
#  ('realiza', 0.9998064637184143),
#  ('hablo', 0.9998063445091248),
#  ('aterro', 0.9998044967651367),
#  ('dados', 0.9998031258583069),
#  ('mortos', 0.9998020529747009),
#  ('saúde', 0.9998019933700562),
#  ('al', 0.9998008608818054),
#  ('detentos', 0.9998006224632263),
#  ('donde', 0.9997991323471069),
#  ('afirma', 0.9997983574867249),
#  ('uol', 0.9997973442077637),
#  ('mil', 0.9997959733009338),
#  ('poços', 0.9997953772544861),
#  ('bairro', 0.9997946619987488),
#  ('hebdo', 0.9997945427894592),
#  ('grande', 0.999794065952301),
#  ('seis', 0.9997936487197876),
#  ('depósitos', 0.9997934699058533),
#  ('ver', 0.9997931718826294),
#  ('palmeiras', 0.9997928142547607),
#  ('valadares', 0.9997926950454712),
#  ('claros', 0.9997912645339966),
#  ('#minas', 0.9997908473014832),
#  ('deste', 0.9997905492782593),
#  ('desastre', 0.9997904300689697),
#  ('joão', 0.9997901320457458),
#  ('pongo', 0.9997895359992981),
#  ('condenado', 0.999789297580719),
#  ('prevenção', 0.9997886419296265),
#  ('julgar', 0.999788224697113),
#  ('justiça', 0.9997870922088623),
#  ('maia', 0.9997863173484802),
#  ('belo', 0.9997859001159668),
#  ('ambiental', 0.9997847676277161),
#  ('economia', 0.9997847080230713),
#  ('helicópteros', 0.9997844696044922),
#  ('emprego', 0.9997842311859131),
#  ('casos', 0.9997841119766235),
#  ('reis', 0.999783456325531),
#  ('tt', 0.9997825026512146),
#  ('suspeitos', 0.9997805953025818),
#  ('tienen', 0.9997801184654236),
#  ('#sdv', 0.999778687953949),
#  ('alvos', 0.9997771382331848),
#  ('deputado', 0.9997767210006714),
#  ('cada', 0.9997764229774475),
#  ('tá', 0.9997761845588684),
#  ('tiene', 0.9997740387916565),
#  ('prisão', 0.9997723698616028),
#  ('partir', 0.999771773815155),
#  ('rj', 0.9997711181640625),
#  ('civil', 0.9997705221176147),
#  ('atirador', 0.9997703433036804),
#  ('nova', 0.9997701644897461),
#  ('bom', 0.9997698068618774),
#  ('assim', 0.9997695684432983),
#  ('foto', 0.9997693300247192),
#  ('ese', 0.9997681975364685),
#  ('francês', 0.999768078327179),
#  ('anuncia', 0.9997671842575073),
#  ('militar', 0.999767005443573),
#  ('home', 0.99976646900177),
#  ('banco', 0.9997656941413879),
#  ('fere', 0.9997644424438477),
#  ('#operaçãobetalab', 0.9997641444206238),
#  ('jovem', 0.999764084815979),
#  ('três', 0.9997639060020447),
#  ('resiste', 0.9997636675834656),
#  ('casa', 0.9997634887695312),
#  ('emergência', 0.9997624158859253),
#  ('santa', 0.9997617602348328),
#  ('sus', 0.999761700630188),
#  ('jovens', 0.9997614622116089),
#  ('detidos', 0.9997606873512268),
#  ('escolas', 0.9997603297233582),
#  ('haverá', 0.9997603297233582),
#  ('têm', 0.9997602105140686),
#  ('zona', 0.9997601509094238),
#  ('otro', 0.9997599124908447),
#  ('deixa', 0.9997595548629761),
#  ('he', 0.9997591376304626),
#  ('apreensão', 0.9997578263282776),
#  ('doses', 0.9997575879096985),
#  ('lauderdale', 0.9997575283050537),
#  ('professores', 0.9997566938400269),
#  ('oito', 0.9997564554214478),
#  ('ppp', 0.9997560977935791),
#  ('mão', 0.9997550249099731),
#  ('município', 0.999754011631012),
#  ('põe', 0.9997537136077881)]
